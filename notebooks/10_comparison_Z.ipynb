# %%
import os
try:
    path_initialized
except NameError:
    path_initialized = True
    os.chdir('..')

import numpy as np
from sympy.abc import x, y

# from qldpc import codes
import networkx as nx
import matplotlib.pyplot as plt
import stim
import pickle
import sinter
from copy import deepcopy
import scipy

import src.device as device
import src.plotting as plotter
import src.stim_dag as stim_dag

from src.RotatedSurfaceCode import RotatedSurfaceCode
from src.TileCode import TileCode
from src.HGPCode import HGPCode
from src.SHYPSCode import SHYPSCode
from src.RadialCode import RadialCode
from src.GBCode import GBCode
from src.HypercubeCode import HypercubeCode
from src.decoders import BPOSD
from src.constructor import construct_code

# %%
compile_tasks = False
if compile_tasks:
    # Making codes
    codes = []
    code_types = []
    code_nkds = []
    code_data_coodes = []

    ds_surface = [3, 5, 7, 9, 11]
    for d in ds_surface:
        code = RotatedSurfaceCode(d)
        codes.append(code)
        code_types.append('Surface')
        code_nkds.append(code.compute_code_parameters())

    nkds_tile = [(288,8,12), (288, 8, 14), (288, 18, 13), (512, 18, 19)]
    for nkd in nkds_tile:
        code = TileCode.known_code(*nkd)
        codes.append(code)
        code_types.append('Tile')
        code_nkds.append(nkd)

    rs_simplex = [3,4]
    for r in rs_simplex:
        code = HGPCode.simplex_code(r)
        codes.append(code)
        code_types.append('Simplex')
        code_nkds.append(code.compute_code_parameters())

    # rs_cube = [2,3]
    # for r in rs_cube:
    #     code = HypercubeCode(r)
    #     codes.append(code)
    #     code_types.append('Hypercube')
    #     code_nkds.append(code.compute_code_parameters())

    lms = [
        (6,6),
        (12,6),
        (12,12),
    ]
    orders = [
        (([3], [1,2]), ([1, 2], [3])),
        (([3], [1, 2]), ([1, 2], [3])),
        (([3], [2, 7]), ([1, 2], [3])),
    ]
    nkds = [
        (72, 12, 6),
        (144, 12, 12),
        (288, 12, 18),
    ]
    for (l,m),(a_ord,b_ord) in zip(lms, orders):
        code = GBCode(l, m, a_ord, b_ord)
        codes.append(code)
        code_types.append('BB')

    code_nkds += nkds

    rsds_radial = [(3,8,12), (3,11,14), (4,6,12), (4,8,16), (4,11,20)]
    for r,s,d in rsds_radial:
        code = RadialCode(r,s,d)
        codes.append(code)
        code_types.append('Radial')
        code_nkds.append(code.compute_code_parameters())

    for code in codes:
        assert len(code.qubit_coords) > 0, code

    code_ids = list(zip(code_types, code_nkds))
else:
    ds_surface = [3, 5, 7, 9, 11]

# %%
if compile_tasks:
    hwp = device.default_hwp
    ps_surface = np.geomspace(1e-3, 1e-1, 7)
    # ps_other = np.geomspace(1e-3, 1.5e-3, 5)
    ps_other = np.geomspace(1e-3, 1e-2, 7)
    p_g = 1e-3
    T2 = 10e-3
    # p = 1e-3
    # t2 = 1e-3
    # p_sh = 1e-3
    # error_params = device.error_params(p=p, T2=t2, p_sh=p_sh)
    buffer = 3
    basis = 'Z'
    schedules = dict()
    tasks = []
    for code, code_type, (n,k,d) in zip(codes, code_types, code_nkds):
        print(code_type, f'[[{n}, {k}, {d}]]...')
        xmax,ymax = 0,0
        data_coords = dict()
        for i in code.data_indices:
            x,y = code.qubit_coords[i]
            data_coords[i] = (x+buffer, y+buffer)
            xmax = max(xmax, x)
            ymax = max(ymax, y)
        dev = device.UnitCellDevice(xmax+2*buffer, ymax+2*buffer, hwp)
        
        rounds = d

        if code_type == 'Surface':
            sched = code.get_schedule(hwp, 'Z', rounds=rounds, refocus_shuttling_noise=True)
        else:
            sched = dev.compile_QEC_schedule(
                code,
                data_coords,
                code.check_cx_layers,
                rounds=rounds,
                use_highways=False,
                refocus_shuttle_noise=True,
                separate_X_Z=code_type != 'Surface',
            )
        schedules[(code_type, (n,k,d))] = sched
        
        for p_sh in (ps_surface if code_type == 'Surface' else ps_other):
            # p = p
            # T2 = 10**(-6-np.log10(p))
            error_params = device.error_params(p=p_g, T2=T2, p_sh=p_sh)
            circ = sched.to_stim_circuit(code, basis, error_params, XYZ_decode=False)
            try:
                circ.detector_error_model()
            except Exception as e:
                print('FAIL', e)

            decoder='pymatching' if code_type == 'Surface' else 'bposd'
            tasks.append(sinter.Task(
                circuit=circ,
                decoder=decoder,
                json_metadata={'n':n, 'k':k, 'd':d, 'type':code_type, 'rounds':rounds, 'basis':basis, 'decoder':decoder, 'p_g':p_g, 'T2':T2, 'p_sh':p_sh},
            ))
    with open('notebooks/data/10_tasks.pkl', 'wb') as f:
        pickle.dump({
            'tasks':tasks,
        }, f)
    with open('notebooks/data/10_params.pkl', 'wb') as f:
        pickle.dump({
            'code_types':code_types,
            'code_nkds':code_nkds,
            'code_data_coodes':code_data_coodes,
            'ps_surface': ps_surface,
            'ps_other': ps_other,
            'schedules':schedules,
        }, f)
else:
    try:
        with open('notebooks/data/10_tasks.pkl', 'rb') as f:
            data = pickle.load(f)
            tasks = data['tasks']
    except FileNotFoundError:
        print('Could not find task file. Setting tasks=None.')
        tasks = None
    with open('notebooks/data/10_params.pkl', 'rb') as f:
        data = pickle.load(f)
        code_types = data['code_types']
        code_nkds = data['code_nkds']
        code_data_coodes = data['code_data_coodes']
        ps_surface = data['ps_surface']
        ps_other = data['ps_other']
        schedules = data['schedules']

# %%
code_ids = list(zip(code_types, code_nkds))

# %%
stats = sinter.read_stats_from_csv_files('notebooks/data/10_results_TMP_Z')
# with open('notebooks/data/10_results_old_prange.pkl', 'rb') as f:
#     stats = pickle.load(f)
#     stats = [s for s in stats if 'p' in s.json_metadata]

# %%
stats
# Out:
# [sinter.TaskStats(strong_id='8c5b39354ede7953df05851bd6a914bc3cdb296a5e1009690861fc5381d00999', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 3, 'type': 'Surface'}, shots=892177, errors=501, seconds=0.21399999999999997),
#  sinter.TaskStats(strong_id='0323ac6ef2cd0d366d3d104ec3127775fbde8a3a41edfa93020b6bf45a88facf', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 3, 'type': 'Surface'}, shots=805137, errors=500, seconds=0.15400000000000003),
#  sinter.TaskStats(strong_id='ffe4dc4bfda4071289d244d4d2be1c997e7d51e63de519c6da993109ec7fbc40', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 3, 'type': 'Surface'}, shots=1314338, errors=666, seconds=0.29500000000000004),
#  sinter.TaskStats(strong_id='25dec3f0ef38b29c9b47f3d355ad87c42b68cd7e37f2197b1eeae27fbb97754d', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 3, 'type': 'Surface'}, shots=898594, errors=581, seconds=0.366),
#  sinter.TaskStats(strong_id='9d5f133a4b0a84eb8ff04931c56cf65f52ea3a879dc42dc3112d8a7e3853a724', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.001, 'p_sh': 0.1, 'rounds': 7, 'type': 'Surface'}, shots=1981508, errors=573, seconds=98.83),
#  sinter.TaskStats(strong_id='2caf0b07f66fe8ddaa5eb320c5cb6d9a128ec6a2cdf958f1e5ed9cd36fabe17d', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 7, 'type': 'Surface'}, shots=10000000, errors=100, seconds=25.821000000000005),
#  sinter.TaskStats(strong_id='e4519a863a73d99d48f9fcc8d95291c4f9ab13af9b948cdaa0044ab5543b7798', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 9, 'type': 'Surface'}, shots=10000000, errors=10, seconds=46.124999999999986),
#  sinter.TaskStats(strong_id='c1b1c6c875895e6cb27943ab310db590bf4d74bd1d7314e5a131d89ccfe69040', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.001, 'p_sh': 0.1, 'rounds': 5, 'type': 'Surface'}, shots=1364514, errors=608, seconds=22.570999999999998),
#  sinter.TaskStats(strong_id='57c4fcab134e6d6560ee4e82c4c2583f8fd42169e8fe0288a54ea9f946920791', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.001, 'p_sh': 0.046415888336127774, 'rounds': 5, 'type': 'Surface'}, shots=1410594, errors=570, seconds=11.943000000000001),
#  sinter.TaskStats(strong_id='707404676d16f52ddd4d3b47e2953541e8160d7440b7c42f589c72b561b61661', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 5, 'type': 'Surface'}, shots=7452194, errors=620, seconds=7.259),
#  sinter.TaskStats(strong_id='e48e5960282b4473cede52e38c3775dbb82766386c8d7751c1ef81d0ff9e12d2', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 7, 'type': 'Surface'}, shots=10000000, errors=325, seconds=63.136),
#  sinter.TaskStats(strong_id='b035ed7c4f666cf12be60044d0b5c92ed05e5bd2e316f9f9b1c567d4804668a9', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 9, 'type': 'Surface'}, shots=10000000, errors=14, seconds=52.287000000000006),
#  sinter.TaskStats(strong_id='c6a1488a0820a44ebea2b4c6b75dd6e0b840caca7ecd22ea25330e675166c2b7', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.001, 'p_sh': 0.1, 'rounds': 9, 'type': 'Surface'}, shots=2530440, errors=575, seconds=338.38400000000007),
#  sinter.TaskStats(strong_id='f7638c649dffbffd88feb76e0904b3dde46e6d7736b28338b5414d1c5786f4dd', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 5, 'type': 'Surface'}, shots=5193250, errors=577, seconds=7.952),
#  sinter.TaskStats(strong_id='3946dd47c9c6edab4eab5d73d767ad992c06af8b6d4c23ed668f00c517403094', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 9, 'type': 'Surface'}, shots=10000000, errors=24, seconds=81.31499999999998),
#  sinter.TaskStats(strong_id='4784b3c608ad5913a05389d2756fbd20af1da6e3a227e9450e9252ce276d0080', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 7, 'type': 'Surface'}, shots=10000000, errors=113, seconds=30.459),
#  sinter.TaskStats(strong_id='2cc733ffdbc59832861009e1a5a54e45167f18f50770f7456c6b5d7d63a9d5dd', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.001, 'p_sh': 0.046415888336127774, 'rounds': 3, 'type': 'Surface'}, shots=789026, errors=596, seconds=0.8719999999999999),
#  sinter.TaskStats(strong_id='592d1318d74c048ec2c5181c07ff103c0808d788726d31c97a417cfaabcdcfb1', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 5, 'type': 'Surface'}, shots=4122146, errors=610, seconds=10.172999999999998),
#  sinter.TaskStats(strong_id='9549e96b816848e83613bd04b4f3c859df2d6b6ac4efd6a520e3791347dbbbf9', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.001, 'p_sh': 0.1, 'rounds': 3, 'type': 'Surface'}, shots=798242, errors=589, seconds=1.7099999999999997),
#  sinter.TaskStats(strong_id='6c8dc925d57be38ae065f922876ce794b12f6a695ce07bcfb3c470e3bb8f94c8', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 5, 'type': 'Surface'}, shots=6392354, errors=580, seconds=7.1850000000000005),
#  sinter.TaskStats(strong_id='c01cc2a7656d322f5ae3a50a670cc3f374210017ac3c9442aebf83b693848010', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 7, 'type': 'Surface'}, shots=10000000, errors=164, seconds=38.64),
#  sinter.TaskStats(strong_id='9fbb0d1e1ab0498d79f0e6fe84762f2f240edb91b0ffbc94acade4c2723e16d3', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.001, 'p_sh': 0.046415888336127774, 'rounds': 7, 'type': 'Surface'}, shots=3943219, errors=676, seconds=98.81899999999999),
#  sinter.TaskStats(strong_id='e3a152fa6110477e03cc683deffedf7b955b169bc3ba909bf6503b59bce15ac2', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.001, 'p_sh': 0.021544346900318832, 'rounds': 5, 'type': 'Surface'}, shots=2389538, errors=631, seconds=10.229000000000001),
#  sinter.TaskStats(strong_id='44e8064bd8b70e86365c980f458f2c434b216c761e0a69083b631d66826c5fff', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 9, 'type': 'Surface'}, shots=10000000, errors=41, seconds=157.9360000000001),
#  sinter.TaskStats(strong_id='bde17d21bcb39929711b19f26e0761dce1f97ffd294f2c6931bcdd4ad9dc6f42', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.001, 'p_sh': 0.021544346900318832, 'rounds': 3, 'type': 'Surface'}, shots=754210, errors=573, seconds=0.475),
#  sinter.TaskStats(strong_id='7b8726c0328e493938ddb7536dfd8c11989a6bed144e4abd637e4760d364d33d', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.001, 'p_sh': 0.021544346900318832, 'rounds': 7, 'type': 'Surface'}, shots=7718397, errors=554, seconds=84.65700000000001),
#  sinter.TaskStats(strong_id='10bf5b5ce1ac879256b02ce319ecd26488573e64e779ab1791e584e3f1da9f00', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 11, 'type': 'Surface'}, shots=10000000, errors=5, seconds=294.5569999999997),
#  sinter.TaskStats(strong_id='9f1fbb49a2631a863ba89e973a08fd28052b2e992d3e8ba9cf6f21be082019dd', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.001, 'p_sh': 0.046415888336127774, 'rounds': 9, 'type': 'Surface'}, shots=8295338, errors=605, seconds=491.5539999999999),
#  sinter.TaskStats(strong_id='f588066e395691e1f02f45f527f9051c9adf7a6d34d0f56d5f746b159fcf5aba', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 11, 'type': 'Surface'}, shots=10000000, errors=1, seconds=106.72400000000002),
#  sinter.TaskStats(strong_id='5013d7cd25e88c8da1385b64ae72f93fd5b12375be01caf8702d0295b831f59d', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.001, 'p_sh': 0.021544346900318832, 'rounds': 11, 'type': 'Surface'}, shots=10000000, errors=41, seconds=497.76999999999975),
#  sinter.TaskStats(strong_id='3855d0a6b0a0396dc4a5701237b6d796506fd88379a7d4fd38864e5387e87cf5', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.001, 'p_sh': 0.021544346900318832, 'rounds': 9, 'type': 'Surface'}, shots=10000000, errors=198, seconds=264.12599999999986),
#  sinter.TaskStats(strong_id='30d561144c95b31c985d411c25183a08414fa26f711b78a39cb8dbdce4a41c8a', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.001, 'p_sh': 0.1, 'rounds': 11, 'type': 'Surface'}, shots=3178836, errors=571, seconds=820.1919999999998),
#  sinter.TaskStats(strong_id='db9b68a05097ad1c22643866253acb2e1b77f3cf1c7a11e94edbe7a39ee20ce9', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 11, 'type': 'Surface'}, shots=10000000, errors=1, seconds=172.34900000000007),
#  sinter.TaskStats(strong_id='44324fac95eb27f2136508fb3e0edbff6cc2143263443b42c085acad354e9299', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 11, 'type': 'Surface'}, shots=10000000, errors=2, seconds=96.29700000000007),
#  sinter.TaskStats(strong_id='ead9f2ed453f9031818a4c44d69f2c30f33dd4471cbad9b6d5d8b59c83b80e6c', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'Z', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.001, 'p_sh': 0.046415888336127774, 'rounds': 11, 'type': 'Surface'}, shots=10000000, errors=353, seconds=1198.5989999999988)]

# %%
def logical_fit(p, a, b, c, d):
    return a*(p/b + c)**((d+1)/2)

def fixed_d_logical_fit(d):
    return lambda p,a,b,c: logical_fit(p,a,b,c,d)

p_upper_cutoffs = {
    ('Radial', (352, 18, 20)): 5e-3,
    ('Radial', (256,18,16)): 8e-3,
    ('Radial', (198, 8, 14)): 8e-3,
    ('BB', (288, 12, 18)): 6e-3,
}

all_ps = [[] for _ in code_ids]
all_lers = [[] for _ in code_ids]
all_uncs = [[] for _ in code_ids]
fit_params = [(np.nan, np.nan, np.nan, np.nan) for _ in code_ids]
for i,(code_type,(n,k,d)) in enumerate(code_ids):
    uncertainties = []
    for stat in stats:
        if stat.shots == 0:
            continue
        jmd = stat.json_metadata
        if (jmd['type'], jmd['n'], jmd['k'], jmd['d']) == (code_type, n, k, d):
            p_sh = jmd['p_sh']

            cutoff = p_upper_cutoffs.get((code_type,(n,k,d)), float('inf'))
            if p_sh > cutoff:
                continue

            ler = stat.errors / stat.shots
            ler = sinter.shot_error_rate_to_piece_error_rate(ler, pieces=d, values=k)
            unc = np.sqrt(ler * (1 - ler) / stat.shots)
            if 0 < ler:
                if ler > 0.5:
                    ler = 0.5
                    unc = np.sqrt(ler * (1 - ler) / stat.shots)
                all_ps[i].append(p_sh)
                all_lers[i].append(ler)
                all_uncs[i].append(unc)
    if len(all_ps[i]) < 3:
        print('Skipping', code_type, n, k, d, all_ps[i], all_lers[i])
        continue
    try:
        if code_type in ['Radial', 'BB']:
            bounds=([0, 0, 0, 0], [float('inf'), float('inf'), float('inf'), float('inf')])
            p0 = [0.5, 10, 1, d]
        else:
            bounds=([0, 0, 0, 0], [float('inf'), float('inf'), float('inf'), float('inf')])
            p0=[0.5, 0.1, 0.2, d]

        log_lers = np.log(np.array(all_lers[i]))
        log_uncertainties = np.array(all_uncs[i]) / np.array(all_lers[i])
        fit_params[i] = scipy.optimize.curve_fit(
            lambda p, a, b, c, d: np.log(logical_fit(p, a, b, c, d)), 
            all_ps[i], 
            log_lers, 
            sigma=log_uncertainties, 
            p0=p0, 
            bounds=bounds, 
            max_nfev=10000
        )[0]
    except Exception as e:
        print(e)
        continue
    
    print(code_type, n,k,d, fit_params[i], all_ps[i], all_lers[i], all_uncs[i])
# Out:
# Surface 9 1 3 [1.81012641e-03 8.95954800e+00 1.16338048e-02 8.08805705e-14] [0.004641588833612777, 0.0021544346900318843, 0.001, 0.01, 0.046415888336127774, 0.1, 0.021544346900318832] [0.0001872527066063001, 0.0002070898687893119, 0.0001689634147835628, 0.00021561484440985046, 0.00025191412472352903, 0.00024607824665906497, 0.0002533734919723529] [np.float64(1.4485979796432389e-05), np.float64(1.6036129704692194e-05), np.float64(1.133720798109114e-05), np.float64(1.5488549435299898e-05), np.float64(1.7865940896530196e-05), np.float64(1.755560831584514e-05), np.float64(1.8326495262017416e-05)]
# Surface 25 1 5 [5.27682065e-04 2.21978746e+00 9.30051306e-04 6.64087438e-02] [0.1, 0.046415888336127774, 0.001, 0.004641588833612777, 0.01, 0.0021544346900318843, 0.021544346900318832] [8.914776191615292e-05, 8.084315574857781e-05, 1.6640502644438282e-05, 2.2223127839338108e-05, 2.9599738953389743e-05, 1.814799696264746e-05, 5.2824717051813685e-05] [np.float64(8.082521439033036e-06), np.float64(7.570125114762843e-06), np.float64(1.4942990855504503e-06), np.float64(2.0686077701117313e-06), np.float64(2.679636149558761e-06), np.float64(1.6849227698017631e-06), np.float64(4.701648395213387e-06)]
# Surface 49 1 7 [8.31754120e-04 1.66221408e+00 1.22966641e-03 1.07319868e+00] [0.1, 0.001, 0.01, 0.0021544346900318843, 0.004641588833612777, 0.046415888336127774, 0.021544346900318832] [4.1320771601849327e-05, 1.4285836736349644e-06, 4.642986484781897e-06, 1.614301350039149e-06, 2.3428900773891925e-06, 2.4494105471450922e-05, 1.0254425454270244e-05] [np.float64(4.5664354552103085e-06), np.float64(3.779658228972101e-07), np.float64(6.81393053050763e-07), np.float64(4.017833675091965e-07), np.float64(4.840335306830796e-07), np.float64(2.4922983158944056e-06), np.float64(1.1526299043268214e-06)]
# Surface 81 1 9 [2.91830310e-03 1.62102111e+00 1.53738739e-03 2.40673162e+00] [0.001, 0.0021544346900318843, 0.1, 0.004641588833612777, 0.01, 0.046415888336127774, 0.021544346900318832] [1.1111120989948375e-07, 1.555557491150772e-07, 2.5253235478694958e-05, 2.666672355711164e-07, 4.555572158393417e-07, 8.104140008069471e-06, 2.2000387209786254e-06] [np.float64(1.0540929634229743e-07), np.float64(1.2472198078826607e-07), np.float64(3.1590391519827645e-06), np.float64(1.6329946860284078e-07), np.float64(2.1343781490330266e-07), np.float64(9.884043877765372e-07), np.float64(4.690451876747326e-07)]
# Surface 121 1 11 [8.21383360e-02 3.57651654e+00 7.52403644e-04 3.78291132e+00] [0.01, 0.0021544346900318843, 0.021544346900318832, 0.1, 0.004641588833612777, 0.001, 0.046415888336127774] [4.5454566111047257e-08, 9.090909913744838e-09, 3.7272866199034027e-07, 1.633225790498294e-05, 9.090909913744838e-09, 1.8181821492824213e-08, 3.20919389634744e-06] [np.float64(6.742000003332073e-08), np.float64(3.015113568524442e-08), np.float64(1.9306178365064507e-07), np.float64(2.2666554390506886e-06), np.float64(3.015113568524442e-08), np.float64(4.2640146765982856e-08), np.float64(5.664965663993009e-07)]
# Skipping Tile 288 8 12 [] []
# Skipping Tile 288 8 14 [] []
# Skipping Tile 288 18 13 [] []
# Skipping Tile 512 18 19 [] []
# Skipping Simplex 98 18 4 [] []
# Skipping Simplex 450 32 8 [] []
# Skipping BB 72 12 6 [] []
# Skipping BB 144 12 12 [] []
# Skipping BB 288 12 18 [] []
# Skipping Radial 144 8 12 [] []
# Skipping Radial 198 8 14 [] []
# Skipping Radial 192 18 12 [] []
# Skipping Radial 256 18 16 [] []
# Skipping Radial 352 18 20 [] []

# %%
markers = ['o', 's', '^', 'v', '<', '>', 'p']
colordict = {
    'Surface':'C0',
    'BB':'C5',
    'Radial':'C2',
    'Simplex':'C3',
    'Tile':'C1',
    # 'Hypercube':'C0'
}

fig,ax = plt.subplots()
# xs_test = np.geomspace(5e-4, 1e-3, 10)
# xs_test_surface = np.geomspace(5e-4, 4e-3, 10)
xs_test = np.geomspace(1e-4, 5e-1, 100)
xs_test_surface = np.geomspace(1e-4, 5e-1, 100)
for i,(fp,code_id) in enumerate(zip(fit_params, code_ids)):
    code_type,(n,k,d) = code_id
    print(fp)
    if code_type == 'Surface':
        plt.plot(xs_test_surface, logical_fit(xs_test_surface, *fp), 'k--', alpha=0.5, color=colordict[code_id[0]])
    else:
        plt.plot(xs_test, logical_fit(xs_test, *fp), 'k--', alpha=0.5, color=colordict[code_id[0]])
# sinter.plot_error_rate(
#     ax=ax,
#     stats=stats,
#     x_func=lambda s: s.json_metadata['p_sh'],
#     group_func=lambda s: f"{s.json_metadata['type']} [[{s.json_metadata['n']}, {s.json_metadata['k']}, {s.json_metadata['d']}]]",
#     failure_units_per_shot_func=lambda s: s.json_metadata['d'],
#     failure_values_func=lambda s: s.json_metadata['k'],
#     # highlight_max_likelihood_factor=None,
#     filter_func=lambda s: s.json_metadata['p_sh'] < p_upper_cutoffs.get((s.json_metadata['type'], (s.json_metadata['n'], s.json_metadata['k'], s.json_metadata['d'])), float('inf')),
# )



for i,code_id in enumerate(code_ids):
    # plt.errorbar(all_ps[i], all_lers[i], yerr=all_uncs[i])
    plt.plot(all_ps[i], all_lers[i], marker=markers[i % len(markers)], color=colordict[code_id[0]], linestyle='none')

# plt.plot(xs_test, logical_fit(xs_test, 0.5, 0.01, 0.2, 10))

plt.legend(bbox_to_anchor=(1,1), loc='upper left')
plt.loglog()
plt.xlim(1e-4)
plt.ylim(1e-10, top=1)
plt.xlabel('Shuttle error ' + r'$p_\text{sh}$')
plt.ylabel('Idling logical error rate')
ax.grid(which='both', linewidth=0.5)
plt.show()
# Out:
# [1.81012641e-03 8.95954800e+00 1.16338048e-02 8.08805705e-14]
# [5.27682065e-04 2.21978746e+00 9.30051306e-04 6.64087438e-02]
# [8.31754120e-04 1.66221408e+00 1.22966641e-03 1.07319868e+00]
# [2.91830310e-03 1.62102111e+00 1.53738739e-03 2.40673162e+00]
# [8.21383360e-02 3.57651654e+00 7.52403644e-04 3.78291132e+00]
# (nan, nan, nan, nan)
# (nan, nan, nan, nan)
# (nan, nan, nan, nan)
# (nan, nan, nan, nan)
# (nan, nan, nan, nan)
# (nan, nan, nan, nan)
# (nan, nan, nan, nan)
# (nan, nan, nan, nan)
# (nan, nan, nan, nan)
# (nan, nan, nan, nan)
# (nan, nan, nan, nan)
# (nan, nan, nan, nan)
# (nan, nan, nan, nan)
# (nan, nan, nan, nan)
# /tmp/ipykernel_2246809/1417914068.py:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(xs_test_surface, logical_fit(xs_test_surface, *fp), 'k--', alpha=0.5, color=colordict[code_id[0]])
# /tmp/ipykernel_2246809/1417914068.py:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(xs_test, logical_fit(xs_test, *fp), 'k--', alpha=0.5, color=colordict[code_id[0]])
# /tmp/ipykernel_2246809/1417914068.py:42: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor=(1,1), loc='upper left')

# %%
[s for s in stats if s.json_metadata['type'] == 'BB' and s.json_metadata['n'] == 288]
# Out:
# [sinter.TaskStats(strong_id='e578d5c54a76065df8400410951e5318ca81575c7339105a0a17474e5dc23708', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 18, 'type': 'BB'}, shots=10000, seconds=132759.1559999999),
#  sinter.TaskStats(strong_id='b14c33d2cb9e66f37b4943637092a34a6ad6574210013b4d6c036f83afc95118', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 18, 'type': 'BB'}, shots=10000, seconds=93514.70000000003),
#  sinter.TaskStats(strong_id='a01755cc181f8e710bd2186777a6d64fa9eaa4c9dfb3b67d06fc0acd9ed47755', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 18, 'type': 'BB'}, shots=20000, seconds=269714.41600000014),
#  sinter.TaskStats(strong_id='cfd8cfcd3e0bf67f406f71d0a3b5913da9043f5f197a801a4454bad7740ea58c', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 18, 'type': 'BB'}, shots=20000, errors=3, seconds=273795.81000000035),
#  sinter.TaskStats(strong_id='ccf480c3b8d4a7d8c7032e19b63d9a6fedea1fae51034f961004549337397d62', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 18, 'type': 'BB'}, shots=10000, errors=25, seconds=154030.4000000001),
#  sinter.TaskStats(strong_id='0d020711eaa88176277f32585d62f63c03aadf88f01bf309aae6babbe0b868fb', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 18, 'type': 'BB'}, shots=1995, errors=100, seconds=37498.3),
#  sinter.TaskStats(strong_id='017ee46c3e7f8d32ada488dbd25c5f89be9e957589e05ba13d3e56b66d3149fc', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 18, 'type': 'BB'}, shots=276, errors=100, seconds=6158.2),
#  sinter.TaskStats(strong_id='1316f9d8e301933c36407ca304e6d154b60e6dd90d40f2622c594f60a51b4fe2', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.003831186849557285, 'rounds': 18, 'type': 'BB'}, shots=20000, errors=5, seconds=249015.19000000035),
#  sinter.TaskStats(strong_id='82efafacd25c2915c8f2cb6047e8e1cfd8d3456207d9be544b4e3a6c32d9638b', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.0026101572156825357, 'rounds': 18, 'type': 'BB'}, shots=20000, seconds=240703.8669999997),
#  sinter.TaskStats(strong_id='74c36e9ae96a4f1ac2ecb72e5ba358940cf47146c8b8f27852529af9897f4c01', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.005623413251903491, 'rounds': 18, 'type': 'BB'}, shots=8943, errors=101, seconds=111258.61999999988)]

# %%
fit_params[code_ids.index(('BB', (288,12,18)))]
# Out:
# array([2.58429162e-01, 1.23584445e-02, 1.34462558e-01, 2.17245428e+01])

# %%
from adjustText import adjust_text

label_all = False
label_codes = [
    ('Simplex', (98,18,4)),
    ('BB', (72,12,6)),
    ('BB', (144,12,12)),
    ('BB', (288,12,18)),
    # ('Radial', (256,18,16)),
    ('Radial', (198,8,14)),
    # ('Radial', (144,8,12)),
    # ('Radial', (192,18,12)),
    # ('Tile', (288,8,14)),
    # ('Tile', (288,8,12)),
]

markerdict = {
    'Surface':'+',
    'BB':'^',
    'Radial':'o',
    'Simplex':'p',
    'Tile':'v',
    'Hypercube':'s',
}
colordict = {
    'Surface':'k',
    'BB':'C5',
    'Radial':'C2',
    'Simplex':'C3',
    'Tile':'C1',
    'Hypercube':'C0'
}

ps_display = [
    r'10^{-2}',
    r'3 \times 10^{-3}',
    r'10^{-3}',
]

skip = ['Hypercube']
# skip = []

fig,ax = plt.subplots(3,1,figsize=(4,10))
fig.subplots_adjust(hspace=0.2)
for j,p_tgt in enumerate([1e-2, 3e-3, 1e-3]):
    T2_tgt = 10**(-6-np.log10(p_tgt))
    p_sh_tgt = p_tgt

    points = [(np.nan, np.nan) for _ in code_ids]
    texts = []
    for i,(code_type, (n,k,d)) in enumerate(code_ids):
        if code_type in skip:
            continue
        if np.all(np.isfinite(fit_params[i])):
            ler_proj = logical_fit(p_tgt, *fit_params[i])
            enc_rate = k / n
            points[i] = (enc_rate*1000, ler_proj)
            ax[j].plot(*points[i], marker=markerdict[code_type], color=colordict[code_type], markeredgecolor=plotter.interpolate(colordict[code_type], 'k', 0.2))
            if label_all or (code_type, (n,k,d)) in label_codes:
                texts.append(ax[j].text(*points[i], f'[[{n}, {k}, {d}]]', fontsize=9, ha='left', va='top'))
            print(code_type, (n,k,d), points[i])
    xs_surface = []
    ys_surface = []
    for d in ds_surface:
        pt = points[code_ids.index(('Surface', (d**2,1,d)))]
        xs_surface.append(pt[0])
        ys_surface.append(pt[1])
    ax[j].plot(xs_surface, ys_surface, 'C0--', alpha=0.5, zorder=0.2)
    ax[j].set_yscale('log')

    ax[j].set_xlim(0, 250)
    ax[j].set_ylim(top=1)
    xlim = ax[j].get_xlim()
    ylim = ax[j].get_ylim()

    xs_surface = np.array([-10] + xs_surface + [1000])
    ys_surface = np.array([1e-30] + ys_surface + [1e-3])
    sort_idx = np.argsort(xs_surface)
    ax[j].fill_between(xs_surface[sort_idx], ys_surface[sort_idx], [1]*len(ys_surface), color='#BBBBBB', zorder=0, alpha=0.5)

    ax[j].set_xlim(*xlim)
    ax[j].set_ylim(*ylim)

    for (code_type, marker) in markerdict.items():
        if code_type in skip:
            continue
        ax[j].plot([], [], color=colordict[code_type], marker=marker, linestyle='none', markeredgecolor=plotter.interpolate(colordict[code_type], 'k', 0.2), label=code_type)
    if j == 1:
        ax[j].legend(bbox_to_anchor=(0.8,0.2), loc='center')

    
    ax[j].set_title(r'$p_\text{sh}=' + ps_display[j] + r'$')
    if j == 2:
        ax[j].set_xlabel('# logical qubits per 1000 physical qubits')
    else:
        ax[j].set_xticklabels([])
    ax[j].set_ylabel('Logical error rate')
    # ax[j].ylim(1e-18, 1e-2)
    ax[j].set_yticks(ax[j].get_yticks(), minor=[])
    adjust_text(
        texts,
        arrowprops=dict(arrowstyle='->', color='gray'),
        # force_text=(1, 1),
        force_static=(1, 1),
        expand=(1.2, 3),
        prevent_crossings=True,
        add_objects=ax[j].collections,
        ax=ax[j],
    )
    ax[j].grid(which='both', linewidth=0.5, zorder=0.1)
    ax[j].tick_params(direction='in', which='both')
    ax[j].set_ylim(top=1)
plt.savefig('notebooks/fig/10_encoding_rate.pdf', bbox_inches='tight')
plt.savefig('notebooks/fig/10_encoding_rate.svg', bbox_inches='tight')
plt.show()
# Out:
# Surface (9, 1, 3) (111.1111111111111, np.float64(0.00040452522562385514))
# Surface (25, 1, 5) (40.0, np.float64(5.881769305288927e-05))
# Surface (49, 1, 7) (20.408163265306122, np.float64(7.85821616597271e-06))
# Surface (81, 1, 9) (12.345679012345679, np.float64(1.0885963497063923e-06))
# Surface (121, 1, 11) (8.264462809917356, np.float64(1.6536765503870294e-07))
# Tile (288, 8, 12) (27.777777777777775, np.float64(2.9126908594681313e-05))
# Tile (288, 8, 14) (27.777777777777775, np.float64(0.0008412949623265401))
# Tile (288, 18, 13) (62.5, np.float64(0.004393551819843667))
# Tile (512, 18, 19) (35.15625, np.float64(0.007916385931771594))
# Simplex (98, 18, 4) (183.67346938775512, np.float64(0.006462442668163874))
# Simplex (450, 32, 8) (71.11111111111111, np.float64(0.0026312250868523817))
# BB (72, 12, 6) (166.66666666666666, np.float64(0.0011439761498778062))
# BB (144, 12, 12) (83.33333333333333, np.float64(0.0028949100747780905))
# BB (288, 12, 18) (41.666666666666664, np.float64(0.13366277724147552))
# Radial (144, 8, 12) (55.55555555555555, np.float64(0.0010417988530023329))
# Radial (198, 8, 14) (40.40404040404041, np.float64(0.10403756238662645))
# Radial (192, 18, 12) (93.75, np.float64(0.040523312614722716))
# Radial (256, 18, 16) (70.3125, np.float64(0.44560610647402576))
# Radial (352, 18, 20) (51.13636363636364, np.float64(435.2200124733139))
# Surface (9, 1, 3) (111.1111111111111, np.float64(0.00026100394797996123))
# Surface (25, 1, 5) (40.0, np.float64(2.868384511660769e-05))
# Surface (49, 1, 7) (20.408163265306122, np.float64(2.6277153354840557e-06))
# Surface (81, 1, 9) (12.345679012345679, np.float64(2.266685187247589e-07))
# Surface (121, 1, 11) (8.264462809917356, np.float64(2.3705410660853257e-08))
# Tile (288, 8, 12) (27.777777777777775, np.float64(8.083850451703525e-06))
# Tile (288, 8, 14) (27.777777777777775, np.float64(6.663551696669883e-05))
# Tile (288, 18, 13) (62.5, np.float64(0.00011799564573911762))
# Tile (512, 18, 19) (35.15625, np.float64(1.9899331938290538e-05))
# Simplex (98, 18, 4) (183.67346938775512, np.float64(0.0035331171034689466))
# Simplex (450, 32, 8) (71.11111111111111, np.float64(5.42561396705102e-05))
# BB (72, 12, 6) (166.66666666666666, np.float64(0.00038795864602166914))
# BB (144, 12, 12) (83.33333333333333, np.float64(1.658747218687066e-05))
# BB (288, 12, 18) (41.666666666666664, np.float64(3.993789900582511e-06))
# Radial (144, 8, 12) (55.55555555555555, np.float64(1.2709836374205272e-05))
# Radial (198, 8, 14) (40.40404040404041, np.float64(8.41253813539608e-07))
# Radial (192, 18, 12) (93.75, np.float64(0.0004401635911940942))
# Radial (256, 18, 16) (70.3125, np.float64(0.0002766200127401806))
# Radial (352, 18, 20) (51.13636363636364, np.float64(0.00028482050588176446))
# Surface (9, 1, 3) (111.1111111111111, np.float64(0.00022483438168863763))
# Surface (25, 1, 5) (40.0, np.float64(2.2105330419124833e-05))
# Surface (49, 1, 7) (20.408163265306122, np.float64(1.7417283114690933e-06))
# Surface (81, 1, 9) (12.345679012345679, np.float64(1.2269702825906254e-07))
# Surface (121, 1, 11) (8.264462809917356, np.float64(1.1128651582055474e-08))
# Tile (288, 8, 12) (27.777777777777775, np.float64(5.6046860005412125e-06))
# Tile (288, 8, 14) (27.777777777777775, np.float64(3.228505344011193e-05))
# Tile (288, 18, 13) (62.5, np.float64(4.197245578068246e-05))
# Tile (512, 18, 19) (35.15625, np.float64(3.597237423383798e-06))
# Simplex (98, 18, 4) (183.67346938775512, np.float64(0.002972988415665413))
# Simplex (450, 32, 8) (71.11111111111111, np.float64(1.7723757696758203e-05))
# BB (72, 12, 6) (166.66666666666666, np.float64(0.0002848320800398593))
# BB (144, 12, 12) (83.33333333333333, np.float64(1.4331743354273695e-06))
# BB (288, 12, 18) (41.666666666666664, np.float64(6.855111988897846e-09))
# Radial (144, 8, 12) (55.55555555555555, np.float64(3.608383987742996e-06))
# Radial (198, 8, 14) (40.40404040404041, np.float64(2.9474257940888753e-08))
# Radial (192, 18, 12) (93.75, np.float64(0.000120819009794999))
# Radial (256, 18, 16) (70.3125, np.float64(3.352850670451802e-05))
# Radial (352, 18, 20) (51.13636363636364, np.float64(8.972953072240747e-07))

# %%
from adjustText import adjust_text

label_all = False

ps_display = [
    r'10^{-2}',
    r'3 \times 10^{-3}',
    r'10^{-3}',
]

for j,p_tgt in enumerate([1e-2, 3e-3, 1e-3]):
    fig,ax = plt.subplots(figsize=(4,3))
    T2_tgt = 10**(-6-np.log10(p_tgt))
    p_sh_tgt = p_tgt

    points = [(np.nan, np.nan) for _ in code_ids]
    texts = []
    for i,(code_type, (n,k,d)) in enumerate(code_ids):
        if code_type in skip:
            continue
        if np.all(np.isfinite(fit_params[i])):
            ler_proj = logical_fit(p_tgt, *fit_params[i])
            enc_rate = k / n
            points[i] = (enc_rate*1000, ler_proj)
            ax.plot(*points[i], marker=markerdict[code_type], color=colordict[code_type], markeredgecolor=plotter.interpolate(colordict[code_type], 'k', 0.2))
            if label_all or (code_type, (n,k,d)) in label_codes:
                texts.append(ax.text(*points[i], f'[[{n}, {k}, {d}]]', fontsize=9, ha='left', va='top'))
    xs_surface = []
    ys_surface = []
    for d in ds_surface:
        pt = points[code_ids.index(('Surface', (d**2,1,d)))]
        xs_surface.append(pt[0])
        ys_surface.append(pt[1])
    ax.plot(xs_surface, ys_surface, 'C0--', alpha=1, zorder=0.2, linewidth=2)
    ax.set_yscale('log')

    ax.set_xlim(0, 250)
    ax.set_ylim(top=1)
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()

    xs_surface = np.array([-10] + xs_surface + [1000])
    ys_surface = np.array([1e-30] + ys_surface + [1])
    sort_idx = np.argsort(xs_surface)
    ax.fill_between(xs_surface[sort_idx], ys_surface[sort_idx], [1]*len(ys_surface), color='#BBBBBB', zorder=0, alpha=0.5)

    ax.set_xlim(*xlim)
    ax.set_ylim(*ylim)

    for (code_type, marker) in markerdict.items():
        if code_type in skip:
            continue
        ax.plot([], [], color=colordict[code_type], marker=marker, linestyle='none', markeredgecolor=plotter.interpolate(colordict[code_type], 'k', 0.2), label=code_type)

    ax.legend(bbox_to_anchor=(1,0.5), loc='center left')
    
    # ax.set_title(r'$(p,T_2,p_\text{sh})=(' + ps_display[j] + f', {T2_tgt*1e3:.2g}ms, ' + ps_display[j] + r')$')
    ax.set_title(r'$p_\text{gate} = 10^{-3}, p_\text{sh}=' + ps_display[j] + r'$')
    ax.set_xlabel('# logical qubits per 1000 physical qubits')

    ax.set_ylabel('Logical error rate')
    # ax.ylim(1e-18, 1e-2)
    ax.set_yticks(ax.get_yticks(), minor=[])
    adjust_text(
        texts,
        arrowprops=dict(arrowstyle='->', color='gray'),
        # force_text=(1, 1),
        force_static=(1, 3),
        expand=(1.2, 4),
        prevent_crossings=True,
        add_objects=ax.collections,
        ax=ax,
    )
    ax.grid(which='both', linewidth=0.5, zorder=0.1)
    ax.tick_params(direction='in', which='both')
    ax.set_ylim(top=1)
    plt.savefig(f'notebooks/fig/10_encoding_rate_{j}.pdf', bbox_inches='tight')
    plt.savefig(f'notebooks/fig/10_encoding_rate_{j}.png', dpi=300, bbox_inches='tight')
    # plt.savefig('notebooks/fig/10_encoding_rate.svg', bbox_inches='tight')
    plt.show()

# %%
from scipy.interpolate import interp1d

# Define the range of physical error rates to plot
ps_eval = np.geomspace(1e-4, 1e-2, 50)

fig, ax = plt.subplots(figsize=(4,3))

# Extract surface code fit parameters
surface_data = []
for d in ds_surface:
    idx = code_ids.index(('Surface', (d**2, 1, d)))
    fp = fit_params[idx]
    surface_data.append((1 / (d**2), fp))

markerlist = [
    '<',
    '>',
    '^',
    'o',
    'p',
    'v',
    's',
    'd',
]

linestyles = ['-', '--', '-.', ':']
type_counts = dict()

def get_equiv_sc_ler(p, encoding_rate):
    # 1. Evaluate surface code LERs at this specific physical error rate (p)
    sc_rates = []
    sc_lers = []
    for sc_rate, sc_fp in surface_data:
        sc_rates.append(sc_rate)
        sc_lers.append(logical_fit(p, *sc_fp))
        
    # Append the bare physical qubit representing an encoding rate of 1
    sc_rates.append(1.0)
    sc_lers.append(1e-3)
    
    # Sort values to ensure interp1d works correctly
    sort_idx = np.argsort(sc_rates)
    sc_rates = np.array(sc_rates)[sort_idx]
    sc_lers = np.array(sc_lers)[sort_idx]
    
    # 2. Create interpolation function in log-log space
    interp_func = interp1d(
        np.log10(sc_rates), 
        np.log10(sc_lers), 
        kind='linear',
        bounds_error=False, 
        fill_value='extrapolate' # Handles codes with k/n < 1/121
    )
    
    # 3. Find the Equivalent Surface Code LER
    equiv_sc_ler = 10**(interp_func(np.log10(encoding_rate)))
    return equiv_sc_ler

# Calculate and plot the improvement factor for each non-Surface code
for i, (code_type, (n, k, d)) in enumerate(code_ids):
    if code_type == 'Surface' or code_type in skip:
        continue
    
    fp_code = fit_params[i]
    if not np.all(np.isfinite(fp_code)):
        continue

    encoding_rate = k / n
    improvements = []

    for p in ps_eval:
        # 4. Find the actual code LER and calculate the ratio (Speedup)
        code_ler = logical_fit(p, *fp_code)
        improvement = get_equiv_sc_ler(p, encoding_rate) / code_ler
        improvements.append(improvement)

    # Plot the results
    ax.plot(
        ps_eval, 
        improvements, 
        label=f'{code_type} [[{n}, {k}, {d}]]',
        color=colordict.get(code_type, 'k'),
        # marker=markerlist[type_counts.get(code_type, 0)],
        # markevery=5, # Spacing out markers so they don't clutter the line
        linestyle=linestyles[i % len(linestyles)],
        markeredgecolor=plotter.interpolate(colordict.get(code_type, 'k'), 'k', 0.2)
    )
    # texts.append(ax.text(ps_eval[0], improvements[0], f'[[{n}, {k}, {d}]]', fontsize=9, ha='right', va='center'))
    type_counts[code_type] = type_counts.get(code_type, 0) + 1

    # for p,ler in zip(all_ps[i], all_lers[i]):
    #     ax.plot(p, get_equiv_sc_ler(p, encoding_rate) / ler, marker=markerlist[i % len(markerlist)], color=colordict[code_type])

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'Physical error rate ($p_{\text{sh}}$)')
ax.set_ylabel(r'$p_L$ improvement factor')
# ax.set_xlim(1e-5)

# Add a baseline indicating "no improvement" over surface codes
ax.axhline(1, color='k', linestyle='-', alpha=0.5)

ax.legend(bbox_to_anchor=(1.05, 0.4), loc='center left')
ax.grid(which='both', linewidth=0.5, zorder=0.1)
ax.tick_params(direction='in', which='both')

# adjust_text(
#     texts,
#     arrowprops=dict(arrowstyle='->', color='gray'),
#     # force_text=(1, 1),
#     # force_static=(1, 3),
#     # expand=(1.2, 4),
#     # prevent_crossings=True,
#     # add_objects=ax.collections,
#     ax=ax,
# )

# plt.title('Relative LER Improvement vs Equivalent Surface Code')
plt.savefig('notebooks/fig/10_improvement_factor.pdf', bbox_inches='tight')
plt.show()
