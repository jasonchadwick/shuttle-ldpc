# %%
import os
try:
    path_initialized
except NameError:
    path_initialized = True
    os.chdir('..')

import numpy as np
from sympy.abc import x, y

# from qldpc import codes
import networkx as nx
import matplotlib.pyplot as plt
import stim
import pickle
import sinter
from copy import deepcopy
import scipy

import src.device as device
import src.plotting as plotter
import src.stim_dag as stim_dag

from src.RotatedSurfaceCode import RotatedSurfaceCode
from src.TileCode import TileCode
from src.HGPCode import HGPCode
from src.SHYPSCode import SHYPSCode
from src.RadialCode import RadialCode
from src.GBCode import GBCode
from src.HypercubeCode import HypercubeCode
from src.decoders import BPOSD
from src.constructor import construct_code

# %%
compile_tasks = False
if compile_tasks:
    # Making codes
    codes = []
    code_types = []
    code_nkds = []
    code_data_coodes = []

    ds_surface = [3, 5, 7, 9, 11]
    for d in ds_surface:
        code = RotatedSurfaceCode(d)
        codes.append(code)
        code_types.append('Surface')
        code_nkds.append(code.compute_code_parameters())

    nkds_tile = [(288,8,12), (288, 8, 14), (288, 18, 13), (512, 18, 19)]
    for nkd in nkds_tile:
        code = TileCode.known_code(*nkd)
        codes.append(code)
        code_types.append('Tile')
        code_nkds.append(nkd)

    rs_simplex = [3,4]
    for r in rs_simplex:
        code = HGPCode.simplex_code(r)
        codes.append(code)
        code_types.append('Simplex')
        code_nkds.append(code.compute_code_parameters())

    # rs_cube = [2,3]
    # for r in rs_cube:
    #     code = HypercubeCode(r)
    #     codes.append(code)
    #     code_types.append('Hypercube')
    #     code_nkds.append(code.compute_code_parameters())

    lms = [
        (6,6),
        (12,6),
        (12,12),
    ]
    orders = [
        (([3], [1,2]), ([1, 2], [3])),
        (([3], [1, 2]), ([1, 2], [3])),
        (([3], [2, 7]), ([1, 2], [3])),
    ]
    nkds = [
        (72, 12, 6),
        (144, 12, 12),
        (288, 12, 18),
    ]
    for (l,m),(a_ord,b_ord) in zip(lms, orders):
        code = GBCode(l, m, a_ord, b_ord)
        codes.append(code)
        code_types.append('BB')

    code_nkds += nkds

    rsds_radial = [(3,8,12), (3,11,14), (4,6,12), (4,8,16), (4,11,20)]
    for r,s,d in rsds_radial:
        code = RadialCode(r,s,d)
        codes.append(code)
        code_types.append('Radial')
        code_nkds.append(code.compute_code_parameters())

    for code in codes:
        assert len(code.qubit_coords) > 0, code

    code_ids = list(zip(code_types, code_nkds))
else:
    ds_surface = [3, 5, 7, 9, 11]

# %%
if compile_tasks:
    hwp = device.default_hwp
    ps_surface = np.geomspace(1e-3, 1e-1, 7)
    # ps_other = np.geomspace(1e-3, 1.5e-3, 5)
    ps_other = np.geomspace(1e-3, 1e-2, 7)
    p_g = 1e-3
    T2 = 10e-3
    # p = 1e-3
    # t2 = 1e-3
    # p_sh = 1e-3
    # error_params = device.error_params(p=p, T2=t2, p_sh=p_sh)
    buffer = 3
    basis = 'X'
    schedules = dict()
    tasks = []
    for code, code_type, (n,k,d) in zip(codes, code_types, code_nkds):
        print(code_type, f'[[{n}, {k}, {d}]]...')
        xmax,ymax = 0,0
        data_coords = dict()
        for i in code.data_indices:
            x,y = code.qubit_coords[i]
            data_coords[i] = (x+buffer, y+buffer)
            xmax = max(xmax, x)
            ymax = max(ymax, y)
        dev = device.UnitCellDevice(xmax+2*buffer, ymax+2*buffer, hwp)
        
        rounds = d

        if code_type == 'Surface':
            sched = code.get_schedule(hwp, 'Z', rounds=rounds, refocus_shuttling_noise=True)
        else:
            sched = dev.compile_QEC_schedule(
                code,
                data_coords,
                code.check_cx_layers,
                rounds=rounds,
                use_highways=False,
                refocus_shuttle_noise=True,
                separate_X_Z=code_type != 'Surface',
            )
        schedules[(code_type, (n,k,d))] = sched
        
        for p_sh in (ps_surface if code_type == 'Surface' else ps_other):
            # p = p
            # T2 = 10**(-6-np.log10(p))
            error_params = device.error_params(p=p_g, T2=T2, p_sh=p_sh)
            circ = sched.to_stim_circuit(code, basis, error_params, XYZ_decode=False)
            try:
                circ.detector_error_model()
            except Exception as e:
                print('FAIL', e)

            decoder='pymatching' if code_type == 'Surface' else 'bposd'
            tasks.append(sinter.Task(
                circuit=circ,
                decoder=decoder,
                json_metadata={'n':n, 'k':k, 'd':d, 'type':code_type, 'rounds':rounds, 'basis':basis, 'decoder':decoder, 'p_g':p_g, 'T2':T2, 'p_sh':p_sh},
            ))
    with open('notebooks/data/10_tasks.pkl', 'wb') as f:
        pickle.dump({
            'tasks':tasks,
        }, f)
    with open('notebooks/data/10_params.pkl', 'wb') as f:
        pickle.dump({
            'code_types':code_types,
            'code_nkds':code_nkds,
            'code_data_coodes':code_data_coodes,
            'ps_surface': ps_surface,
            'ps_other': ps_other,
            'schedules':schedules,
        }, f)
else:
    try:
        with open('notebooks/data/10_tasks.pkl', 'rb') as f:
            data = pickle.load(f)
            tasks = data['tasks']
    except FileNotFoundError:
        print('Could not find task file. Setting tasks=None.')
        tasks = None
    with open('notebooks/data/10_params.pkl', 'rb') as f:
        data = pickle.load(f)
        code_types = data['code_types']
        code_nkds = data['code_nkds']
        code_data_coodes = data['code_data_coodes']
        ps_surface = data['ps_surface']
        ps_other = data['ps_other']
        schedules = data['schedules']

# %%
code_ids = list(zip(code_types, code_nkds))

# %%
# stats = sinter.read_stats_from_csv_files('notebooks/data/10_results_TMP')
with open('notebooks/data/10_results.pkl', 'rb') as f:
    stats = pickle.load(f)

# %%
stats
# Out:
# [sinter.TaskStats(strong_id='401f73b70d04a170a1ef47c5b8e2ae9ba34baa02178c60714beb43ccb1657514', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 3, 'type': 'Surface'}, shots=390417, errors=500, seconds=0.14899999999999997),
#  sinter.TaskStats(strong_id='36b0e9c4dfbba579713f75c7e50700b5a0ab10c4ac9943c100d67f6f9e642661', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 3, 'type': 'Surface'}, shots=589073, errors=501, seconds=0.192),
#  sinter.TaskStats(strong_id='6f69cdce5edde9b745057ab87bc56cd9ffaa309e3f67fe68efdc2ab3d2a1e58d', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 3, 'type': 'Surface'}, shots=921122, errors=637, seconds=0.24000000000000002),
#  sinter.TaskStats(strong_id='ffa2213e8dd24952e490bcc743180401937de2a3e279d137f2b2547106c873a3', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 3, 'type': 'Surface'}, shots=878114, errors=628, seconds=0.253),
#  sinter.TaskStats(strong_id='047b6658b9851f897d0454e904a8c722f3af52e7ae0e8df6d8229cfdbd88a254', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 5, 'type': 'Surface'}, shots=1816098, errors=532, seconds=5.753000000000001),
#  sinter.TaskStats(strong_id='9e1c7c974b5df0993ef0b00d878f9775dc06b8af23bbd9f84d860a431acb1a2b', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.001, 'p_sh': 0.1, 'rounds': 5, 'type': 'Surface'}, shots=80418, errors=613, seconds=1.9529999999999998),
#  sinter.TaskStats(strong_id='39f4fd209319b0c8804b5d7f9059d8c033644b39e6a7f5e383bbc18c5f76128e', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.001, 'p_sh': 0.046415888336127774, 'rounds': 7, 'type': 'Surface'}, shots=635426, errors=575, seconds=18.890000000000004),
#  sinter.TaskStats(strong_id='4109b58203e8bb1ac1bc3726133a23a26b8ebedac030de43a6ca5c4daf5d6e02', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 9, 'type': 'Surface'}, shots=10000000, errors=97, seconds=175.344),
#  sinter.TaskStats(strong_id='cc8dea640abe6b67818627f1001f0fe2e7bf3d120469390ace0066520fed16dc', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.001, 'p_sh': 0.046415888336127774, 'rounds': 5, 'type': 'Surface'}, shots=306722, errors=604, seconds=3.7839999999999994),
#  sinter.TaskStats(strong_id='1d5e1f89f4c640c318e3e42f036452a2c626c259e7da9d5b704459f310a737a3', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.001, 'p_sh': 0.1, 'rounds': 7, 'type': 'Surface'}, shots=94754, errors=516, seconds=5.662),
#  sinter.TaskStats(strong_id='00f0b8c7e2d8cbebaa823b8acfeacc50c61854bff985d2736000537501386236', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.001, 'p_sh': 0.021544346900318832, 'rounds': 7, 'type': 'Surface'}, shots=3362611, errors=598, seconds=46.668),
#  sinter.TaskStats(strong_id='35deb35c428fadabea857350026e3b160389bbf98a76192ad39f10a03e64a297', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.001, 'p_sh': 0.046415888336127774, 'rounds': 9, 'type': 'Surface'}, shots=1402470, errors=604, seconds=109.85500000000002),
#  sinter.TaskStats(strong_id='a8265bac7c6818376a3b514bc497159f974bfe2916c78019c9c55e0b2896bba1', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 7, 'type': 'Surface'}, shots=10000000, errors=147, seconds=31.695000000000004),
#  sinter.TaskStats(strong_id='7d8f6d3319661bdd44675c1f3736a356f66e135bb471cd45ea3ed4722642317d', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.001, 'p_sh': 0.1, 'rounds': 11, 'type': 'Surface'}, shots=166706, errors=622, seconds=57.71800000000002),
#  sinter.TaskStats(strong_id='523ddf6e1bbc1256408fab11265901128dec4a0ab3933e1a332873f3b80bc1a0', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 5, 'type': 'Surface'}, shots=4465186, errors=568, seconds=5.625000000000001),
#  sinter.TaskStats(strong_id='692cb7205c74501a6d2910e2c12fc77fa8a8e4aca8b65b368ce4e746ef5bb2ac', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.001, 'p_sh': 0.021544346900318832, 'rounds': 9, 'type': 'Surface'}, shots=10000000, errors=483, seconds=326.7279999999995),
#  sinter.TaskStats(strong_id='cbcd5fff71d8afa8612611c9bf62f23e58f80c91b321a144d345f3f301cb1aff', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.001, 'p_sh': 0.1, 'rounds': 9, 'type': 'Surface'}, shots=122402, errors=528, seconds=22.267999999999994),
#  sinter.TaskStats(strong_id='03b5a3174be26867e7ec2fe4a74b6f8922660d128817c3df1cc73b7f94aec8eb', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 7, 'type': 'Surface'}, shots=9600688, errors=532, seconds=71.14200000000002),
#  sinter.TaskStats(strong_id='a772d00f265aef15358da633b09933a05d296e11b0aaaca1801bb89129cc96d6', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 7, 'type': 'Surface'}, shots=10000000, errors=127, seconds=27.465999999999998),
#  sinter.TaskStats(strong_id='5931ce3757d26177455f721178385e780e01c2fd245101d15da456b831568089', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 5, 'type': 'Surface'}, shots=3101218, errors=575, seconds=5.682),
#  sinter.TaskStats(strong_id='424ae49fdd4be0a2ac0a6bd060c3dba75ae33bdca44f68c806cf3ce581857daa', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 5, 'type': 'Surface'}, shots=5305890, errors=569, seconds=5.545000000000001),
#  sinter.TaskStats(strong_id='f72ee474390d1c2e9c504ae86d6038302f95c01a561fa84c8407eca0c5ff540f', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 9, 'type': 'Surface'}, shots=10000000, errors=15, seconds=57.35299999999999),
#  sinter.TaskStats(strong_id='698091cc62c1c3c2e86c7d4d6683a5160c701f87e1a6751c2a810cd95ee18369', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.001, 'p_sh': 0.1, 'rounds': 3, 'type': 'Surface'}, shots=41233, errors=508, seconds=0.14400000000000002),
#  sinter.TaskStats(strong_id='44c2499293f546e21044a10f3a215a39197927a58d5659c894d2bb4d89a004cd', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 7, 'type': 'Surface'}, shots=10000000, errors=252, seconds=40.90599999999999),
#  sinter.TaskStats(strong_id='c7fadfecc6af29404ce5b111658b67ea7455044810123678779bea104b581ca0', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.001, 'p_sh': 0.046415888336127774, 'rounds': 3, 'type': 'Surface'}, shots=136738, errors=621, seconds=0.256),
#  sinter.TaskStats(strong_id='fd9246702d8b6cc546131d09517b13dae649649d1e40f87c06bed12cfd9e32b1', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 9, 'type': 'Surface'}, shots=10000000, errors=36, seconds=89.92),
#  sinter.TaskStats(strong_id='d8b99aceb49690254312b76ead363a039ab14fcd523cbf1f9ab647dfb00c3ec5', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 9, 'type': 'Surface'}, shots=10000000, errors=12, seconds=46.17500000000001),
#  sinter.TaskStats(strong_id='3bba07311d9be8c54b2a53cc6a52e42b071b76cb449f29e6c7f6127cec60db25', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.001, 'p_sh': 0.021544346900318832, 'rounds': 5, 'type': 'Surface'}, shots=901666, errors=595, seconds=5.318999999999999),
#  sinter.TaskStats(strong_id='29c906655bf8a507a5ed3c414b20e49d9cb1132a3aa7662d3005dd41702554d3', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.001, 'p_sh': 0.021544346900318832, 'rounds': 11, 'type': 'Surface'}, shots=10000000, errors=136, seconds=589.0789999999998),
#  sinter.TaskStats(strong_id='3def39c9ade7f43e831df792745bb70b18e6bb66a8796ec339ed2a1ecb43bdcf', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.001, 'p_sh': 0.021544346900318832, 'rounds': 3, 'type': 'Surface'}, shots=317986, errors=652, seconds=0.305),
#  sinter.TaskStats(strong_id='7e8a435f420fe62d7b31ddedeeb15af4712b91e52668552c30adb141aab081cd', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 11, 'type': 'Surface'}, shots=10000000, errors=1, seconds=101.63700000000004),
#  sinter.TaskStats(strong_id='831fb77a1345d7e9ccea3d9e5b83820f488dcb60e548f5f33d4e3a2131d6e269', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 11, 'type': 'Surface'}, shots=10000000, errors=17, seconds=332.1109999999995),
#  sinter.TaskStats(strong_id='29c724433aed67fdb286368870562dc3764d92829e58d8bab4bd0cf8bcc05646', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 11, 'type': 'Surface'}, shots=10000000, errors=6, seconds=192.31200000000004),
#  sinter.TaskStats(strong_id='b2e637f5d338de45be5c6d91cc2f1a925d06ec85034259fd5b457f595b7a3420', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 11, 'type': 'Surface'}, shots=10000000, errors=2, seconds=100.36700000000003),
#  sinter.TaskStats(strong_id='2f2fcdb7ca693d34ea214eaac0f7ca87cff63e83e37fe8bb76757def37606700', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.001, 'p_sh': 0.046415888336127774, 'rounds': 11, 'type': 'Surface'}, shots=2909524, errors=560, seconds=449.30500000000035),
#  sinter.TaskStats(strong_id='ec4a2f5d0949c120e004630918942234d512cb45e5878bba65f4120081f241e8', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 12, 'type': 'Tile'}, shots=10000, seconds=14328.686000000003),
#  sinter.TaskStats(strong_id='ef70991308b94fc3b9431faeba935ed864811836c1ba6100c5eb5afa2ae86869', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 4, 'decoder': 'bposd', 'k': 18, 'n': 98, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 4, 'type': 'Simplex'}, shots=38737, errors=500, seconds=632.115),
#  sinter.TaskStats(strong_id='a70f2e310f279a7bd95bacf010d893e1e33a6d4605d66ae6d73405d9777d5905', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 4, 'decoder': 'bposd', 'k': 18, 'n': 98, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 4, 'type': 'Simplex'}, shots=42161, errors=502, seconds=592.076),
#  sinter.TaskStats(strong_id='402c21998a1571b705af416cdab9d1a3e63f65d65993800a5abf794e2e5668f0', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 8, 'decoder': 'bposd', 'k': 32, 'n': 450, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 8, 'type': 'Simplex'}, shots=10000, errors=2, seconds=52242.56300000002),
#  sinter.TaskStats(strong_id='8e5cef754cb039764c6700611c8d075c02cedb4fce7aad0b4f85cb45d752cb02', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 4, 'decoder': 'bposd', 'k': 18, 'n': 98, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 4, 'type': 'Simplex'}, shots=28609, errors=502, seconds=544.021),
#  sinter.TaskStats(strong_id='6deb10d4da0e973ec8b44fb8d59555c5213c0058525d6b4b86b8655fe44d55bc', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 4, 'decoder': 'bposd', 'k': 18, 'n': 98, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 4, 'type': 'Simplex'}, shots=36497, errors=500, seconds=554.176),
#  sinter.TaskStats(strong_id='899ef6486358190187a082387315651dda1fb7d0cfb29af5e3fa1410ef1e545f', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 4, 'decoder': 'bposd', 'k': 18, 'n': 98, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 4, 'type': 'Simplex'}, shots=41297, errors=500, seconds=559.926),
#  sinter.TaskStats(strong_id='a34c90f9f2a0f71a931e054b22d0e9143a59171d5f1fa9cc51e0eea204fc5c2b', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 4, 'decoder': 'bposd', 'k': 18, 'n': 98, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 4, 'type': 'Simplex'}, shots=26113, errors=500, seconds=708.62),
#  sinter.TaskStats(strong_id='13765fd689814323f05f5c67a95e65d5e7834fb12771b432a3b5f8333387cba1', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 12, 'type': 'Tile'}, shots=10000, errors=1, seconds=14857.013999999997),
#  sinter.TaskStats(strong_id='9bb3db29b4a66577c36a6ecea37924b2e171ea682c7adf2516efdc5000b9fc4b', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 4, 'decoder': 'bposd', 'k': 18, 'n': 98, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 4, 'type': 'Simplex'}, shots=19633, errors=502, seconds=864.609),
#  sinter.TaskStats(strong_id='e207aa681659c79eae6807e48f5fdd6ef19d7cb867647199b91fc3e2006d0448', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 13, 'decoder': 'bposd', 'k': 18, 'n': 288, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 13, 'type': 'Tile'}, shots=10000, errors=27, seconds=16541.37),
#  sinter.TaskStats(strong_id='fd2eb7bec9c0b962368df2291bc3db74b4a226183789e8a185b565fcbdba3457', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 12, 'type': 'Tile'}, shots=10000, errors=1, seconds=15054.776000000002),
#  sinter.TaskStats(strong_id='d4f631c6a01a48591ce70708781f4d258d5b91296fe3b45b8fabb25d975ff189', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 12, 'type': 'Tile'}, shots=10000, errors=4, seconds=15324.7),
#  sinter.TaskStats(strong_id='c51e47a1eee7c78863cebbcf3ab9a5a0b8f8a4fd32120a167934cfba73370283', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 12, 'type': 'Tile'}, shots=10000, errors=1, seconds=13784.996000000001),
#  sinter.TaskStats(strong_id='33ea8c7d6e02e2e30163f7cd1ffb8bdab70bedc8ed18ec6e5c0049ebc1a10ad2', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 12, 'type': 'Tile'}, shots=10000, errors=1, seconds=14327.133000000003),
#  sinter.TaskStats(strong_id='a302f495104405037a39a70287295aaa08a28bd1d51a416211cdeec13f92a7f5', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 13, 'decoder': 'bposd', 'k': 18, 'n': 288, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 13, 'type': 'Tile'}, shots=1743, errors=100, seconds=3399.9200000000014),
#  sinter.TaskStats(strong_id='205230f0b8238e775dd831ca456d3f3edecfd55678e7fbc047083a477360770c', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 14, 'type': 'Tile'}, shots=10000, errors=6, seconds=44555.71200000004),
#  sinter.TaskStats(strong_id='1255bc8720d4c2fc9e139c72cafa81d77e486b0933d78065dc80ef7323b97852', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 13, 'decoder': 'bposd', 'k': 18, 'n': 288, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 13, 'type': 'Tile'}, shots=10000, errors=14, seconds=15517.699999999995),
#  sinter.TaskStats(strong_id='8b8e9186675c0f84c2d24e5f893158affb121eff041cabd8ab04b91a295190ea', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 13, 'decoder': 'bposd', 'k': 18, 'n': 288, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 13, 'type': 'Tile'}, shots=10000, errors=17, seconds=15947.320000000005),
#  sinter.TaskStats(strong_id='a229f17c47da6c1e6e21d54e0552ecdedb47c168bb84aabeac4f6fdffd7244ea', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 13, 'decoder': 'bposd', 'k': 18, 'n': 288, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 13, 'type': 'Tile'}, shots=9284, errors=100, seconds=15862.29),
#  sinter.TaskStats(strong_id='e878c74f474bb14a3c897d7ae07f1821f005a97271109892b91cbe20ea39b2ee', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 14, 'type': 'Tile'}, shots=10000, errors=11, seconds=46132.67999999997),
#  sinter.TaskStats(strong_id='58a73d47348d6af1888d4675d7d8c44d7188da5dc7d8bab015e715bb141e3a62', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 8, 'decoder': 'bposd', 'k': 32, 'n': 450, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 8, 'type': 'Simplex'}, shots=10000, seconds=58657.853999999956),
#  sinter.TaskStats(strong_id='3c098978c12d02d12f2c5e9af74b1d55ec1a0c83319e522a4aa8b0fe50d96f48', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 14, 'type': 'Tile'}, shots=10000, errors=2, seconds=45638.780000000006),
#  sinter.TaskStats(strong_id='99e94782050014aaa7a780ad89800414fc9a9cdd093fabb86d62f2fe1b3e2446', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 14, 'type': 'Tile'}, shots=10000, errors=8, seconds=46452.263000000006),
#  sinter.TaskStats(strong_id='ec0feeda04a4533849ef85c8348076aec5a0076fb85f8393889e66c6b37eed7a', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 13, 'decoder': 'bposd', 'k': 18, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 13, 'type': 'Tile'}, shots=10000, errors=7, seconds=30578.65000000001),
#  sinter.TaskStats(strong_id='e3126eb90ade82758a11529cf709c7a73b3f36b6007e72336408aab7c2a721d2', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 13, 'decoder': 'bposd', 'k': 18, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 13, 'type': 'Tile'}, shots=10000, errors=6, seconds=32953.09799999999),
#  sinter.TaskStats(strong_id='1279447e80516e2a1638c2e17dcb920d647ab3783a3fbd9b3266387dee38fa53', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 14, 'type': 'Tile'}, shots=10000, errors=34, seconds=51637.450000000004),
#  sinter.TaskStats(strong_id='b1ac9eb7fd8dad73f1e6a7c12a837536f9079f61821836ee048ce659df002d21', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 14, 'type': 'Tile'}, shots=8427, errors=100, seconds=47660.59199999997),
#  sinter.TaskStats(strong_id='87b0849b1c5489a0bb078f8e39861d955f12ad2bbcb9ba3b1975bd56645e1ee4', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 14, 'type': 'Tile'}, shots=10000, errors=17, seconds=51053.27199999993),
#  sinter.TaskStats(strong_id='4e6b4cc81d082c7223ce9a97c914f2c2d01103ebcaa02c9fcfd04a196651b5ab', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 8, 'decoder': 'bposd', 'k': 32, 'n': 450, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 8, 'type': 'Simplex'}, shots=10000, errors=2, seconds=51909.022999999994),
#  sinter.TaskStats(strong_id='35a4c61d820ff5f2c6a35e01fa3466d21ea3b22963fe882600a5a7b0745ee44b', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 8, 'decoder': 'bposd', 'k': 32, 'n': 450, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 8, 'type': 'Simplex'}, shots=10000, errors=10, seconds=71759.71999999994),
#  sinter.TaskStats(strong_id='88740c9e9462a488d66cfb2c3cf64a24ad9c9876681d2d229cd51f838aebf268', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 8, 'decoder': 'bposd', 'k': 32, 'n': 450, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 8, 'type': 'Simplex'}, shots=10000, errors=3, seconds=69163.21999999999),
#  sinter.TaskStats(strong_id='c1419b5306bc72daeaca28149aff27d724918668e56165ff53bd5000d60b3a0f', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 12, 'type': 'Tile'}, shots=10000, seconds=14368.830000000002),
#  sinter.TaskStats(strong_id='8b655f4a6a21680c173407384d95ae5944fa2fc854eb9fc6b7c9cfd650dd6917', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 19, 'decoder': 'bposd', 'k': 18, 'n': 512, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 19, 'type': 'Tile'}, shots=10000, errors=1, seconds=237893.20000000022),
#  sinter.TaskStats(strong_id='0a35dfa880658503fe03b309fe46f7b242c53ce02742bfaada93d6d578b3bb3b', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 19, 'decoder': 'bposd', 'k': 18, 'n': 512, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 19, 'type': 'Tile'}, shots=10000, errors=2, seconds=221334.5000000003),
#  sinter.TaskStats(strong_id='cbabc873974ec9791b82ac9796641e2aaf264c2227261b2b883c7cf597bfc743', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 19, 'decoder': 'bposd', 'k': 18, 'n': 512, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 19, 'type': 'Tile'}, shots=10000, errors=2, seconds=219978.4000000004),
#  sinter.TaskStats(strong_id='284b72649d25c8ac174f02e643c7a8bc7967807f626f336a805d2e5d95238730', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 19, 'decoder': 'bposd', 'k': 18, 'n': 512, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 19, 'type': 'Tile'}, shots=10000, errors=7, seconds=308541.9999999995),
#  sinter.TaskStats(strong_id='9523dc4dafc297754ebd9497215bfcc82c89b936e1480b44100756ff7fcd2f37', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 19, 'decoder': 'bposd', 'k': 18, 'n': 512, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 19, 'type': 'Tile'}, shots=10000, errors=84, seconds=323807.9000000006),
#  sinter.TaskStats(strong_id='c8cecf2e9e9bf8f539ddaf82512210895b09a78199343fd945f8b97458db9abd', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 19, 'decoder': 'bposd', 'k': 18, 'n': 512, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 19, 'type': 'Tile'}, shots=10000, errors=14, seconds=331760.70000000007),
#  sinter.TaskStats(strong_id='a87e021a5fdd946733df08a80e900a8dd767792820f7101da85f891a3c6466fb', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 19, 'decoder': 'bposd', 'k': 18, 'n': 512, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 19, 'type': 'Tile'}, shots=668, errors=100, seconds=29377.699999999993),
#  sinter.TaskStats(strong_id='76dfc40d9bae4061bd816db74cbe27ab221e8668edb83ca28fceafe91221e105', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 8, 'decoder': 'bposd', 'k': 32, 'n': 450, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 8, 'type': 'Simplex'}, shots=10000, errors=38, seconds=73289.37000000004),
#  sinter.TaskStats(strong_id='da9566b66644dc1f5746b875be8baceb4e4c0879097d28248ef16fca6da7c2c6', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 6, 'decoder': 'bposd', 'k': 12, 'n': 72, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 6, 'type': 'BB'}, shots=50000, errors=123, seconds=929.29),
#  sinter.TaskStats(strong_id='261c8daf9f4a3ef225953b7613d1ac12163406e4d12d44beec4ddf17eb598697', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 8, 'decoder': 'bposd', 'k': 32, 'n': 450, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 8, 'type': 'Simplex'}, shots=4824, errors=100, seconds=42136.73000000001),
#  sinter.TaskStats(strong_id='ba00bfb90652f91729ea44f4ff473e51b4d3257b063b67c7feadf40ec0398d06', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 6, 'decoder': 'bposd', 'k': 12, 'n': 72, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 6, 'type': 'BB'}, shots=50000, errors=88, seconds=875.845),
#  sinter.TaskStats(strong_id='2ac00fbc01b616b682411e51fa3132660c845e72a23adfa6276b10b52de2fa10', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 6, 'decoder': 'bposd', 'k': 12, 'n': 72, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 6, 'type': 'BB'}, shots=50000, errors=100, seconds=907.422),
#  sinter.TaskStats(strong_id='688e6374895fed9fab34d23a3449c5cda510867ac911c526d1050b37b36626ee', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 6, 'decoder': 'bposd', 'k': 12, 'n': 72, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 6, 'type': 'BB'}, shots=50000, errors=87, seconds=1212.0570000000002),
#  sinter.TaskStats(strong_id='dd279f5ac1d96592844329bb49240030dc1ba9aafd47adf4af68b7585039b8f4', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 6, 'decoder': 'bposd', 'k': 12, 'n': 72, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 6, 'type': 'BB'}, shots=50000, errors=122, seconds=1751.267),
#  sinter.TaskStats(strong_id='2ff7b8ad340ecfa90ce2cdfd1a3e2986afdb8559fae905c4460f6d33c82eec62', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 6, 'decoder': 'bposd', 'k': 12, 'n': 72, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 6, 'type': 'BB'}, shots=22642, errors=83, seconds=1238.6819999999996),
#  sinter.TaskStats(strong_id='f270b26e6f797c541880f51ac77e4fb5e31378dab1eb1279146d4caf6bfd7fa8', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 6, 'decoder': 'bposd', 'k': 12, 'n': 72, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 6, 'type': 'BB'}, shots=13909, errors=117, seconds=1162.777),
#  sinter.TaskStats(strong_id='f2c78381473990df995e89a74922dc137c6ea33c7da5a94a74697b6cf260f886', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 12, 'n': 144, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 12, 'type': 'BB'}, shots=10000, seconds=6841.619999999999),
#  sinter.TaskStats(strong_id='c89f4b7146c307a47961a211f81f2a959bdf58d40dcb082e4d4443ef4b7c365b', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 12, 'n': 144, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 12, 'type': 'BB'}, shots=10000, seconds=7147.238000000001),
#  sinter.TaskStats(strong_id='277f1abb9caa3f9da20e5bd86fd074fd41a8be7f3e2a6ff7819953738ed6f77b', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 12, 'n': 144, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 12, 'type': 'BB'}, shots=10000, errors=1, seconds=8957.690000000004),
#  sinter.TaskStats(strong_id='49007a5fc5a75639efc9a4a4c193500cbff43f6b5aafecb2c419b85af50d0e65', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 12, 'n': 144, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 12, 'type': 'BB'}, shots=10000, errors=3, seconds=11283.353000000005),
#  sinter.TaskStats(strong_id='82a9a3ed6e74752aed84f50b7f5d811b27b647f303191b755ecafb71eb968828', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 12, 'n': 144, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 12, 'type': 'BB'}, shots=10000, errors=5, seconds=13056.58),
#  sinter.TaskStats(strong_id='e7592f007ddc410105e0e738e49a894e439d90656b64278eea0204f69685a35a', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 12, 'n': 144, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 12, 'type': 'BB'}, shots=10000, errors=53, seconds=8059.7739999999985),
#  sinter.TaskStats(strong_id='10c7a3c044bef149b5ea27e94b0d9e58ba4c744e6cba670e2cd29ef17a186723', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 12, 'n': 144, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 12, 'type': 'BB'}, shots=2958, errors=100, seconds=4377.79),
#  sinter.TaskStats(strong_id='e578d5c54a76065df8400410951e5318ca81575c7339105a0a17474e5dc23708', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 18, 'type': 'BB'}, shots=10000, seconds=132759.1559999999),
#  sinter.TaskStats(strong_id='b14c33d2cb9e66f37b4943637092a34a6ad6574210013b4d6c036f83afc95118', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 18, 'type': 'BB'}, shots=10000, seconds=93514.70000000003),
#  sinter.TaskStats(strong_id='a01755cc181f8e710bd2186777a6d64fa9eaa4c9dfb3b67d06fc0acd9ed47755', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 18, 'type': 'BB'}, shots=20000, seconds=269714.41600000014),
#  sinter.TaskStats(strong_id='cfd8cfcd3e0bf67f406f71d0a3b5913da9043f5f197a801a4454bad7740ea58c', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 18, 'type': 'BB'}, shots=20000, errors=3, seconds=273795.81000000035),
#  sinter.TaskStats(strong_id='ccf480c3b8d4a7d8c7032e19b63d9a6fedea1fae51034f961004549337397d62', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 18, 'type': 'BB'}, shots=10000, errors=25, seconds=154030.4000000001),
#  sinter.TaskStats(strong_id='0d020711eaa88176277f32585d62f63c03aadf88f01bf309aae6babbe0b868fb', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 18, 'type': 'BB'}, shots=1995, errors=100, seconds=37498.3),
#  sinter.TaskStats(strong_id='017ee46c3e7f8d32ada488dbd25c5f89be9e957589e05ba13d3e56b66d3149fc', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 18, 'type': 'BB'}, shots=276, errors=100, seconds=6158.2),
#  sinter.TaskStats(strong_id='1bef887d729872df84cd6dab6806b90cce3380c73dd135a530caebc9d7aaab20', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 144, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 12, 'type': 'Radial'}, shots=10000, errors=1, seconds=5483.94),
#  sinter.TaskStats(strong_id='2c64f37bf86d451bed9661f00fc29d7e29daf51f320b65b235b6a598f3748d10', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 144, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 12, 'type': 'Radial'}, shots=10000, seconds=5058.318),
#  sinter.TaskStats(strong_id='6a512cc654f8be390f08b619fdfcee78811f690b0cfda916cd6f0e8299e82267', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 144, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 12, 'type': 'Radial'}, shots=10000, seconds=7724.675999999999),
#  sinter.TaskStats(strong_id='a821fb712bff905bbaf27621b20382017b7d484a28e9ef7d3f3324a3fda80d45', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 144, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 12, 'type': 'Radial'}, shots=10000, seconds=10264.209999999997),
#  sinter.TaskStats(strong_id='b8eb5c879a3d156a6e5bf3c3eea82a66dd9da720a8ae31090256a78598868e26', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 144, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 12, 'type': 'Radial'}, shots=10000, errors=2, seconds=10994.043999999998),
#  sinter.TaskStats(strong_id='3c7d279192b5ebb64720878d32623bc270c160e6573c0dab09c19df76a23a98c', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 144, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 12, 'type': 'Radial'}, shots=10000, errors=17, seconds=7680.422000000001),
#  sinter.TaskStats(strong_id='719660ad29ab89f7e251ca8c0ac96fb64a21b27d776526b30ea2bf4ea94cad7a', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 144, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 12, 'type': 'Radial'}, shots=8012, errors=100, seconds=10878.670000000002),
#  sinter.TaskStats(strong_id='159531ab6648e04170aa7a49db13d7cbfb24171e3e3c06a37ac65731b23f0066', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 14, 'type': 'Radial'}, shots=10000, seconds=10003.390000000003),
#  sinter.TaskStats(strong_id='addbf220ef7c58c9b86ce80a35f4987fb031b97130dd8dbae2b8333c429ec6a8', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 14, 'type': 'Radial'}, shots=10000, seconds=12254.309999999998),
#  sinter.TaskStats(strong_id='1a4c5931f920cfc47afb0481400545037ead28f7d50b90a0a0cb93ff4ca88034', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 14, 'type': 'Radial'}, shots=10000, seconds=15542.769999999999),
#  sinter.TaskStats(strong_id='759149505ea7bbed9336a6259e2e61148eec1a9dd1788d916724250be0e64d97', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 14, 'type': 'Radial'}, shots=10000, seconds=27005.940000000002),
#  sinter.TaskStats(strong_id='7290c65a76da8a3357575c188acabbcc8dad272f977e0a43b70d9a100f68c1b1', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 14, 'type': 'Radial'}, shots=10000, errors=2, seconds=32103.439999999995),
#  sinter.TaskStats(strong_id='8320890a542d2d53f1f02d142d25506f3e5e5dc0e2b5df5a61d330b95b014ad7', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 14, 'type': 'Radial'}, shots=10000, errors=71, seconds=34080.319999999985),
#  sinter.TaskStats(strong_id='05468ad0686840b4a0c555559d3eb353845fe055999e358b32e28352307dc71d', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 14, 'type': 'Radial'}, shots=1480, errors=100, seconds=5553.929999999998),
#  sinter.TaskStats(strong_id='b221267661d0c09a12566c07dba822cbf23b42dd3879593faea5adb8d6b5a6c7', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 18, 'n': 192, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 12, 'type': 'Radial'}, shots=10000, errors=22, seconds=57519.30899999996),
#  sinter.TaskStats(strong_id='c0592a4860c5d86662dfdcfb8d26f5eb37740d0634af828ed6b289b850db2535', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 18, 'n': 192, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 12, 'type': 'Radial'}, shots=10000, errors=24, seconds=81866.09099999994),
#  sinter.TaskStats(strong_id='559c88cc96ecb7d593e1c69401400badcecbc498eb3a89aaee52c76dcdda3236', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 18, 'n': 192, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 12, 'type': 'Radial'}, shots=10000, errors=27, seconds=80832.55700000003),
#  sinter.TaskStats(strong_id='722718200522ba991ebad587939de97f5ba29ce218212ee3987c1a201d876ef0', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 18, 'n': 192, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 12, 'type': 'Radial'}, shots=10000, errors=30, seconds=110883.5369999999),
#  sinter.TaskStats(strong_id='4af87e9a0ac7d6dff8a244ced840f4374958fba62e94cdfe7c659261dab1b1b5', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 18, 'n': 192, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 12, 'type': 'Radial'}, shots=6920, errors=100, seconds=88768.73999999996),
#  sinter.TaskStats(strong_id='62e4c47ab1d94496eb1990331526fa8b217b72e1d7f65c600f7d39454091ecfd', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 18, 'n': 192, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 12, 'type': 'Radial'}, shots=1375, errors=100, seconds=24867.3),
#  sinter.TaskStats(strong_id='f5d64a83265e8267f992b6f1ea18cd284f20f5f1cbb103c4d3e955a0e456618d', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 18, 'n': 192, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 12, 'type': 'Radial'}, shots=268, errors=100, seconds=3734.080000000001),
#  sinter.TaskStats(strong_id='497c9258b881d279ea87c94e932c55eab9a955f2dc9a7a5a3f3b8f8163849611', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 16, 'decoder': 'bposd', 'k': 18, 'n': 256, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 16, 'type': 'Radial'}, shots=10000, errors=14, seconds=462794.63499999914),
#  sinter.TaskStats(strong_id='eeca633d1fa25612d22302ba2fb73ae99a9f98080bef76d1ea7488f78afbdede', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 16, 'decoder': 'bposd', 'k': 18, 'n': 256, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 16, 'type': 'Radial'}, shots=10000, errors=12, seconds=531737.4319999997),
#  sinter.TaskStats(strong_id='84ba86d3bfdbc308e40c6c898194ad4574c09e0afafc80359a55080f08bd908e', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 16, 'decoder': 'bposd', 'k': 18, 'n': 256, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 16, 'type': 'Radial'}, shots=10000, errors=17, seconds=506785.3650000003),
#  sinter.TaskStats(strong_id='0f4ec44d4a9442e428f403bc577f3c67d3add1c93af096e93f48201ae67f15fd', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 16, 'decoder': 'bposd', 'k': 18, 'n': 256, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 16, 'type': 'Radial'}, shots=10000, errors=23, seconds=488062.3729999998),
#  sinter.TaskStats(strong_id='662b29167b735c8b0182e30fd6d276659133b150b780fb4644a797c5cac70e8a', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 16, 'decoder': 'bposd', 'k': 18, 'n': 256, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 16, 'type': 'Radial'}, shots=4505, errors=100, seconds=273058.7000000004),
#  sinter.TaskStats(strong_id='ecccd0705cfe21c41482cb3b258f7ea51c2e947f7f246120632d52e4cec9d51f', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 16, 'decoder': 'bposd', 'k': 18, 'n': 256, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 16, 'type': 'Radial'}, shots=411, errors=100, seconds=32659.49999999999),
#  sinter.TaskStats(strong_id='8f0db7e4fb9f90533443db75a30f6f1a9d237c2aad80c5f03c276778d842bc09', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 16, 'decoder': 'bposd', 'k': 18, 'n': 256, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 16, 'type': 'Radial'}, shots=138, errors=100, seconds=13527.10000000001),
#  sinter.TaskStats(strong_id='d6e452358c43279c5d05f7357890879d82433e1d72b3ffa1903c784d6ae83e9c', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 20, 'type': 'Radial'}, shots=2636, seconds=904088.0910000007),
#  sinter.TaskStats(strong_id='a2e550d9e8bb41a03de0a625551fe86951076672a67377af26fd9527537513db', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 20, 'type': 'Radial'}, shots=2951, seconds=901463.0450000014),
#  sinter.TaskStats(strong_id='19a9721b9f97002c545dda50a247d87f0dd1d04b992b3597a7a6d43863a92996', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 20, 'type': 'Radial'}, shots=2687, errors=3, seconds=897127.4000000008),
#  sinter.TaskStats(strong_id='dc37a63e821bb3f1a3947f992eb59132dc9fd5bdf3db7c9ec7d9ca98c4af28f2', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 20, 'type': 'Radial'}, shots=2497, errors=14, seconds=887397.8999999992),
#  sinter.TaskStats(strong_id='3f93aa6127b94104ae9674d46e945873932168f7e6f08a25eb0e7a04722b6ae0', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 20, 'type': 'Radial'}, shots=383, errors=101, seconds=182642.8000000001),
#  sinter.TaskStats(strong_id='ca21e0da28e1c6078c2e654af7b5bee428ec4534f60e7ad2b2a691e28ff5821f', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 20, 'type': 'Radial'}, shots=120, errors=102, seconds=71997.7),
#  sinter.TaskStats(strong_id='c00981b919db547bbf6678d961e774aa271f0b22df473b5e95f7aecc055c84e7', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 20, 'type': 'Radial'}, shots=100, errors=100, seconds=55092.29999999999),
#  sinter.TaskStats(strong_id='8ce89ea829b707175f55c793b51d4404122effce1220e8f532bff51d6f5b5292', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.001, 'p_sh': 0.005623413251903491, 'rounds': 14, 'type': 'Radial'}, shots=10000, errors=7, seconds=25343.260000000002),
#  sinter.TaskStats(strong_id='ec635ebf8f4a0cfb66bda82386475eab3f833e9a91290351e660311dd2be798c', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.001, 'p_sh': 0.003831186849557285, 'rounds': 14, 'type': 'Radial'}, shots=10000, errors=1, seconds=24217.65),
#  sinter.TaskStats(strong_id='b56e53d28b003d668dbae7202b283ce4f12ace0b8a4f531d47572e7906354dcf', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.001, 'p_sh': 0.0026101572156825357, 'rounds': 14, 'type': 'Radial'}, shots=10000, seconds=22132.997),
#  sinter.TaskStats(strong_id='1316f9d8e301933c36407ca304e6d154b60e6dd90d40f2622c594f60a51b4fe2', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.003831186849557285, 'rounds': 18, 'type': 'BB'}, shots=20000, errors=5, seconds=249015.19000000035),
#  sinter.TaskStats(strong_id='82efafacd25c2915c8f2cb6047e8e1cfd8d3456207d9be544b4e3a6c32d9638b', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.0026101572156825357, 'rounds': 18, 'type': 'BB'}, shots=20000, seconds=240703.8669999997),
#  sinter.TaskStats(strong_id='74c36e9ae96a4f1ac2ecb72e5ba358940cf47146c8b8f27852529af9897f4c01', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.005623413251903491, 'rounds': 18, 'type': 'BB'}, shots=8943, errors=101, seconds=111258.61999999988),
#  sinter.TaskStats(strong_id='8824f11318e522dd08c9c9ed44fe815472de41b233ca7aee63dc23343d696338', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.001, 'p_sh': 0.003831186849557285, 'rounds': 20, 'type': 'Radial'}, shots=2039, errors=100, seconds=735255.5999999989),
#  sinter.TaskStats(strong_id='55ee5defb84692f7fd557f3e1d97f56e4ee46b4cdec502fbce3d724b279ef910', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.001, 'p_sh': 0.0026101572156825357, 'rounds': 20, 'type': 'Radial'}, shots=6140, errors=11, seconds=2010785.6999999946),
#  sinter.TaskStats(strong_id='a245c18a2d92fd61a2c5c72321ec2bbd4319880f9d610eeb7f500cc10ab225d7', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.001, 'p_sh': 0.005623413251903491, 'rounds': 20, 'type': 'Radial'}, shots=166, errors=103, seconds=81989.50000000001)]

# %%
def logical_fit(p, a, b, c, d):
    return a*(p/b + c)**((d+1)/2)

def fixed_d_logical_fit(d):
    return lambda p,a,b,c: logical_fit(p,a,b,c,d)

p_upper_cutoffs = {
    ('Radial', (352, 18, 20)): 5e-3,
    ('Radial', (256,18,16)): 8e-3,
    ('Radial', (198, 8, 14)): 8e-3,
    ('BB', (288, 12, 18)): 6e-3,
}

all_ps = [[] for _ in code_ids]
all_lers = [[] for _ in code_ids]
all_uncs = [[] for _ in code_ids]
fit_params = [(np.nan, np.nan, np.nan, np.nan) for _ in code_ids]
for i,(code_type,(n,k,d)) in enumerate(code_ids):
    uncertainties = []
    for stat in stats:
        if stat.shots == 0:
            continue
        jmd = stat.json_metadata
        if (jmd['type'], jmd['n'], jmd['k'], jmd['d']) == (code_type, n, k, d):
            p_sh = jmd['p_sh']

            cutoff = p_upper_cutoffs.get((code_type,(n,k,d)), float('inf'))
            if p_sh > cutoff:
                continue

            ler = stat.errors / stat.shots
            ler = sinter.shot_error_rate_to_piece_error_rate(ler, pieces=d, values=k)
            unc = np.sqrt(ler * (1 - ler) / stat.shots)
            if 0 < ler:
                if ler > 0.5:
                    ler = 0.5
                    unc = np.sqrt(ler * (1 - ler) / stat.shots)
                all_ps[i].append(p_sh)
                all_lers[i].append(ler)
                all_uncs[i].append(unc)
    if len(all_ps[i]) < 3:
        print('Skipping', code_type, n, k, d, all_ps[i], all_lers[i])
        continue
    try:
        if code_type in ['Radial', 'BB']:
            bounds=([0, 0, 0, 0], [float('inf'), float('inf'), float('inf'), float('inf')])
            p0 = [0.5, 10, 1, d]
        else:
            bounds=([0, 0, 0, 0], [float('inf'), float('inf'), float('inf'), float('inf')])
            p0=[0.5, 0.1, 0.2, d]

        log_lers = np.log(np.array(all_lers[i]))
        log_uncertainties = np.array(all_uncs[i]) / np.array(all_lers[i])
        fit_params[i] = scipy.optimize.curve_fit(
            lambda p, a, b, c, d: np.log(logical_fit(p, a, b, c, d)), 
            all_ps[i], 
            log_lers, 
            sigma=log_uncertainties, 
            p0=p0, 
            bounds=bounds, 
            max_nfev=10000
        )[0]
    except Exception as e:
        print(e)
        continue
    
    print(code_type, n,k,d, fit_params[i], all_ps[i], all_lers[i], all_uncs[i])
# Out:
# Surface 9 1 3 [0.08735888 0.72782306 0.0285817  2.39928912] [0.01, 0.004641588833612777, 0.001, 0.0021544346900318843, 0.1, 0.046415888336127774, 0.021544346900318832] [0.0004272589756422751, 0.0002836571653012654, 0.00023062232915022074, 0.00023850345005227425, 0.004140943125619023, 0.0015184507106367762, 0.0006844046369048895] [np.float64(3.307413079620957e-05), np.float64(2.1940711981580385e-05), np.float64(1.5821294500642012e-05), np.float64(1.6478591417545583e-05), np.float64(0.00031624677437678796), np.float64(0.00010529936686515143), np.float64(4.637712306498265e-05)]
# Surface 25 1 5 [0.07174666 0.72466177 0.01937242 3.17284127] [0.01, 0.1, 0.046415888336127774, 0.0021544346900318843, 0.004641588833612777, 0.001, 0.021544346900318832] [5.8600881372217195e-05, 0.001533917085757286, 0.00039446389690939165, 2.5443858839901967e-05, 3.7087706059479864e-05, 2.1449702938380888e-05, 0.00013204764433893956] [np.float64(5.680279535031393e-06), np.float64(0.00013800377515638424), np.float64(3.5854650464560306e-05), np.float64(2.3870756705744557e-06), np.float64(3.4581257717713116e-06), np.float64(2.010605480990768e-06), np.float64(1.210079229519907e-05)]
# Surface 49 1 7 [0.04568019 0.47203222 0.02481902 4.63026009] [0.046415888336127774, 0.1, 0.021544346900318832, 0.0021544346900318843, 0.01, 0.001, 0.004641588833612777] [0.00012937248601258, 0.0007816102948087211, 2.540930140088049e-05, 2.100026460505333e-06, 7.916475359803776e-06, 1.814305464364896e-06, 3.6000777624001223e-06] [np.float64(1.4267910504772732e-05), np.float64(9.078760685114278e-05), np.float64(2.7488594202155494e-06), np.float64(4.582599753845189e-07), np.float64(9.08056841728128e-07), np.float64(4.2594626100725173e-07), np.float64(6.000054001290511e-07)]
# Surface 81 1 9 [0.06122459 0.42598952 0.02254861 6.1054334 ] [0.01, 0.046415888336127774, 0.021544346900318832, 0.1, 0.0021544346900318843, 0.004641588833612777, 0.001] [1.0777870707578963e-06, 4.787041170545292e-05, 5.366897089575939e-06, 0.00048114283572081584, 1.6666688890110137e-07, 4.0000127998762736e-07, 1.3333347553823316e-07] [np.float64(3.2829649847857446e-07), np.float64(5.842199672915592e-06), np.float64(7.325891267273607e-07), np.float64(6.268133689573348e-05), np.float64(1.2909952018626929e-07), np.float64(2.0000027999645485e-07), np.float64(1.1547010771642047e-07)]
# Surface 121 1 11 [0.1782653  0.44682257 0.02197923 7.91730321] [0.1, 0.021544346900318832, 0.001, 0.01, 0.004641588833612777, 0.0021544346900318843, 0.046415888336127774] [0.0003403486878080786, 1.236378922575554e-06, 9.090909913744838e-09, 1.5454569340933588e-07, 5.454548429595363e-08, 1.8181821492824213e-08, 1.750045741383266e-05] [np.float64(4.517649219923037e-05), np.float64(3.516215855067367e-07), np.float64(3.015113568524442e-08), np.float64(1.243163985663052e-07), np.float64(7.385491271455392e-08), np.float64(4.2640146765982856e-08), np.float64(2.452505149121479e-06)]
# Tile 288 8 12 [2.11911876e+00 4.30201741e+01 9.98345319e-01 1.57304556e+04] [0.001, 0.0031622776601683794, 0.01, 0.004641588833612777, 0.006812920690579608] [8.3337630496505e-06, 8.3337630496505e-06, 3.334021021417222e-05, 8.3337630496505e-06, 8.3337630496505e-06] [np.float64(2.8868137449520243e-05), np.float64(2.8868137449520243e-05), np.float64(5.7740019609067584e-05), np.float64(2.8868137449520243e-05), np.float64(2.8868137449520243e-05)]
# Tile 288 8 14 [2.07035484e+01 2.23175158e+01 9.98300273e-01 1.61449773e+04] [0.001467799267622069, 0.0031622776601683794, 0.001, 0.0021544346900318843, 0.006812920690579608, 0.01, 0.004641588833612777] [4.287057953022977e-05, 7.861660628394329e-05, 1.4287206838381472e-05, 5.7166747853609756e-05, 0.00024328944336338143, 0.0008529126585798963, 0.00012153651985913339] [np.float64(6.547422519101735e-05), np.float64(8.86625206686341e-05), np.float64(3.779815169304212e-05), np.float64(7.560653398784367e-05), np.float64(0.0001559584090743841), np.float64(0.0003180024723103304), np.float64(0.00011023690340964495)]
# Tile 288 18 13 [6.34034144e+01 3.43705734e+01 9.99169629e-01 3.54981649e+04] [0.004641588833612777, 0.01, 0.0021544346900318843, 0.0031622776601683794, 0.006812920690579608, 0.001467799267622069, 0.001] [0.00020796598988270798, 0.004541481746600962, 0.00010776582718541317, 0.0001308776559657554, 0.0008329342911874704, 5.3864525236813066e-05, 4.616734261209121e-05] [np.float64(0.00014419526345541315), np.float64(0.0016105035132991696), np.float64(0.00010380472711389603), np.float64(0.00011439428613568264), np.float64(0.0002994034913466289), np.float64(7.33904788441485e-05), np.float64(6.79449859728938e-05)]
# Tile 512 18 19 [2.07660333e+01 3.30244959e+01 9.99418374e-01 5.64586260e+04] [0.0021544346900318843, 0.001467799267622069, 0.001, 0.0031622776601683794, 0.006812920690579608, 0.004641588833612777, 0.01] [5.263421070211827e-06, 1.052736856044234e-05, 1.052736856044234e-05, 3.685500603123337e-05, 0.00044397258655393124, 7.373583774317183e-05, 0.008535214081963227] [np.float64(2.29420865803668e-05), np.float64(3.244573582915563e-05), np.float64(3.244573582915563e-05), np.float64(6.070720528879897e-05), np.float64(0.0002106597908705693), np.float64(8.586640831512876e-05), np.float64(0.003559242880731708)]
# Simplex 98 18 4 [2.13439487e+00 8.61469167e+00 9.91000265e-01 1.47296917e+03] [0.001, 0.001467799267622069, 0.004641588833612777, 0.0031622776601683794, 0.0021544346900318843, 0.006812920690579608, 0.01] [0.00324350374807314, 0.002990814204783865, 0.004417522241026983, 0.0034436647230595696, 0.0030414659030769675, 0.004823587669779639, 0.00645799820754811] [np.float64(0.00028889415002276444), np.float64(0.0002659431726815891), np.float64(0.00039208177509806143), np.float64(0.0003066428016911405), np.float64(0.00027096972580085055), np.float64(0.0004287525743703064), np.float64(0.0005716743972732237)]
# Simplex 450 32 8 [1.56192523e+00 5.27438396e-01 9.58805895e-01 5.67031548e+02] [0.001467799267622069, 0.001, 0.004641588833612777, 0.0031622776601683794, 0.006812920690579608, 0.01] [2.5002256144768253e-05, 2.5002256144768253e-05, 0.00012505643223659213, 3.75050766480145e-05, 0.000475816331144574, 0.0026157684304594087] [np.float64(5.000163100535414e-05), np.float64(5.000163100535414e-05), np.float64(0.00011182164062709346), np.float64(6.124024005279545e-05), np.float64(0.0002180802443972379), np.float64(0.0007354061312336588)]
# BB 72 12 6 [2.19443047e+00 3.75717725e+01 9.98430492e-01 1.15910344e+04] [0.001, 0.001467799267622069, 0.0021544346900318843, 0.0031622776601683794, 0.004641588833612777, 0.006812920690579608, 0.01] [0.000410455982853164, 0.00029356663098811797, 0.00033363464175939495, 0.0002902280226629861, 0.0004071152595984673, 0.0006119722848239029, 0.0014073218219692318] [np.float64(9.058559584606197e-05), np.float64(7.661337345676514e-05), np.float64(8.167292448360264e-05), np.float64(7.617660931780138e-05), np.float64(9.021635292604876e-05), np.float64(0.00016435221263765175), np.float64(0.0003178651724093144)]
# BB 144 12 12 [ 0.24443894  0.02550421  0.17101255 14.44869041] [0.0021544346900318843, 0.0031622776601683794, 0.004641588833612777, 0.006812920690579608, 0.01] [8.333747133604241e-06, 2.500372470259915e-05, 4.167701444468541e-05, 0.00044283307861103793, 0.0028656020954656025] [np.float64(2.8868109883161654e-05), np.float64(5.0003099420286086e-05), np.float64(6.455639199270076e-05), np.float64(0.0002103893955206692), np.float64(0.0009828465269320478)]
# /tmp/ipykernel_3126435/1851788761.py:54: OptimizeWarning: Covariance of the parameters could not be estimated
#   fit_params[i] = scipy.optimize.curve_fit(
# BB 288 12 18 [2.58429162e-01 1.23584445e-02 1.34462558e-01 2.17245428e+01] [0.0031622776601683794, 0.004641588833612777, 0.003831186849557285, 0.005623413251903491] [8.333972865925965e-06, 0.00013906682014241945, 1.3890665489291187e-05, 0.0006310835235139312] [np.float64(2.0413112710733554e-05), np.float64(0.00011791839574975353), np.float64(2.6353816174041525e-05), np.float64(0.000265561262190715)]
# Radial 144 8 12 [7.58125137e-01 3.42811595e+01 9.99402834e-01 4.31397050e+04] [0.001, 0.004641588833612777, 0.006812920690579608, 0.01] [8.3337630496505e-06, 1.666838565150819e-05, 0.00014179099086342184, 0.0010468579455525928] [np.float64(2.8868137449520243e-05), np.float64(4.082659404901169e-05), np.float64(0.00011906758004525489), np.float64(0.0003612817010976079)]
# Radial 198 8 14 [6.66127937e-01 1.18724583e+01 9.99064319e-01 3.97575461e+04] [0.004641588833612777, 0.006812920690579608, 0.005623413251903491, 0.003831186849557285] [1.4287206838381472e-05, 0.0005090328314821813, 5.0018290065678706e-05, 7.143230255857169e-06] [np.float64(3.779815169304212e-05), np.float64(0.00022556012880353089), np.float64(7.072184120647427e-05), np.float64(2.6726726754540447e-05)]
# Radial 192 18 12 [8.31726213e-01 8.15685812e+00 9.98200252e-01 1.05282232e+04] [0.001, 0.001467799267622069, 0.0021544346900318843, 0.0031622776601683794, 0.004641588833612777, 0.006812920690579608, 0.01] [0.0001835287467677471, 0.0002002325887275891, 0.00022529442820784507, 0.0002503635633710477, 0.0012127388189818733, 0.00628461356205301, 0.03862790181579279] [np.float64(0.0001354603499061098), np.float64(0.00014148939735471365), np.float64(0.0001500812015638413), np.float64(0.00015820900146868504), np.float64(0.000418376314334095), np.float64(0.0021311741867172523), np.float64(0.01177142172665645)]
# Radial 256 18 16 [8.83285230e-01 2.50929267e+01 9.99575630e-01 5.29330663e+04] [0.001, 0.001467799267622069, 0.0021544346900318843, 0.0031622776601683794, 0.004641588833612777, 0.006812920690579608] [8.756066839143983e-05, 7.504456677021043e-05, 0.0001063394727711664, 0.00014391384080203462, 0.0014028132834589258, 0.017400359005820487] [np.float64(9.356976088501599e-05), np.float64(8.662501664254312e-05), np.float64(0.00010311554911248698), np.float64(0.0001199554624052028), np.float64(0.0005576320234274208), np.float64(0.006449803654622754)]
# Radial 352 18 20 [4.23511073e-01 1.44259309e-02 5.72357448e-01 5.78937803e+01] [0.0021544346900318843, 0.0031622776601683794, 0.004641588833612777, 0.003831186849557285, 0.0026101572156825357] [5.5855612896782425e-05, 0.0002811274389037388, 0.015313722821053477, 0.00251453496661036, 8.96571062224405e-05] [np.float64(0.00014417416617589973), np.float64(0.0003354913230176272), np.float64(0.006274656370692345), np.float64(0.0011091071747654777), np.float64(0.00012083387512939292)]

# %%
markers = ['o', 's', '^', 'v', '<', '>', 'p']
colordict = {
    'Surface':'C0',
    'BB':'C5',
    'Radial':'C2',
    'Simplex':'C3',
    'Tile':'C1',
    # 'Hypercube':'C0'
}

fig,ax = plt.subplots(figsize=(5,4))
# xs_test = np.geomspace(5e-4, 1e-3, 10)
# xs_test_surface = np.geomspace(5e-4, 4e-3, 10)
xs_test = np.geomspace(1e-4, 5e-1, 100)
xs_test_surface = np.geomspace(1e-4, 5e-1, 100)
for i,(fp,code_id) in enumerate(zip(fit_params, code_ids)):
    code_type,(n,k,d) = code_id
    print(fp)
    if code_type == 'Surface':
        plt.plot(xs_test_surface, logical_fit(xs_test_surface, *fp), 'k--', alpha=0.5, color=colordict[code_id[0]])
    else:
        plt.plot(xs_test, logical_fit(xs_test, *fp), 'k--', alpha=0.5, color=colordict[code_id[0]])
# sinter.plot_error_rate(
#     ax=ax,
#     stats=stats,
#     x_func=lambda s: s.json_metadata['p_sh'],
#     group_func=lambda s: f"{s.json_metadata['type']} [[{s.json_metadata['n']}, {s.json_metadata['k']}, {s.json_metadata['d']}]]",
#     failure_units_per_shot_func=lambda s: s.json_metadata['d'],
#     failure_values_func=lambda s: s.json_metadata['k'],
#     # highlight_max_likelihood_factor=None,
#     filter_func=lambda s: s.json_metadata['p_sh'] < p_upper_cutoffs.get((s.json_metadata['type'], (s.json_metadata['n'], s.json_metadata['k'], s.json_metadata['d'])), float('inf')),
# )



for i,code_id in enumerate(code_ids):
    # plt.errorbar(all_ps[i], all_lers[i], yerr=all_uncs[i])
    code_type,(n,k,d) = code_id
    plt.plot(all_ps[i], all_lers[i], marker=markers[i % len(markers)], color=colordict[code_id[0]], linestyle='none', label=f'{code_type} [[{n}, {k}, {d}]]')

# plt.plot(xs_test, logical_fit(xs_test, 0.5, 0.01, 0.2, 10))

plt.legend(bbox_to_anchor=(1,0.5), loc='center left')
plt.loglog()
plt.xlim(1e-4)
plt.ylim(1e-10, top=1)
plt.xlabel('Shuttle error ' + r'$p_\text{sh}$')
plt.ylabel('Idling logical error rate')
ax.grid(which='both', linewidth=0.5)
ax.tick_params(which='both', direction='in')
plt.savefig('notebooks/fig/10_simulation_fits.pdf', bbox_inches='tight')
plt.show()
# Out:
# [0.08735888 0.72782306 0.0285817  2.39928912]
# [0.07174666 0.72466177 0.01937242 3.17284127]
# [0.04568019 0.47203222 0.02481902 4.63026009]
# [0.06122459 0.42598952 0.02254861 6.1054334 ]
# [0.1782653  0.44682257 0.02197923 7.91730321]
# [2.11911876e+00 4.30201741e+01 9.98345319e-01 1.57304556e+04]
# [2.07035484e+01 2.23175158e+01 9.98300273e-01 1.61449773e+04]
# [6.34034144e+01 3.43705734e+01 9.99169629e-01 3.54981649e+04]
# [2.07660333e+01 3.30244959e+01 9.99418374e-01 5.64586260e+04]
# [2.13439487e+00 8.61469167e+00 9.91000265e-01 1.47296917e+03]
# [1.56192523e+00 5.27438396e-01 9.58805895e-01 5.67031548e+02]
# [2.19443047e+00 3.75717725e+01 9.98430492e-01 1.15910344e+04]
# [ 0.24443894  0.02550421  0.17101255 14.44869041]
# [2.58429162e-01 1.23584445e-02 1.34462558e-01 2.17245428e+01]
# [7.58125137e-01 3.42811595e+01 9.99402834e-01 4.31397050e+04]
# [6.66127937e-01 1.18724583e+01 9.99064319e-01 3.97575461e+04]
# [8.31726213e-01 8.15685812e+00 9.98200252e-01 1.05282232e+04]
# [8.83285230e-01 2.50929267e+01 9.99575630e-01 5.29330663e+04]
# [4.23511073e-01 1.44259309e-02 5.72357448e-01 5.78937803e+01]
# /tmp/ipykernel_3126435/4154501166.py:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(xs_test_surface, logical_fit(xs_test_surface, *fp), 'k--', alpha=0.5, color=colordict[code_id[0]])
# /tmp/ipykernel_3126435/4154501166.py:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(xs_test, logical_fit(xs_test, *fp), 'k--', alpha=0.5, color=colordict[code_id[0]])
# /tmp/ipykernel_3126435/1851788761.py:2: RuntimeWarning: overflow encountered in power
#   return a*(p/b + c)**((d+1)/2)

# %%
[s for s in stats if s.json_metadata['type'] == 'BB' and s.json_metadata['n'] == 288]
# Out:
# [sinter.TaskStats(strong_id='e578d5c54a76065df8400410951e5318ca81575c7339105a0a17474e5dc23708', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 18, 'type': 'BB'}, shots=10000, seconds=132759.1559999999),
#  sinter.TaskStats(strong_id='b14c33d2cb9e66f37b4943637092a34a6ad6574210013b4d6c036f83afc95118', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001467799267622069, 'rounds': 18, 'type': 'BB'}, shots=10000, seconds=93514.70000000003),
#  sinter.TaskStats(strong_id='a01755cc181f8e710bd2186777a6d64fa9eaa4c9dfb3b67d06fc0acd9ed47755', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.0021544346900318843, 'rounds': 18, 'type': 'BB'}, shots=20000, seconds=269714.41600000014),
#  sinter.TaskStats(strong_id='cfd8cfcd3e0bf67f406f71d0a3b5913da9043f5f197a801a4454bad7740ea58c', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.0031622776601683794, 'rounds': 18, 'type': 'BB'}, shots=20000, errors=3, seconds=273795.81000000035),
#  sinter.TaskStats(strong_id='ccf480c3b8d4a7d8c7032e19b63d9a6fedea1fae51034f961004549337397d62', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.004641588833612777, 'rounds': 18, 'type': 'BB'}, shots=10000, errors=25, seconds=154030.4000000001),
#  sinter.TaskStats(strong_id='0d020711eaa88176277f32585d62f63c03aadf88f01bf309aae6babbe0b868fb', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.006812920690579608, 'rounds': 18, 'type': 'BB'}, shots=1995, errors=100, seconds=37498.3),
#  sinter.TaskStats(strong_id='017ee46c3e7f8d32ada488dbd25c5f89be9e957589e05ba13d3e56b66d3149fc', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.01, 'rounds': 18, 'type': 'BB'}, shots=276, errors=100, seconds=6158.2),
#  sinter.TaskStats(strong_id='1316f9d8e301933c36407ca304e6d154b60e6dd90d40f2622c594f60a51b4fe2', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.003831186849557285, 'rounds': 18, 'type': 'BB'}, shots=20000, errors=5, seconds=249015.19000000035),
#  sinter.TaskStats(strong_id='82efafacd25c2915c8f2cb6047e8e1cfd8d3456207d9be544b4e3a6c32d9638b', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.0026101572156825357, 'rounds': 18, 'type': 'BB'}, shots=20000, seconds=240703.8669999997),
#  sinter.TaskStats(strong_id='74c36e9ae96a4f1ac2ecb72e5ba358940cf47146c8b8f27852529af9897f4c01', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.005623413251903491, 'rounds': 18, 'type': 'BB'}, shots=8943, errors=101, seconds=111258.61999999988)]

# %%
fit_params[code_ids.index(('BB', (288,12,18)))]
# Out:
# array([2.58429162e-01, 1.23584445e-02, 1.34462558e-01, 2.17245428e+01])

# %%
from adjustText import adjust_text

label_all = False
label_codes = [
    [],
    [
        ('Simplex', (98,18,4)),
        ('BB', (72,12,6)),
        ('BB', (144,12,12)),
        ('Radial', (198,8,14)),
    ],
    [
        ('Simplex', (98,18,4)),
        ('BB', (72,12,6)),
        ('BB', (144,12,12)),
        ('BB', (288,12,18)),
        ('Radial', (198,8,14)),
    ],
]

markerdict = {
    'Surface':'+',
    'BB':'^',
    'Radial':'o',
    'Simplex':'p',
    'Tile':'v',
    'Hypercube':'s',
}
colordict = {
    'Surface':'k',
    'BB':'C5',
    'Radial':'C2',
    'Simplex':'C3',
    'Tile':'C1',
    'Hypercube':'C0'
}

ps_display = [
    r'10^{-2}',
    r'3 \times 10^{-3}',
    r'10^{-3}',
]

skip = ['Hypercube']
# skip = []

fig,ax = plt.subplots(3,1,figsize=(4,10))
fig.subplots_adjust(hspace=0.2)
for j,p_tgt in enumerate([1e-2, 3e-3, 1e-3]):
    T2_tgt = 10**(-6-np.log10(p_tgt))
    p_sh_tgt = p_tgt

    points = [(np.nan, np.nan) for _ in code_ids]
    texts = []
    for i,(code_type, (n,k,d)) in enumerate(code_ids):
        if code_type in skip:
            continue
        if np.all(np.isfinite(fit_params[i])):
            ler_proj = logical_fit(p_tgt, *fit_params[i])
            enc_rate = k / n
            points[i] = (enc_rate*1000, ler_proj)
            ax[j].plot(*points[i], marker=markerdict[code_type], color=colordict[code_type], markeredgecolor=plotter.interpolate(colordict[code_type], 'k', 0.2))
            if label_all or (code_type, (n,k,d)) in label_codes[j]:
                texts.append(ax[j].text(*points[i], f'[[{n}, {k}, {d}]]', fontsize=9, ha='left', va='top'))
            print(code_type, (n,k,d), points[i])
    xs_surface = []
    ys_surface = []
    for d in ds_surface:
        pt = points[code_ids.index(('Surface', (d**2,1,d)))]
        xs_surface.append(pt[0])
        ys_surface.append(pt[1])
    ax[j].plot(xs_surface, ys_surface, 'C0--', alpha=0.5, zorder=0.2)
    ax[j].set_yscale('log')

    ax[j].set_xlim(0, 250)
    ax[j].set_ylim(top=1)
    xlim = ax[j].get_xlim()
    ylim = ax[j].get_ylim()

    xs_surface = np.array([-10] + xs_surface + [1000])
    ys_surface = np.array([1e-30] + ys_surface + [1e-3])
    sort_idx = np.argsort(xs_surface)
    ax[j].fill_between(xs_surface[sort_idx], ys_surface[sort_idx], [1]*len(ys_surface), color='#BBBBBB', zorder=0, alpha=0.5)

    ax[j].set_xlim(*xlim)
    ax[j].set_ylim(*ylim)

    for (code_type, marker) in markerdict.items():
        if code_type in skip:
            continue
        ax[j].plot([], [], color=colordict[code_type], marker=marker, linestyle='none', markeredgecolor=plotter.interpolate(colordict[code_type], 'k', 0.2), label=code_type)
    if j == 0:
        ax[j].legend(bbox_to_anchor=(0.8,0.3), loc='center')

    
    ax[j].set_title(r'$p_\text{sh}=' + ps_display[j] + r'$')
    if j == 2:
        ax[j].set_xlabel('# logical qubits per 1000 physical qubits')
    else:
        ax[j].set_xticklabels([])
    ax[j].set_ylabel('Logical error rate')
    # ax[j].ylim(1e-18, 1e-2)
    ax[j].set_yticks(ax[j].get_yticks(), minor=[])
    adjust_text(
        texts,
        arrowprops=dict(arrowstyle='->', color='gray'),
        # force_text=(1, 1),
        force_static=(1, 1),
        expand=(1.2, 3),
        prevent_crossings=True,
        add_objects=ax[j].collections,
        ax=ax[j],
    )
    ax[j].grid(which='both', linewidth=0.5, zorder=0.1)
    ax[j].tick_params(direction='in', which='both')
    ax[j].set_ylim(top=1)
plt.savefig('notebooks/fig/10_encoding_rate.pdf', bbox_inches='tight')
plt.savefig('notebooks/fig/10_encoding_rate.svg', bbox_inches='tight')
plt.show()
# Out:
# Surface (9, 1, 3) (111.1111111111111, np.float64(0.00040452522562385514))
# Surface (25, 1, 5) (40.0, np.float64(5.881769305288927e-05))
# Surface (49, 1, 7) (20.408163265306122, np.float64(7.85821616597271e-06))
# Surface (81, 1, 9) (12.345679012345679, np.float64(1.0885963497063923e-06))
# Surface (121, 1, 11) (8.264462809917356, np.float64(1.6536765503870294e-07))
# Tile (288, 8, 12) (27.777777777777775, np.float64(2.9126908594681313e-05))
# Tile (288, 8, 14) (27.777777777777775, np.float64(0.0008412949623265401))
# Tile (288, 18, 13) (62.5, np.float64(0.004393551819843667))
# Tile (512, 18, 19) (35.15625, np.float64(0.007916385931771594))
# Simplex (98, 18, 4) (183.67346938775512, np.float64(0.006462442668163874))
# Simplex (450, 32, 8) (71.11111111111111, np.float64(0.0026312250868523817))
# BB (72, 12, 6) (166.66666666666666, np.float64(0.0011439761498778062))
# BB (144, 12, 12) (83.33333333333333, np.float64(0.0028949100747780905))
# BB (288, 12, 18) (41.666666666666664, np.float64(0.13366277724147552))
# Radial (144, 8, 12) (55.55555555555555, np.float64(0.0010417988530023329))
# Radial (198, 8, 14) (40.40404040404041, np.float64(0.10403756238662645))
# Radial (192, 18, 12) (93.75, np.float64(0.040523312614722716))
# Radial (256, 18, 16) (70.3125, np.float64(0.44560610647402576))
# Radial (352, 18, 20) (51.13636363636364, np.float64(435.2200124733139))
# Surface (9, 1, 3) (111.1111111111111, np.float64(0.00026100394797996123))
# Surface (25, 1, 5) (40.0, np.float64(2.868384511660769e-05))
# Surface (49, 1, 7) (20.408163265306122, np.float64(2.6277153354840557e-06))
# Surface (81, 1, 9) (12.345679012345679, np.float64(2.266685187247589e-07))
# Surface (121, 1, 11) (8.264462809917356, np.float64(2.3705410660853257e-08))
# Tile (288, 8, 12) (27.777777777777775, np.float64(8.083850451703525e-06))
# Tile (288, 8, 14) (27.777777777777775, np.float64(6.663551696669883e-05))
# Tile (288, 18, 13) (62.5, np.float64(0.00011799564573911762))
# Tile (512, 18, 19) (35.15625, np.float64(1.9899331938290538e-05))
# Simplex (98, 18, 4) (183.67346938775512, np.float64(0.0035331171034689466))
# Simplex (450, 32, 8) (71.11111111111111, np.float64(5.42561396705102e-05))
# BB (72, 12, 6) (166.66666666666666, np.float64(0.00038795864602166914))
# BB (144, 12, 12) (83.33333333333333, np.float64(1.658747218687066e-05))
# BB (288, 12, 18) (41.666666666666664, np.float64(3.993789900582511e-06))
# Radial (144, 8, 12) (55.55555555555555, np.float64(1.2709836374205272e-05))
# Radial (198, 8, 14) (40.40404040404041, np.float64(8.41253813539608e-07))
# Radial (192, 18, 12) (93.75, np.float64(0.0004401635911940942))
# Radial (256, 18, 16) (70.3125, np.float64(0.0002766200127401806))
# Radial (352, 18, 20) (51.13636363636364, np.float64(0.00028482050588176446))
# Surface (9, 1, 3) (111.1111111111111, np.float64(0.00022483438168863763))
# Surface (25, 1, 5) (40.0, np.float64(2.2105330419124833e-05))
# Surface (49, 1, 7) (20.408163265306122, np.float64(1.7417283114690933e-06))
# Surface (81, 1, 9) (12.345679012345679, np.float64(1.2269702825906254e-07))
# Surface (121, 1, 11) (8.264462809917356, np.float64(1.1128651582055474e-08))
# Tile (288, 8, 12) (27.777777777777775, np.float64(5.6046860005412125e-06))
# Tile (288, 8, 14) (27.777777777777775, np.float64(3.228505344011193e-05))
# Tile (288, 18, 13) (62.5, np.float64(4.197245578068246e-05))
# Tile (512, 18, 19) (35.15625, np.float64(3.597237423383798e-06))
# Simplex (98, 18, 4) (183.67346938775512, np.float64(0.002972988415665413))
# Simplex (450, 32, 8) (71.11111111111111, np.float64(1.7723757696758203e-05))
# BB (72, 12, 6) (166.66666666666666, np.float64(0.0002848320800398593))
# BB (144, 12, 12) (83.33333333333333, np.float64(1.4331743354273695e-06))
# BB (288, 12, 18) (41.666666666666664, np.float64(6.855111988897846e-09))
# Radial (144, 8, 12) (55.55555555555555, np.float64(3.608383987742996e-06))
# Radial (198, 8, 14) (40.40404040404041, np.float64(2.9474257940888753e-08))
# Radial (192, 18, 12) (93.75, np.float64(0.000120819009794999))
# Radial (256, 18, 16) (70.3125, np.float64(3.352850670451802e-05))
# Radial (352, 18, 20) (51.13636363636364, np.float64(8.972953072240747e-07))

# %%
from adjustText import adjust_text

label_all = False

ps_display = [
    r'10^{-2}',
    r'3 \times 10^{-3}',
    r'10^{-3}',
]

for j,p_tgt in enumerate([1e-2, 3e-3, 1e-3]):
    fig,ax = plt.subplots(figsize=(4,3))
    T2_tgt = 10**(-6-np.log10(p_tgt))
    p_sh_tgt = p_tgt

    points = [(np.nan, np.nan) for _ in code_ids]
    texts = []
    for i,(code_type, (n,k,d)) in enumerate(code_ids):
        if code_type in skip:
            continue
        if np.all(np.isfinite(fit_params[i])):
            ler_proj = logical_fit(p_tgt, *fit_params[i])
            enc_rate = k / n
            points[i] = (enc_rate*1000, ler_proj)
            ax.plot(*points[i], marker=markerdict[code_type], color=colordict[code_type], markeredgecolor=plotter.interpolate(colordict[code_type], 'k', 0.2))
            if label_all or (code_type, (n,k,d)) in label_codes:
                texts.append(ax.text(*points[i], f'[[{n}, {k}, {d}]]', fontsize=9, ha='left', va='top'))
    xs_surface = []
    ys_surface = []
    for d in ds_surface:
        pt = points[code_ids.index(('Surface', (d**2,1,d)))]
        xs_surface.append(pt[0])
        ys_surface.append(pt[1])
    ax.plot(xs_surface, ys_surface, 'C0--', alpha=1, zorder=0.2, linewidth=2)
    ax.set_yscale('log')

    ax.set_xlim(0, 250)
    ax.set_ylim(top=1)
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()

    xs_surface = np.array([-10] + xs_surface + [1000])
    ys_surface = np.array([1e-30] + ys_surface + [1])
    sort_idx = np.argsort(xs_surface)
    ax.fill_between(xs_surface[sort_idx], ys_surface[sort_idx], [1]*len(ys_surface), color='#BBBBBB', zorder=0, alpha=0.5)

    ax.set_xlim(*xlim)
    ax.set_ylim(*ylim)

    for (code_type, marker) in markerdict.items():
        if code_type in skip:
            continue
        ax.plot([], [], color=colordict[code_type], marker=marker, linestyle='none', markeredgecolor=plotter.interpolate(colordict[code_type], 'k', 0.2), label=code_type)

    ax.legend(bbox_to_anchor=(1,0.5), loc='center left')
    
    # ax.set_title(r'$(p,T_2,p_\text{sh})=(' + ps_display[j] + f', {T2_tgt*1e3:.2g}ms, ' + ps_display[j] + r')$')
    ax.set_title(r'$p_\text{gate} = 10^{-3}, p_\text{sh}=' + ps_display[j] + r'$')
    ax.set_xlabel('# logical qubits per 1000 physical qubits')

    ax.set_ylabel('Logical error rate')
    # ax.ylim(1e-18, 1e-2)
    ax.set_yticks(ax.get_yticks(), minor=[])
    adjust_text(
        texts,
        arrowprops=dict(arrowstyle='->', color='gray'),
        # force_text=(1, 1),
        force_static=(1, 3),
        expand=(1.2, 4),
        prevent_crossings=True,
        add_objects=ax.collections,
        ax=ax,
    )
    ax.grid(which='both', linewidth=0.5, zorder=0.1)
    ax.tick_params(direction='in', which='both')
    ax.set_ylim(top=1)
    plt.savefig(f'notebooks/fig/10_encoding_rate_{j}.pdf', bbox_inches='tight')
    plt.savefig(f'notebooks/fig/10_encoding_rate_{j}.png', dpi=300, bbox_inches='tight')
    # plt.savefig('notebooks/fig/10_encoding_rate.svg', bbox_inches='tight')
    plt.show()

# %%
from scipy.interpolate import interp1d

# Define the range of physical error rates to plot
ps_eval = np.geomspace(1e-4, 1e-2, 50)

fig, ax = plt.subplots(figsize=(4,3))

# Extract surface code fit parameters
surface_data = []
for d in ds_surface:
    idx = code_ids.index(('Surface', (d**2, 1, d)))
    fp = fit_params[idx]
    surface_data.append((1 / (d**2), fp))

markerlist = [
    '<',
    '>',
    '^',
    'o',
    'p',
    'v',
    's',
    'd',
]

linestyles = ['-', '--', '-.', ':']
type_counts = dict()

def get_equiv_sc_ler(p, encoding_rate):
    # 1. Evaluate surface code LERs at this specific physical error rate (p)
    sc_rates = []
    sc_lers = []
    for sc_rate, sc_fp in surface_data:
        sc_rates.append(sc_rate)
        sc_lers.append(logical_fit(p, *sc_fp))
        
    # Append the bare physical qubit representing an encoding rate of 1
    sc_rates.append(1.0)
    sc_lers.append(1e-3)
    
    # Sort values to ensure interp1d works correctly
    sort_idx = np.argsort(sc_rates)
    sc_rates = np.array(sc_rates)[sort_idx]
    sc_lers = np.array(sc_lers)[sort_idx]
    
    # 2. Create interpolation function in log-log space
    interp_func = interp1d(
        np.log10(sc_rates), 
        np.log10(sc_lers), 
        kind='linear',
        bounds_error=False, 
        fill_value='extrapolate' # Handles codes with k/n < 1/121
    )
    
    # 3. Find the Equivalent Surface Code LER
    equiv_sc_ler = 10**(interp_func(np.log10(encoding_rate)))
    return equiv_sc_ler

# Calculate and plot the improvement factor for each non-Surface code
for i, (code_type, (n, k, d)) in enumerate(code_ids):
    if code_type == 'Surface' or code_type in skip:
        continue
    
    fp_code = fit_params[i]
    if not np.all(np.isfinite(fp_code)):
        continue

    encoding_rate = k / n
    improvements = []

    for p in ps_eval:
        # 4. Find the actual code LER and calculate the ratio (Speedup)
        code_ler = logical_fit(p, *fp_code)
        improvement = get_equiv_sc_ler(p, encoding_rate) / code_ler
        improvements.append(improvement)

    # Plot the results
    ax.plot(
        ps_eval, 
        improvements, 
        label=f'{code_type} [[{n}, {k}, {d}]]',
        color=colordict.get(code_type, 'k'),
        # marker=markerlist[type_counts.get(code_type, 0)],
        # markevery=5, # Spacing out markers so they don't clutter the line
        linestyle=linestyles[i % len(linestyles)],
        markeredgecolor=plotter.interpolate(colordict.get(code_type, 'k'), 'k', 0.2)
    )
    # texts.append(ax.text(ps_eval[0], improvements[0], f'[[{n}, {k}, {d}]]', fontsize=9, ha='right', va='center'))
    type_counts[code_type] = type_counts.get(code_type, 0) + 1

    # for p,ler in zip(all_ps[i], all_lers[i]):
    #     ax.plot(p, get_equiv_sc_ler(p, encoding_rate) / ler, marker=markerlist[i % len(markerlist)], color=colordict[code_type])

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'Physical error rate ($p_{\text{sh}}$)')
ax.set_ylabel(r'$p_L$ improvement factor')
# ax.set_xlim(1e-5)

# Add a baseline indicating "no improvement" over surface codes
ax.axhline(1, color='k', linestyle='-', alpha=0.5)

ax.legend(bbox_to_anchor=(1.05, 0.4), loc='center left')
ax.grid(which='both', linewidth=0.5, zorder=0.1)
ax.tick_params(direction='in', which='both')

# adjust_text(
#     texts,
#     arrowprops=dict(arrowstyle='->', color='gray'),
#     # force_text=(1, 1),
#     # force_static=(1, 3),
#     # expand=(1.2, 4),
#     # prevent_crossings=True,
#     # add_objects=ax.collections,
#     ax=ax,
# )

# plt.title('Relative LER Improvement vs Equivalent Surface Code')
plt.savefig('notebooks/fig/10_improvement_factor.pdf', bbox_inches='tight')
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
