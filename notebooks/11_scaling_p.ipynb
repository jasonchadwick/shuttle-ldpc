# %%
import os
try:
    path_initialized
except NameError:
    path_initialized = True
    os.chdir('..')

import numpy as np
from sympy.abc import x, y

# from qldpc import codes
import networkx as nx
import matplotlib.pyplot as plt
import stim
import pickle
import sinter
from copy import deepcopy
import scipy

import src.device as device
import src.plotting as plotter
import src.stim_dag as stim_dag

from src.RotatedSurfaceCode import RotatedSurfaceCode
from src.TileCode import TileCode
from src.HGPCode import HGPCode
from src.SHYPSCode import SHYPSCode
from src.RadialCode import RadialCode
from src.GBCode import GBCode
from src.HypercubeCode import HypercubeCode
from src.decoders import BPOSD
from src.constructor import construct_code

# %%
compile_tasks = False
if compile_tasks:
    # Making codes
    codes = []
    code_types = []
    code_nkds = []
    code_data_coodes = []

    ds_surface = [3, 5, 7, 9, 11]
    for d in ds_surface:
        code = RotatedSurfaceCode(d)
        codes.append(code)
        code_types.append('Surface')
        code_nkds.append(code.compute_code_parameters())

    nkds_tile = [(288,8,12), (288, 8, 14), (288, 18, 13), (512, 18, 19)]
    for nkd in nkds_tile:
        code = TileCode.known_code(*nkd)
        codes.append(code)
        code_types.append('Tile')
        code_nkds.append(nkd)

    rs_simplex = [3,4]
    for r in rs_simplex:
        code = HGPCode.simplex_code(r)
        codes.append(code)
        code_types.append('Simplex')
        code_nkds.append(code.compute_code_parameters())

    # rs_cube = [2,3]
    # for r in rs_cube:
    #     code = HypercubeCode(r)
    #     codes.append(code)
    #     code_types.append('Hypercube')
    #     code_nkds.append(code.compute_code_parameters())

    lms = [
        (6,6),
        (12,6),
        (12,12),
    ]
    orders = [
        (([3], [1,2]), ([1, 2], [3])),
        (([3], [1, 2]), ([1, 2], [3])),
        (([3], [2, 7]), ([1, 2], [3])),
    ]
    nkds = [
        (72, 12, 6),
        (144, 12, 12),
        (288, 12, 18),
    ]
    for (l,m),(a_ord,b_ord) in zip(lms, orders):
        code = GBCode(l, m, a_ord, b_ord)
        codes.append(code)
        code_types.append('BB')

    code_nkds += nkds

    rsds_radial = [(3,8,12), (3,11,14), (4,6,12), (4,8,16), (4,11,20)]
    for r,s,d in rsds_radial:
        code = RadialCode(r,s,d)
        codes.append(code)
        code_types.append('Radial')
        code_nkds.append(code.compute_code_parameters())

    for code in codes:
        assert len(code.qubit_coords) > 0, code

    code_ids = list(zip(code_types, code_nkds))
else:
    ds_surface = [3, 5, 7, 9, 11]

# %%
if compile_tasks:
    hwp = device.default_hwp
    ps_surface = np.geomspace(1e-3, 1e-1, 7)
    # ps_other = np.geomspace(1e-3, 1.5e-3, 5)
    ps_other = np.geomspace(1e-3, 1e-2, 7)
    # p_g = 1e-3
    T2 = 10e-3
    # p = 1e-3
    # t2 = 1e-3
    # p_sh = 1e-3
    # error_params = device.error_params(p=p, T2=t2, p_sh=p_sh)
    buffer = 3
    basis = 'X'
    schedules = dict()
    tasks = []
    for code, code_type, (n,k,d) in zip(codes, code_types, code_nkds):
        print(code_type, f'[[{n}, {k}, {d}]]...')
        xmax,ymax = 0,0
        data_coords = dict()
        for i in code.data_indices:
            x,y = code.qubit_coords[i]
            data_coords[i] = (x+buffer, y+buffer)
            xmax = max(xmax, x)
            ymax = max(ymax, y)
        dev = device.UnitCellDevice(xmax+2*buffer, ymax+2*buffer, hwp)
        
        rounds = d

        if code_type == 'Surface':
            sched = code.get_schedule(hwp, 'Z', rounds=rounds, refocus_shuttling_noise=True)
        else:
            sched = dev.compile_QEC_schedule(
                code,
                data_coords,
                code.check_cx_layers,
                rounds=rounds,
                use_highways=False,
                refocus_shuttle_noise=True,
                separate_X_Z=code_type != 'Surface',
            )
        schedules[(code_type, (n,k,d))] = sched
        
        for p_sh in (ps_surface if code_type == 'Surface' else ps_other):
            p_g = p_sh
            error_params = device.error_params(p=p_g, T2=T2, p_sh=p_sh)
            circ = sched.to_stim_circuit(code, basis, error_params, XYZ_decode=False)
            try:
                circ.detector_error_model()
            except Exception as e:
                print('FAIL', e)

            decoder='pymatching' if code_type == 'Surface' else 'bposd'
            tasks.append(sinter.Task(
                circuit=circ,
                decoder=decoder,
                json_metadata={'n':n, 'k':k, 'd':d, 'type':code_type, 'rounds':rounds, 'basis':basis, 'decoder':decoder, 'p_g':p_g, 'T2':T2, 'p_sh':p_sh},
            ))
    with open('notebooks/data/11_tasks.pkl', 'wb') as f:
        pickle.dump({
            'tasks':tasks,
        }, f)
    with open('notebooks/data/11_params.pkl', 'wb') as f:
        pickle.dump({
            'code_types':code_types,
            'code_nkds':code_nkds,
            'code_data_coodes':code_data_coodes,
            'ps_surface': ps_surface,
            'ps_other': ps_other,
            'schedules':schedules,
        }, f)
else:
    try:
        with open('notebooks/data/11_tasks.pkl', 'rb') as f:
            data = pickle.load(f)
            tasks = data['tasks']
    except FileNotFoundError:
        print('Could not find task file. Setting tasks=None.')
        tasks = None
    with open('notebooks/data/11_params.pkl', 'rb') as f:
        data = pickle.load(f)
        code_types = data['code_types']
        code_nkds = data['code_nkds']
        code_data_coodes = data['code_data_coodes']
        ps_surface = data['ps_surface']
        ps_other = data['ps_other']
        schedules = data['schedules']

# %%
code_ids = list(zip(code_types, code_nkds))

# %%
stats = sinter.read_stats_from_csv_files('notebooks/data/11_results_TMP')
# with open('notebooks/data/10_results_old_prange.pkl', 'rb') as f:
#     stats = pickle.load(f)
#     stats = [s for s in stats if 'p' in s.json_metadata]

# %%
stats
# Out:
# [sinter.TaskStats(strong_id='1c1486fa37e702fa5ea85caa2a64650f529c3463544fe37940f492c1b5e52364', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 3, 'type': 'Surface'}, shots=39185, errors=508, seconds=0.016),
#  sinter.TaskStats(strong_id='a23ad824a9cd5af9ac2cf96c6b150ead6f832a4263a5f17dcf513fe43fd47219', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 3, 'type': 'Surface'}, shots=9489, errors=509, seconds=0.009999999999999998),
#  sinter.TaskStats(strong_id='424ae49fdd4be0a2ac0a6bd060c3dba75ae33bdca44f68c806cf3ce581857daa', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 5, 'type': 'Surface'}, shots=5560661, errors=570, seconds=5.455),
#  sinter.TaskStats(strong_id='c499469474b27b6147ca8c708ef3903dd3719b8a151cf4cc0ac135ae8ced8218', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 5, 'type': 'Surface'}, shots=7441, errors=605, seconds=0.07200000000000001),
#  sinter.TaskStats(strong_id='084f32e5205cea59cf4232d84d3d7569d59fcd6a8869211a9c4cda128ed97e5f', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.021544346900318832, 'p_sh': 0.021544346900318832, 'rounds': 3, 'type': 'Surface'}, shots=3345, errors=607, seconds=0.01),
#  sinter.TaskStats(strong_id='e1582b6dfc7d05618ae1188a4c8986f8d202f6d91a50a278c72f38eb2b42e55b', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.021544346900318832, 'p_sh': 0.021544346900318832, 'rounds': 5, 'type': 'Surface'}, shots=2321, errors=777, seconds=0.055),
#  sinter.TaskStats(strong_id='64a181c6faa6c3d16eb27267ff9206ecbd1c679366310b0de10858ca48ae83fc', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.046415888336127774, 'p_sh': 0.046415888336127774, 'rounds': 5, 'type': 'Surface'}, shots=1297, errors=642, seconds=0.053),
#  sinter.TaskStats(strong_id='8041a54097f46965b2ab3e6c66ce224cdae0e5ebc3d063813dfd0573e6625928', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.046415888336127774, 'p_sh': 0.046415888336127774, 'rounds': 3, 'type': 'Surface'}, shots=2321, errors=885, seconds=0.013000000000000001),
#  sinter.TaskStats(strong_id='41a611290fe9bf4b7fd3b56d1d8e1ec0cc92a2d4644dd677558ccb9eac016b5a', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.1, 'p_sh': 0.1, 'rounds': 3, 'type': 'Surface'}, shots=1297, errors=664, seconds=0.011),
#  sinter.TaskStats(strong_id='6f69cdce5edde9b745057ab87bc56cd9ffaa309e3f67fe68efdc2ab3d2a1e58d', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 3, 'type': 'Surface'}, shots=876066, errors=600, seconds=0.234),
#  sinter.TaskStats(strong_id='c7890a205004668ec56fde20c1f9d32a459d9075df548cd8a75c7b41ff376d59', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 5, 'type': 'Surface'}, shots=69154, errors=662, seconds=0.264),
#  sinter.TaskStats(strong_id='aeed2a3d08dcdaa33178348cd8fde0f6eb3e7da6d154ece000185c315f5a38e8', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.046415888336127774, 'p_sh': 0.046415888336127774, 'rounds': 7, 'type': 'Surface'}, shots=1297, errors=643, seconds=0.13),
#  sinter.TaskStats(strong_id='ca481f0f47cc97527e39845fa44254422b9fa1871f18b22c03842e089d8cde6b', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.1, 'p_sh': 0.1, 'rounds': 7, 'type': 'Surface'}, shots=1297, errors=650, seconds=0.167),
#  sinter.TaskStats(strong_id='5ac74edb385ce50a6b6a0ae14a941c358224eb0447299fe97dc3bfbde3b45a55', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 9, 'type': 'Surface'}, shots=102468, errors=545, seconds=1.9989999999999999),
#  sinter.TaskStats(strong_id='e6d40bf22b144bba83f2004224b19cfd45f7923b30af2dd8c2634f603ddd651a', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.021544346900318832, 'p_sh': 0.021544346900318832, 'rounds': 7, 'type': 'Surface'}, shots=1297, errors=547, seconds=0.08),
#  sinter.TaskStats(strong_id='abe3a6aa544a783a5b88ffd252207b9063a61e538816a286fba52793d9d2b13d', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 7, 'type': 'Surface'}, shots=77619, errors=586, seconds=0.7050000000000002),
#  sinter.TaskStats(strong_id='0afaf8d68767244cf6f6f0de395faf9155fadd9c4574a94d442fceb920fe5566', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 7, 'type': 'Surface'}, shots=1847910, errors=555, seconds=9.075000000000001),
#  sinter.TaskStats(strong_id='2374b966814a05219e87323b9ca5de75b68fa76ccb4c27177a600b2bd6d69f46', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 11, 'type': 'Surface'}, shots=6690, errors=1251, seconds=1.167),
#  sinter.TaskStats(strong_id='aa02fc72cc3d13b670715196338c0c1ba97c2266870c2ab712ed2fb026ab64ce', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.1, 'p_sh': 0.1, 'rounds': 5, 'type': 'Surface'}, shots=1297, errors=604, seconds=0.066),
#  sinter.TaskStats(strong_id='a772d00f265aef15358da633b09933a05d296e11b0aaaca1801bb89129cc96d6', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 7, 'type': 'Surface'}, shots=10000000, errors=123, seconds=27.326000000000015),
#  sinter.TaskStats(strong_id='85c8f809e78b08c2d23b1719d26cfd6869d7b6f4a69a2560f2cfc05fada6fda5', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 3, 'decoder': 'pymatching', 'k': 1, 'n': 9, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 3, 'type': 'Surface'}, shots=216610, errors=637, seconds=0.082),
#  sinter.TaskStats(strong_id='67703383c70641356f8d5a41208460d206f37d04666d1c8851e701901cac43f6', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 7, 'decoder': 'pymatching', 'k': 1, 'n': 49, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 7, 'type': 'Surface'}, shots=6690, errors=744, seconds=0.182),
#  sinter.TaskStats(strong_id='e131d7abcf413c295edb1f38d75b0a75e9e9e2d4b6e2ea354027408613f1ef0a', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 5, 'decoder': 'pymatching', 'k': 1, 'n': 25, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 5, 'type': 'Surface'}, shots=591667, errors=586, seconds=0.9600000000000001),
#  sinter.TaskStats(strong_id='4ce93a6fd4f290e53708c75d64c27a692431d21c80b780244b512fbf7a1f3bf2', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.046415888336127774, 'p_sh': 0.046415888336127774, 'rounds': 9, 'type': 'Surface'}, shots=1297, errors=643, seconds=0.365),
#  sinter.TaskStats(strong_id='ad222eebe471a8fbacd2135f5cdf83bc5206907c4d8164c03f18d404cf078a7f', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.1, 'p_sh': 0.1, 'rounds': 9, 'type': 'Surface'}, shots=1297, errors=629, seconds=0.46399999999999997),
#  sinter.TaskStats(strong_id='75f8db7cb19857e60769f2af7015d4bf5d12edbac4986718a4e1ceda2e75e687', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 9, 'type': 'Surface'}, shots=4642, errors=692, seconds=0.38),
#  sinter.TaskStats(strong_id='d6d3a8279efb3f628f04d43b6d43aba4a1da4b6ce981f91133f157471683e0f2', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 9, 'type': 'Surface'}, shots=7161309, errors=586, seconds=63.46899999999998),
#  sinter.TaskStats(strong_id='d8b99aceb49690254312b76ead363a039ab14fcd523cbf1f9ab647dfb00c3ec5', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 9, 'type': 'Surface'}, shots=10000000, errors=7, seconds=49.68499999999997),
#  sinter.TaskStats(strong_id='e72a1b41b5caf8538af04e99d720943aa8a3d66ceb6c7525d8fbfda8876199ef', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.021544346900318832, 'p_sh': 0.021544346900318832, 'rounds': 11, 'type': 'Surface'}, shots=2594, errors=1291, seconds=1.041),
#  sinter.TaskStats(strong_id='b8ef3dfca3668abc4a898fbb7a44c866121de4decc1d019820785c9723dd81d9', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 11, 'type': 'Surface'}, shots=10000000, errors=203, seconds=171.5820000000001),
#  sinter.TaskStats(strong_id='7e8a435f420fe62d7b31ddedeeb15af4712b91e52668552c30adb141aab081cd', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 11, 'type': 'Surface'}, shots=10000000, errors=3, seconds=95.48500000000004),
#  sinter.TaskStats(strong_id='5add16175637c7e3c375f9dc07aeb2932e5578817783888ec36327bcfe0bbb87', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.046415888336127774, 'p_sh': 0.046415888336127774, 'rounds': 11, 'type': 'Surface'}, shots=2594, errors=1308, seconds=1.607),
#  sinter.TaskStats(strong_id='73776d11eb6a6f97bb289378e7df765b68dc83c9208aa6e2aff68220d12476ad', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.1, 'p_sh': 0.1, 'rounds': 11, 'type': 'Surface'}, shots=2594, errors=1268, seconds=1.95),
#  sinter.TaskStats(strong_id='86092d9e73f8007ee73e8d359e6d7bb1c460362badecb633c4e534ebbcd3bf39', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 11, 'decoder': 'pymatching', 'k': 1, 'n': 121, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 11, 'type': 'Surface'}, shots=191351, errors=622, seconds=8.908000000000003),
#  sinter.TaskStats(strong_id='9ae3d7019147e8fc47196a7a84f85cd0f25dc9da68435c25ba13758240eba899', decoder='pymatching', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 9, 'decoder': 'pymatching', 'k': 1, 'n': 81, 'p_g': 0.021544346900318832, 'p_sh': 0.021544346900318832, 'rounds': 9, 'type': 'Surface'}, shots=1297, errors=638, seconds=0.244),
#  sinter.TaskStats(strong_id='ef70991308b94fc3b9431faeba935ed864811836c1ba6100c5eb5afa2ae86869', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 4, 'decoder': 'bposd', 'k': 18, 'n': 98, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 4, 'type': 'Simplex'}, shots=10313, errors=101, seconds=177.51999999999998),
#  sinter.TaskStats(strong_id='78ea8bc4416544bbea146204fad810094bb48a829d9bc1ee5e6bd4046ed47e95', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 4, 'decoder': 'bposd', 'k': 18, 'n': 98, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 4, 'type': 'Simplex'}, shots=105, errors=104, seconds=10.361),
#  sinter.TaskStats(strong_id='1d25f91180a22365515c735fa2f5e9e1071254e5cd7c520008cdd90976b6653d', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.006812920690579608, 'p_sh': 0.006812920690579608, 'rounds': 12, 'type': 'Tile'}, shots=104, errors=100, seconds=166.26),
#  sinter.TaskStats(strong_id='ff822a8055f10fa25b13a6da093a8d70263582faed1ab5b661fa1fed85d07b03', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 12, 'type': 'Tile'}, shots=7966, errors=16, seconds=14377.124999999995),
#  sinter.TaskStats(strong_id='cbf69fc64c63dd5bb20631eedb56f4b3453727bd1e068c3a53878c626640654e', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 4, 'decoder': 'bposd', 'k': 18, 'n': 98, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 4, 'type': 'Simplex'}, shots=1589, errors=100, seconds=55.693999999999996),
#  sinter.TaskStats(strong_id='2bac51881944471d93b6de7be9d6da8b54305f075bc8b1bc80c7eb3740f678a6', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 12, 'type': 'Tile'}, shots=362, errors=100, seconds=557.84),
#  sinter.TaskStats(strong_id='65f17fe4ad475690621831a5add4db970182251e7841a19fbc984971aa0c6a62', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 4, 'decoder': 'bposd', 'k': 18, 'n': 98, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 4, 'type': 'Simplex'}, shots=293, errors=100, seconds=23.067999999999998),
#  sinter.TaskStats(strong_id='9bead85f80c47ec2e775f3768100acb8617c397e554ac1eb67ca0c71937110c4', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 4, 'decoder': 'bposd', 'k': 18, 'n': 98, 'p_g': 0.006812920690579608, 'p_sh': 0.006812920690579608, 'rounds': 4, 'type': 'Simplex'}, shots=145, errors=103, seconds=14.604999999999999),
#  sinter.TaskStats(strong_id='1bfa4d365468fbd6620b8fe20dc84b664b36496eff0c883ee47328d9808b764e', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.0031622776601683794, 'p_sh': 0.0031622776601683794, 'rounds': 12, 'type': 'Tile'}, shots=5063, errors=100, seconds=8643.939000000002),
#  sinter.TaskStats(strong_id='ae66ff62edfa2f7b6a1556b81d59855d9d6efde6df6bc002cb54a63083805ac0', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 4, 'decoder': 'bposd', 'k': 18, 'n': 98, 'p_g': 0.0031622776601683794, 'p_sh': 0.0031622776601683794, 'rounds': 4, 'type': 'Simplex'}, shots=709, errors=101, seconds=37.873),
#  sinter.TaskStats(strong_id='b2d3df04afae939daef4c3ac0ede0f9c8cc8c62b1ed4275fcc0a78ea053adc6c', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 4, 'decoder': 'bposd', 'k': 18, 'n': 98, 'p_g': 0.001467799267622069, 'p_sh': 0.001467799267622069, 'rounds': 4, 'type': 'Simplex'}, shots=3905, errors=101, seconds=88.323),
#  sinter.TaskStats(strong_id='5ec39e6a17f55c8fdef7d7346a9947cd8a6ab914626755d7de2433d778fdfea5', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001467799267622069, 'p_sh': 0.001467799267622069, 'rounds': 12, 'type': 'Tile'}, shots=9221, errors=1, seconds=14402.450000000003),
#  sinter.TaskStats(strong_id='3e6b0cb32fff84b2106169a976074b851b56251943916c7bbc2b058b5002c1f2', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 12, 'type': 'Tile'}, shots=100, errors=100, seconds=184.76),
#  sinter.TaskStats(strong_id='13765fd689814323f05f5c67a95e65d5e7834fb12771b432a3b5f8333387cba1', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 12, 'type': 'Tile'}, shots=11351, seconds=14803.539999999997),
#  sinter.TaskStats(strong_id='c9fd0d3fdd5df80b91191a9e6f05f0964189d2ff3e26779ea90efff15aa4534c', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 13, 'decoder': 'bposd', 'k': 18, 'n': 288, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 13, 'type': 'Tile'}, shots=100, errors=100, seconds=223.73999999999998),
#  sinter.TaskStats(strong_id='18507f6258d39c453441e3e1d41d47959c955aa79365d9a6184543103f706588', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 13, 'decoder': 'bposd', 'k': 18, 'n': 288, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 13, 'type': 'Tile'}, shots=1638, errors=100, seconds=2671.1800000000003),
#  sinter.TaskStats(strong_id='3c098978c12d02d12f2c5e9af74b1d55ec1a0c83319e522a4aa8b0fe50d96f48', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 14, 'type': 'Tile'}, shots=4199, seconds=14428.620000000004),
#  sinter.TaskStats(strong_id='e3126eb90ade82758a11529cf709c7a73b3f36b6007e72336408aab7c2a721d2', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 13, 'decoder': 'bposd', 'k': 18, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 13, 'type': 'Tile'}, shots=5473, errors=3, seconds=14421.520000000006),
#  sinter.TaskStats(strong_id='ff9ef87faf956bf2e8f3bc629e431946336327494fd42833cebf15b572ad91ad', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 13, 'decoder': 'bposd', 'k': 18, 'n': 288, 'p_g': 0.0031622776601683794, 'p_sh': 0.0031622776601683794, 'rounds': 13, 'type': 'Tile'}, shots=195, errors=100, seconds=362.46),
#  sinter.TaskStats(strong_id='40a4c24983ed2e05494804ad6d5418d4dafc87b65309d14e89e75ed804e77a8d', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 13, 'decoder': 'bposd', 'k': 18, 'n': 288, 'p_g': 0.001467799267622069, 'p_sh': 0.001467799267622069, 'rounds': 13, 'type': 'Tile'}, shots=5246, errors=47, seconds=14386.460000000006),
#  sinter.TaskStats(strong_id='13c8e0062c7e6befd2f0eb6024cd4cbeff9deba0445c113406c1a9278e1ee83a', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 13, 'decoder': 'bposd', 'k': 18, 'n': 288, 'p_g': 0.006812920690579608, 'p_sh': 0.006812920690579608, 'rounds': 13, 'type': 'Tile'}, shots=100, errors=100, seconds=320.8),
#  sinter.TaskStats(strong_id='212c8389b65c146e493c63400e61f9ba97ae841d9054fa2e602660c263428c07', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.001467799267622069, 'p_sh': 0.001467799267622069, 'rounds': 14, 'type': 'Tile'}, shots=3394, errors=10, seconds=14458.86000000001),
#  sinter.TaskStats(strong_id='aa7d077f7ad97b523e11f40f5eba6599b0ef846ba40d0bbd77f2751bead02cd4', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 14, 'type': 'Tile'}, shots=1885, errors=100, seconds=8336.6),
#  sinter.TaskStats(strong_id='d31ff8ec858a095e8a8f79ef692916438c4152359b4287c7eef5a111b0e8c650', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.0031622776601683794, 'p_sh': 0.0031622776601683794, 'rounds': 14, 'type': 'Tile'}, shots=271, errors=100, seconds=1365.5700000000002),
#  sinter.TaskStats(strong_id='519a52c5416f1b9c019ca60fda5d3a31487c852e40730de2bdfab8d20f27bb18', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 13, 'decoder': 'bposd', 'k': 18, 'n': 288, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 13, 'type': 'Tile'}, shots=100, errors=100, seconds=495.95),
#  sinter.TaskStats(strong_id='90e95132d0067487e92ce71be846812ac385cae33398bdb65c71fc897844bf80', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 14, 'type': 'Tile'}, shots=103, errors=100, seconds=689.9300000000001),
#  sinter.TaskStats(strong_id='06eaa7d1669586e559bc90b80bdce821e86bf3bc991e06887de6123c9dcad990', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.006812920690579608, 'p_sh': 0.006812920690579608, 'rounds': 14, 'type': 'Tile'}, shots=101, errors=100, seconds=745.74),
#  sinter.TaskStats(strong_id='77c99eb6b4f35566c997697b12ac0f95dcd074d5525b1c9ee779d0e271576d45', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 288, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 14, 'type': 'Tile'}, shots=100, errors=100, seconds=915.4699999999999),
#  sinter.TaskStats(strong_id='9cdb6d41d803c9ee0e73fd0dacda2b762072d68dfac0fa1a307690b0a5d0e165', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 8, 'decoder': 'bposd', 'k': 32, 'n': 450, 'p_g': 0.001467799267622069, 'p_sh': 0.001467799267622069, 'rounds': 8, 'type': 'Simplex'}, shots=2518, errors=3, seconds=14470.429999999998),
#  sinter.TaskStats(strong_id='4e6b4cc81d082c7223ce9a97c914f2c2d01103ebcaa02c9fcfd04a196651b5ab', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 8, 'decoder': 'bposd', 'k': 32, 'n': 450, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 8, 'type': 'Simplex'}, shots=3089, seconds=14455.892999999996),
#  sinter.TaskStats(strong_id='eb4ad63b346a4c1fdf2a64df709eed85a110d84e23b69cf914caba11d8fe1809', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 8, 'decoder': 'bposd', 'k': 32, 'n': 450, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 8, 'type': 'Simplex'}, shots=111, errors=100, seconds=1113.5),
#  sinter.TaskStats(strong_id='cbb2ec8f046b2e0c34ad3f7e1ea4f5fb391b3a532c56bd2f0847bd2f522e3e22', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 8, 'decoder': 'bposd', 'k': 32, 'n': 450, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 8, 'type': 'Simplex'}, shots=2293, errors=28, seconds=14387.679000000006),
#  sinter.TaskStats(strong_id='5552f042f898e39d51dbdf260f4028521c89785cce62b1f154eb7026cbcbe1c4', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 8, 'decoder': 'bposd', 'k': 32, 'n': 450, 'p_g': 0.0031622776601683794, 'p_sh': 0.0031622776601683794, 'rounds': 8, 'type': 'Simplex'}, shots=595, errors=100, seconds=5210.94),
#  sinter.TaskStats(strong_id='da9566b66644dc1f5746b875be8baceb4e4c0879097d28248ef16fca6da7c2c6', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 6, 'decoder': 'bposd', 'k': 12, 'n': 72, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 6, 'type': 'BB'}, shots=20000, errors=46, seconds=375.09900000000005),
#  sinter.TaskStats(strong_id='72e2a82e3bc2f50b0658c145683d2cd7d2fc4bfab48615f6dc0920d2e7e2498e', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 19, 'decoder': 'bposd', 'k': 18, 'n': 512, 'p_g': 0.001467799267622069, 'p_sh': 0.001467799267622069, 'rounds': 19, 'type': 'Tile'}, shots=644, errors=1, seconds=14369.400000000001),
#  sinter.TaskStats(strong_id='cbabc873974ec9791b82ac9796641e2aaf264c2227261b2b883c7cf597bfc743', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 19, 'decoder': 'bposd', 'k': 18, 'n': 512, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 19, 'type': 'Tile'}, shots=704, seconds=14415.299999999992),
#  sinter.TaskStats(strong_id='ab9d3e7308133f6a97362c13e33e0ba6f71016c002a3848fe9107a1a7322e9c8', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 8, 'decoder': 'bposd', 'k': 32, 'n': 450, 'p_g': 0.006812920690579608, 'p_sh': 0.006812920690579608, 'rounds': 8, 'type': 'Simplex'}, shots=100, errors=100, seconds=1196.0800000000002),
#  sinter.TaskStats(strong_id='ec1d9e7ef29b46168064c7d5d46c12ffae5e02bbef248bb498e9b21e3b841a75', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 19, 'decoder': 'bposd', 'k': 18, 'n': 512, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 19, 'type': 'Tile'}, shots=683, errors=17, seconds=14411.600000000006),
#  sinter.TaskStats(strong_id='94c15b14dc785855d8bd4b07a0d027e9745ccf3afe629b93724975272f5cb4a1', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 8, 'decoder': 'bposd', 'k': 32, 'n': 450, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 8, 'type': 'Simplex'}, shots=100, errors=100, seconds=1315.9000000000003),
#  sinter.TaskStats(strong_id='2fcc918790a2da0f11d2d1fb88d63f5bf6a2b5a868adf17f81c758a17c54d797', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 6, 'decoder': 'bposd', 'k': 12, 'n': 72, 'p_g': 0.001467799267622069, 'p_sh': 0.001467799267622069, 'rounds': 6, 'type': 'BB'}, shots=16241, errors=100, seconds=438.88),
#  sinter.TaskStats(strong_id='7a567d7a8c558f9e03e510f7e53ca39e168531d6876db21e4dfc808007b77d2f', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 19, 'decoder': 'bposd', 'k': 18, 'n': 512, 'p_g': 0.0031622776601683794, 'p_sh': 0.0031622776601683794, 'rounds': 19, 'type': 'Tile'}, shots=137, errors=100, seconds=6200.199999999999),
#  sinter.TaskStats(strong_id='b8d67e9d24dd6784df52794c9674d50e12d262a8d36fc24ca09d322299a2ef9b', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 6, 'decoder': 'bposd', 'k': 12, 'n': 72, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 6, 'type': 'BB'}, shots=4769, errors=100, seconds=206.96599999999998),
#  sinter.TaskStats(strong_id='98426a79fb6293f07f20d01646a2d36879da23eb88260b2e4255791d12563f01', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 6, 'decoder': 'bposd', 'k': 12, 'n': 72, 'p_g': 0.0031622776601683794, 'p_sh': 0.0031622776601683794, 'rounds': 6, 'type': 'BB'}, shots=913, errors=100, seconds=63.862999999999985),
#  sinter.TaskStats(strong_id='86156b66d3c34ddcabf044c7322149245371d263cd3cb6e0011b35b6f32d3542', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 6, 'decoder': 'bposd', 'k': 12, 'n': 72, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 6, 'type': 'BB'}, shots=313, errors=103, seconds=31.835),
#  sinter.TaskStats(strong_id='5ab35e8538c38558bde5cbaaac41c84bd5a0c6661db811b83bea2cf3cd926faf', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 6, 'decoder': 'bposd', 'k': 12, 'n': 72, 'p_g': 0.006812920690579608, 'p_sh': 0.006812920690579608, 'rounds': 6, 'type': 'BB'}, shots=145, errors=102, seconds=16.372),
#  sinter.TaskStats(strong_id='508d3c8d669b0e78462415909932d05dd543b98fd2b1910e81232a7ca4423c46', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 19, 'decoder': 'bposd', 'k': 18, 'n': 512, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 19, 'type': 'Tile'}, shots=100, errors=100, seconds=9594.499999999998),
#  sinter.TaskStats(strong_id='9e0b8eb746c0c224f170079a1537623a93e510c6241478cb81890b46f58abf06', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 6, 'decoder': 'bposd', 'k': 12, 'n': 72, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 6, 'type': 'BB'}, shots=105, errors=103, seconds=12.914),
#  sinter.TaskStats(strong_id='f2c78381473990df995e89a74922dc137c6ea33c7da5a94a74697b6cf260f886', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 12, 'n': 144, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 12, 'type': 'BB'}, shots=20000, errors=3, seconds=11666.523000000003),
#  sinter.TaskStats(strong_id='8907d007005970d613cf81bc6c4b493833571b73121f9be2842f5ee3dd9603d2', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 12, 'n': 144, 'p_g': 0.001467799267622069, 'p_sh': 0.001467799267622069, 'rounds': 12, 'type': 'BB'}, shots=18116, errors=14, seconds=14299.012000000002),
#  sinter.TaskStats(strong_id='2513ed5bc26a39b10817bd7c7f4dd36df6e5cac79bf46e8f1deab503d1be0c58', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 12, 'n': 144, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 12, 'type': 'BB'}, shots=9616, errors=100, seconds=9813.679999999998),
#  sinter.TaskStats(strong_id='f373e29861ba28e817d9fca493c0c83bceb628cfe6ac00b745eccf69e02f0a54', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 12, 'n': 144, 'p_g': 0.0031622776601683794, 'p_sh': 0.0031622776601683794, 'rounds': 12, 'type': 'BB'}, shots=720, errors=100, seconds=883.0799999999999),
#  sinter.TaskStats(strong_id='e9463b0e7b676af1841f91c54f3e213c1b8dd8d134876e161b740b429f3ec58f', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 12, 'n': 144, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 12, 'type': 'BB'}, shots=123, errors=100, seconds=114.795),
#  sinter.TaskStats(strong_id='90308916ac14696ab992f71da24ee08b28db21e297a757f6162448cd067cebbc', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 12, 'n': 144, 'p_g': 0.006812920690579608, 'p_sh': 0.006812920690579608, 'rounds': 12, 'type': 'BB'}, shots=100, errors=100, seconds=151.49999999999997),
#  sinter.TaskStats(strong_id='438e173903b897d37101a8b6967cc2acbb50912a7c5471571e74bdd064f7e5fe', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 19, 'decoder': 'bposd', 'k': 18, 'n': 512, 'p_g': 0.006812920690579608, 'p_sh': 0.006812920690579608, 'rounds': 19, 'type': 'Tile'}, shots=75, errors=75, seconds=14357.800000000001),
#  sinter.TaskStats(strong_id='18f1e3cabd678d9de18d528cde116d445d6b38b5314059371d35bd24fd78615e', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 19, 'decoder': 'bposd', 'k': 18, 'n': 512, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 19, 'type': 'Tile'}, shots=43, errors=43, seconds=14389.600000000002),
#  sinter.TaskStats(strong_id='315b525d1bfb282a11f62041e8e2d52623101ef2762a388a378bc7ab74739e3c', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 12, 'n': 144, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 12, 'type': 'BB'}, shots=100, errors=100, seconds=124.79599999999999),
#  sinter.TaskStats(strong_id='e578d5c54a76065df8400410951e5318ca81575c7339105a0a17474e5dc23708', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 18, 'type': 'BB'}, shots=1556, seconds=14014.560000000003),
#  sinter.TaskStats(strong_id='e1cdf56af427c1c1e49e7a89c269b00bcca5ad3fd6daa7abe981af63449d9d78', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001467799267622069, 'p_sh': 0.001467799267622069, 'rounds': 18, 'type': 'BB'}, shots=1419, seconds=14005.509999999995),
#  sinter.TaskStats(strong_id='13b34cee9314c68d0966265a77282eac654e3ec533484cb1449140aa6a3c7138', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 18, 'type': 'BB'}, shots=790, errors=5, seconds=14058.900000000003),
#  sinter.TaskStats(strong_id='bb195c9c13abf89f41448acfa9172579120230ea6d7875c39ae9f8a57656e374', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.0031622776601683794, 'p_sh': 0.0031622776601683794, 'rounds': 18, 'type': 'BB'}, shots=238, errors=100, seconds=4826.600000000001),
#  sinter.TaskStats(strong_id='078568797764589a111419d2248c9ee2f80151aa43b8491b805186e109cd6646', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 18, 'type': 'BB'}, shots=100, errors=100, seconds=1552.3999999999999),
#  sinter.TaskStats(strong_id='c6bf36bb1aae0e50dfcd006734bd1654864f6f3acf2d9c598a7af2effcba2f71', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.006812920690579608, 'p_sh': 0.006812920690579608, 'rounds': 18, 'type': 'BB'}, shots=100, errors=100, seconds=3169.5),
#  sinter.TaskStats(strong_id='006f8a29d2ed6bd1491cd9a8879b048ec08c19a07bdee62247824af1ebe908e5', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 18, 'type': 'BB'}, shots=100, errors=100, seconds=2228.0),
#  sinter.TaskStats(strong_id='1bef887d729872df84cd6dab6806b90cce3380c73dd135a530caebc9d7aaab20', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 144, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 12, 'type': 'Radial'}, shots=20000, seconds=9344.650999999998),
#  sinter.TaskStats(strong_id='c48cf8895e021069b816403c7d6ee652e2a54ffdbc674d677d7fd9e995851487', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 144, 'p_g': 0.001467799267622069, 'p_sh': 0.001467799267622069, 'rounds': 12, 'type': 'Radial'}, shots=20000, errors=5, seconds=13282.586000000007),
#  sinter.TaskStats(strong_id='81fedaa84509579a1bcac2367cbebe5dd93a2228a9f7ddeff40d67b57a77bf86', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 144, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 12, 'type': 'Radial'}, shots=15257, errors=45, seconds=13704.403999999997),
#  sinter.TaskStats(strong_id='c51bdc6c32bdffc194a40c431ca6c37a65f8c27672f46a3c69169fa936ef3738', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 144, 'p_g': 0.0031622776601683794, 'p_sh': 0.0031622776601683794, 'rounds': 12, 'type': 'Radial'}, shots=1374, errors=100, seconds=1479.862),
#  sinter.TaskStats(strong_id='ca2ccd20160b495cb0f59720bfabec36aab3bbac49519a7bf2141a97f5d5909e', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 144, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 12, 'type': 'Radial'}, shots=145, errors=100, seconds=177.358),
#  sinter.TaskStats(strong_id='542bee0bda3c6963979928770f585bc90a1694faf144196bb48ffad254973808', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 144, 'p_g': 0.006812920690579608, 'p_sh': 0.006812920690579608, 'rounds': 12, 'type': 'Radial'}, shots=100, errors=100, seconds=152.55),
#  sinter.TaskStats(strong_id='5f4163aebeb7b23725cac097061ca87285f906d3386f80036dc1c638b1f07111', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 8, 'n': 144, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 12, 'type': 'Radial'}, shots=100, errors=100, seconds=176.95),
#  sinter.TaskStats(strong_id='159531ab6648e04170aa7a49db13d7cbfb24171e3e3c06a37ac65731b23f0066', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 14, 'type': 'Radial'}, shots=8795, seconds=13198.089999999995),
#  sinter.TaskStats(strong_id='f934a4788535a7797e5ee2ca7cb9b7b2e9cb0e3db05d812c3b7a4231939d49db', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.001467799267622069, 'p_sh': 0.001467799267622069, 'rounds': 14, 'type': 'Radial'}, shots=5724, seconds=13115.35),
#  sinter.TaskStats(strong_id='8fa1cf25ea0d14a172f0fe4c53e2e04bc66391b15b2899bae5a2b61b61345d6c', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 14, 'type': 'Radial'}, shots=4983, errors=4, seconds=13008.609999999999),
#  sinter.TaskStats(strong_id='e57a5d919281914208bb1d0a0916150c691d74b1290f225157b235cd2d0b0291', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.0031622776601683794, 'p_sh': 0.0031622776601683794, 'rounds': 14, 'type': 'Radial'}, shots=692, errors=100, seconds=1902.4),
#  sinter.TaskStats(strong_id='b4f0c07b1f6dda7683774f10236f19b8b83121a79e04508c3495bc16a1dd1524', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 14, 'type': 'Radial'}, shots=108, errors=100, seconds=382.04),
#  sinter.TaskStats(strong_id='1953aa4ebfd0e9de423c1473faf189a0ee00d4d249365d87412c8dae24aa945e', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.006812920690579608, 'p_sh': 0.006812920690579608, 'rounds': 14, 'type': 'Radial'}, shots=102, errors=100, seconds=419.72),
#  sinter.TaskStats(strong_id='b7dc28173b9e5b5ec231e314833cf0f0127705b7bfe07d2872d05b86a93f11d5', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 14, 'decoder': 'bposd', 'k': 8, 'n': 198, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 14, 'type': 'Radial'}, shots=102, errors=100, seconds=358.18000000000006),
#  sinter.TaskStats(strong_id='b221267661d0c09a12566c07dba822cbf23b42dd3879593faea5adb8d6b5a6c7', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 18, 'n': 192, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 12, 'type': 'Radial'}, shots=1583, errors=5, seconds=12289.873000000001),
#  sinter.TaskStats(strong_id='784ad248f5d3a985b4adce0961971b28ca7d82b7e45970cf62140cc205c94bd3', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 18, 'n': 192, 'p_g': 0.001467799267622069, 'p_sh': 0.001467799267622069, 'rounds': 12, 'type': 'Radial'}, shots=1527, errors=19, seconds=12053.884),
#  sinter.TaskStats(strong_id='57448eb3fb7d84224476d968375d56bdb1a1e4a527fad791a010faa384ae50ab', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 18, 'n': 192, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 12, 'type': 'Radial'}, shots=633, errors=100, seconds=8003.500000000001),
#  sinter.TaskStats(strong_id='3c30eb0076a1035843da31dc7db13cda475d33b1f17f6a740d95291a61e4fe45', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 18, 'n': 192, 'p_g': 0.0031622776601683794, 'p_sh': 0.0031622776601683794, 'rounds': 12, 'type': 'Radial'}, shots=124, errors=100, seconds=1519.0799999999997),
#  sinter.TaskStats(strong_id='933612b8fab7a44be39411d51d1333ed2597504317ff1659c5db8810650240e8', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 18, 'n': 192, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 12, 'type': 'Radial'}, shots=100, errors=100, seconds=1995.3),
#  sinter.TaskStats(strong_id='da3e879efc6dfe9510b001f62522bd6a0c305a5e8913d903fbc565e7de33f409', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 18, 'n': 192, 'p_g': 0.006812920690579608, 'p_sh': 0.006812920690579608, 'rounds': 12, 'type': 'Radial'}, shots=100, errors=100, seconds=3362.8),
#  sinter.TaskStats(strong_id='af8cf1a57c4f082f4a9d89e959976c025ebe4054c70f5a7ff7dbb7d59c5d98a3', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 12, 'decoder': 'bposd', 'k': 18, 'n': 192, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 12, 'type': 'Radial'}, shots=100, errors=100, seconds=4416.6),
#  sinter.TaskStats(strong_id='497c9258b881d279ea87c94e932c55eab9a955f2dc9a7a5a3f3b8f8163849611', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 16, 'decoder': 'bposd', 'k': 18, 'n': 256, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 16, 'type': 'Radial'}, shots=228, seconds=10200.347000000002),
#  sinter.TaskStats(strong_id='35b3bf1fc427840293b88b2698d58f5e90eb008457b9062c8d339828d936355d', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 16, 'decoder': 'bposd', 'k': 18, 'n': 256, 'p_g': 0.001467799267622069, 'p_sh': 0.001467799267622069, 'rounds': 16, 'type': 'Radial'}, shots=192, errors=1, seconds=9622.199999999999),
#  sinter.TaskStats(strong_id='0c00351b827b1a8294cca1f968900735d22d6fa8418256314194820b7c8fbc95', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 16, 'decoder': 'bposd', 'k': 18, 'n': 256, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 16, 'type': 'Radial'}, shots=152, errors=22, seconds=9229.300000000001),
#  sinter.TaskStats(strong_id='41bdc0d1a5f6c6d7944b2ee2c53b84d297e7d1ca39ada5e975119786921ba641', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 16, 'decoder': 'bposd', 'k': 18, 'n': 256, 'p_g': 0.0031622776601683794, 'p_sh': 0.0031622776601683794, 'rounds': 16, 'type': 'Radial'}, shots=89, errors=87, seconds=9138.800000000001),
#  sinter.TaskStats(strong_id='ae71aaa59ee710d194304da5dd5555d44d3e19e878922454f551f7948f3f9cf9', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 16, 'decoder': 'bposd', 'k': 18, 'n': 256, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 16, 'type': 'Radial'}, shots=39, errors=39, seconds=8108.099999999999),
#  sinter.TaskStats(strong_id='8912182fce0fc40b36c360649fed6916e43b09df175d1c5511dec4dc26c1dca6', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 16, 'decoder': 'bposd', 'k': 18, 'n': 256, 'p_g': 0.006812920690579608, 'p_sh': 0.006812920690579608, 'rounds': 16, 'type': 'Radial'}, shots=36, errors=36, seconds=7804.5999999999985),
#  sinter.TaskStats(strong_id='b26e653be7e7060d597268cdfcf2b148bda0f63b7846c8b57e3ed811ded29d51', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 16, 'decoder': 'bposd', 'k': 18, 'n': 256, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 16, 'type': 'Radial'}, shots=19, errors=19, seconds=6182.2),
#  sinter.TaskStats(strong_id='d6e452358c43279c5d05f7357890879d82433e1d72b3ffa1903c784d6ae83e9c', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 20, 'type': 'Radial'}, shots=13, seconds=5875.499999999999),
#  sinter.TaskStats(strong_id='c20daf54e5c762ac8738077cfc2b3325713e3017872b4d4f5d206ccb83ffc157', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.001467799267622069, 'p_sh': 0.001467799267622069, 'rounds': 20, 'type': 'Radial'}, shots=18, seconds=5520.200000000001),
#  sinter.TaskStats(strong_id='ae8529717b68c16945e0daaf8bfe00382a6de9a62632baa254a1a3a6e69b306d', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 20, 'type': 'Radial'}, shots=9, errors=3, seconds=4658.8),
#  sinter.TaskStats(strong_id='a539e6268f36e0a9d30950cd0ce21d354122b61774145c5e151c741e14568872', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.0031622776601683794, 'p_sh': 0.0031622776601683794, 'rounds': 20, 'type': 'Radial'}, shots=4, errors=4, seconds=4392.0),
#  sinter.TaskStats(strong_id='9d6f6fc94f523d8995955a174a7adefc1fcb5fdd06b1d9aef6c350e125224924', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 20, 'type': 'Radial'}, shots=2, errors=2, seconds=3899.2),
#  sinter.TaskStats(strong_id='7b4e0f30fdcbb23df9af3988c6c5b37f999e47abfd8369424760324bff956b31', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.006812920690579608, 'p_sh': 0.006812920690579608, 'rounds': 20, 'type': 'Radial'}, shots=2, errors=2, seconds=4018.7),
#  sinter.TaskStats(strong_id='1875c2f05803ddf85d4d6950955a6b5c376d3ebe3a819404f6f84ab0f17dd697', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 20, 'decoder': 'bposd', 'k': 18, 'n': 352, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 20, 'type': 'Radial'}, shots=1, errors=1, seconds=1345.9)]

# %%
def logical_fit(p, a, b, c, d):
    return a*(p/b + c)**((d+1)/2)

def fixed_d_logical_fit(d):
    return lambda p,a,b,c: logical_fit(p,a,b,c,d)

p_upper_cutoffs = {
    ('Radial', (352, 18, 20)): 5e-3,
    ('Radial', (256,18,16)): 8e-3,
    ('Radial', (198, 8, 14)): 8e-3,
    ('BB', (288, 12, 18)): 6e-3,
}

fit_params = [(np.nan, np.nan, np.nan, np.nan) for _ in code_ids]
for i,(code_type,(n,k,d)) in enumerate(code_ids):
    ps = []
    lers = []
    uncertainties = []
    for stat in stats:
        if stat.shots == 0:
            continue
        jmd = stat.json_metadata
        if (jmd['type'], jmd['n'], jmd['k'], jmd['d']) == (code_type, n, k, d):
            p_sh = jmd['p_sh']

            cutoff = p_upper_cutoffs.get((code_type,(n,k,d)), float('inf'))
            if p_sh > cutoff:
                continue

            ler = stat.errors / stat.shots
            ler = sinter.shot_error_rate_to_piece_error_rate(ler, pieces=d, values=k)
            unc = np.sqrt(ler * (1 - ler) / stat.shots)
            if 0 < ler:
                if ler > 0.5:
                    ler = 0.5
                    unc = np.sqrt(ler * (1 - ler) / stat.shots)
                ps.append(p_sh)
                lers.append(ler)
                uncertainties.append(unc)
    if len(ps) < 3:
        print('Skipping', code_type, n, k, d, ps, lers)
        continue
    try:
        if code_type in ['Radial', 'BB']:
            bounds=([0, 0, 0, 0], [float('inf'), float('inf'), float('inf'), float('inf')])
            p0 = [0.5, 10, 1, d]
        else:
            bounds=([0, 0, 0, 0], [float('inf'), float('inf'), float('inf'), float('inf')])
            p0=[0.5, 0.1, 0.2, d]

        log_lers = np.log(np.array(lers))
        log_uncertainties = np.array(uncertainties) / np.array(lers)
        fit_params[i] = scipy.optimize.curve_fit(
            lambda p, a, b, c, d: np.log(logical_fit(p, a, b, c, d)), 
            ps, 
            log_lers, 
            sigma=log_uncertainties, 
            p0=p0, 
            bounds=bounds, 
            max_nfev=10000
        )[0]
        # fit_params[i] = scipy.optimize.curve_fit(fixed_d_logical_fit(d), ps, lers, sigma=uncertainties, p0=[1, 1, 0.001])[0]
    except Exception as e:
        print(e)
        continue
    
    print(code_type, n,k,d, fit_params[i], ps, lers, uncertainties)
# Out:
# Surface 9 1 3 [4.81794950e-01 9.02974456e-02 4.96501267e-18 2.25033502e+00] [0.004641588833612777, 0.01, 0.021544346900318832, 0.046415888336127774, 0.1, 0.001, 0.0021544346900318843] [0.0043592776296917934, 0.018560836247849766, 0.06977156222321829, 0.19040389340209057, 0.5, 0.00022839761715992557, 0.00098218448413262] [np.float64(0.0003328117605197559), np.float64(0.001385543733338428), np.float64(0.0044048991385696405), np.float64(0.00814956724398845), np.float64(0.013883533620176643), np.float64(1.614461786263501e-05), np.float64(6.73044686465938e-05)]
# Surface 25 1 5 [7.52018227e-02 3.05913148e-02 1.67425057e-16 3.04934078e+00] [0.001, 0.01, 0.021544346900318832, 0.046415888336127774, 0.004641588833612777, 0.1, 0.0021544346900318843] [2.0502841241165637e-05, 0.01743558452103189, 0.09932333616912009, 0.30085441641622795, 0.001929400483864696, 0.20740964191254457, 0.00019824153195102667] [np.float64(1.9201685953552523e-06), np.float64(0.0015173407424940496), np.float64(0.006208297704552202), np.float64(0.012734796717939655), np.float64(0.00016687188433252016), np.float64(0.011258197813431969), np.float64(1.8302718365769646e-05)]
# Surface 49 1 7 [7.58817019e-02 3.44324962e-02 1.46119364e-18 3.11154163e+00] [0.046415888336127774, 0.1, 0.021544346900318832, 0.004641588833612777, 0.0021544346900318843, 0.001, 0.01] [0.24705000389284065, 0.5, 0.11637527987618101, 0.001085573557896402, 4.291666406508465e-05, 1.7571613827316312e-06, 0.017650272835982195] [np.float64(0.01197582695919183), np.float64(0.013883533620176643), np.float64(0.008904187769697324), np.float64(0.0001181978969055674), np.float64(4.819070181102164e-06), np.float64(4.1918472003586993e-07), np.float64(0.0016098881997408424)]
# Surface 81 1 9 [2.62921230e-01 5.88664213e-02 2.77708089e-19 3.11976509e+00] [0.004641588833612777, 0.046415888336127774, 0.1, 0.01, 0.0021544346900318843, 0.001, 0.021544346900318832] [0.0005937832321293857, 0.205694700030231, 0.161255118930468, 0.019286608898670232, 9.092729772786079e-06, 7.77778261795703e-08, 0.18377147690344547] [np.float64(7.610108666351177e-05), np.float64(0.011223680440431124), np.float64(0.010211786074232908), np.float64(0.0020185821174097435), np.float64(1.1268055077221192e-06), np.float64(8.819173438037153e-08), np.float64(0.01075412173516082)]
# Surface 121 1 11 [3.96895491e-02 1.13959934e-02 3.49212279e-15 2.09152476e+00] [0.01, 0.021544346900318832, 0.0021544346900318843, 0.001, 0.046415888336127774, 0.1, 0.004641588833612777] [0.02084356223566186, 0.1932980877130296, 1.8454886033802964e-06, 2.7272734737238125e-08, 0.5, 0.14606726378329088, 0.0002963833195778198] [np.float64(0.001746622114685433), np.float64(0.007753277641513791), np.float64(4.2959110763051313e-07), np.float64(5.222330322129773e-08), np.float64(0.009817140769658322), np.float64(0.0069343106311945115), np.float64(3.93502179844971e-05)]
# Tile 288 8 12 [1.26530535e+01 2.02109250e-02 1.52164560e-34 7.42689258e+00] [0.006812920690579608, 0.0021544346900318843, 0.004641588833612777, 0.0031622776601683794, 0.001467799267622069, 0.01] [0.30240572061190785, 0.00016755160696035887, 0.027088099676520594, 0.001662920218629238, 9.037847691018008e-06, 0.5] [np.float64(0.04503807158234838), np.float64(0.00014501661424003967), np.float64(0.008532410509060475), np.float64(0.0005726250517800229), np.float64(3.1307005930919855e-05), np.float64(0.05)]
# Tile 288 8 14 [2.31005397e+01 5.22384773e-02 1.93064925e-15 3.21683745e+00] [0.001467799267622069, 0.0021544346900318843, 0.0031622776601683794, 0.004641588833612777, 0.006812920690579608, 0.01] [0.00021077996553942047, 0.003898312442080276, 0.03325690580424967, 0.2954184016032855, 0.43771087854222457, 0.5] [np.float64(0.00024917987893106), np.float64(0.0014352728928746599), np.float64(0.010892104866159389), np.float64(0.04495373777319327), np.float64(0.04936428192710192), np.float64(0.05)]
# Tile 288 18 13 [9.27833573e+00 3.84803624e-02 5.79902216e-17 2.53784275e+00] [0.004641588833612777, 0.0021544346900318843, 0.001, 0.0031622776601683794, 0.001467799267622069, 0.006812920690579608, 0.01] [0.5, 0.004841719270904377, 4.217629798131117e-05, 0.054819815181275766, 0.0006921956921182026, 0.5, 0.5] [np.float64(0.05), np.float64(0.0017150979755021307), np.float64(8.778338947746724e-05), np.float64(0.01630079485945654), np.float64(0.00036311981001361837), np.float64(0.05), np.float64(0.05)]
# Tile 512 18 19 [3.43842297e-01 4.25731719e-03 1.25847707e-13 5.55618158e-01] [0.001467799267622069, 0.0021544346900318843, 0.0031622776601683794, 0.004641588833612777, 0.006812920690579608, 0.01] [8.178957203996973e-05, 0.0013265893507620197, 0.06896541290123337, 0.5, 0.5, 0.5] [np.float64(0.0003563594443543648), np.float64(0.0013927387049368176), np.float64(0.021649022621622018), np.float64(0.05), np.float64(0.05773502691896258), np.float64(0.07624928516630233)]
# Simplex 98 18 4 [1.32978449e+00 1.46735665e-02 8.54002034e-15 3.61571371e+00] [0.001, 0.01, 0.0021544346900318843, 0.004641588833612777, 0.006812920690579608, 0.0031622776601683794, 0.001467799267622069] [0.002457913115333832, 0.5, 0.016140442784220776, 0.09994548462200425, 0.2726554953168082, 0.037810853606567774, 0.006533305884204754] [np.float64(0.00048759177218137337), np.float64(0.048795003647426664), np.float64(0.003161275372848237), np.float64(0.01752193990125906), np.float64(0.0369822395575511), np.float64(0.0071633364585766595), np.float64(0.0012892366199955536)]
# Simplex 450 32 8 [2.84184439e+01 5.30046369e-02 4.46714413e-15 3.35612661e+00] [0.001467799267622069, 0.004641588833612777, 0.0021544346900318843, 0.0031622776601683794, 0.006812920690579608, 0.01] [0.0001490078348981294, 0.2582932511517131, 0.0015348595873398985, 0.02279483274025118, 0.5, 0.5] [np.float64(0.00024324522870558738), np.float64(0.04154427222380151), np.float64(0.0008175206881882616), np.float64(0.006118607566728079), np.float64(0.05), np.float64(0.05)]
# BB 72 12 6 [2.07489259e-01 7.35154749e-03 1.76171289e-23 5.30379429e+00] [0.001, 0.001467799267622069, 0.0021544346900318843, 0.0031622776601683794, 0.004641588833612777, 0.006812920690579608, 0.01] [0.000383731889731731, 0.0010290727439135061, 0.003528318186632462, 0.019225551523947226, 0.06524372845617565, 0.19112403897062813, 0.5] [np.float64(0.00013848910418667128), np.float64(0.0002515898286042281), np.float64(0.0008586233425252781), np.float64(0.004544525936010794), np.float64(0.013958746196488965), np.float64(0.0326523633509315), np.float64(0.048795003647426664)]
# BB 144 12 12 [1.15232793e-01 5.39706184e-03 3.48557535e-15 5.67391355e+00] [0.001, 0.001467799267622069, 0.0021544346900318843, 0.0031622776601683794, 0.004641588833612777, 0.006812920690579608, 0.01] [1.2500931081849131e-05, 6.442451785415582e-05, 0.0008711172687554392, 0.012454833261785092, 0.1394166310448548, 0.5, 0.5] [np.float64(2.5000774796565025e-05), np.float64(5.963214651302507e-05), np.float64(0.0003008512644229006), np.float64(0.004133150263117546), np.float64(0.031232101740512705), np.float64(0.05), np.float64(0.05)]
# BB 288 12 18 [2.21492896e-01 4.16663281e-03 5.34163238e-09 1.41598173e+01] [0.0021544346900318843, 0.0031622776601683794, 0.004641588833612777] [0.00035276081513258006, 0.030484807628948563, 0.5] [np.float64(0.0006681131327490545), np.float64(0.01114372946729367), np.float64(0.05)]
# /tmp/ipykernel_3139300/2901240841.py:53: OptimizeWarning: Covariance of the parameters could not be estimated
#   fit_params[i] = scipy.optimize.curve_fit(
# Radial 144 8 12 [2.14445018e+00 1.31411850e-02 1.53289522e-17 5.62570788e+00] [0.001467799267622069, 0.0021544346900318843, 0.0031622776601683794, 0.004641588833612777, 0.006812920690579608, 0.01] [2.083601933933199e-05, 0.00024616337381255793, 0.0063046165091694695, 0.09983563510651883, 0.5, 0.5] [np.float64(3.2276605459395884e-05), np.float64(0.00012700583800335298), np.float64(0.0021353182268729525), np.float64(0.024895433879826352), np.float64(0.05), np.float64(0.05)]
# Radial 198 8 14 [1.62340903e-01 5.23835096e-03 1.52730966e-14 6.05215892e+00] [0.0021544346900318843, 0.0031622776601683794, 0.004641588833612777, 0.006812920690579608] [5.736185972715635e-05, 0.011188458863444883, 0.20408426998928653, 0.34079353278297864] [np.float64(0.00010728863295535953), np.float64(0.003998424048598066), np.float64(0.038781663375715106), np.float64(0.04693062263746302)]
# Radial 192 18 12 [8.32584266e-02 1.84242056e-03 4.26251332e-19 1.58387635e+00] [0.001, 0.001467799267622069, 0.0021544346900318843, 0.0031622776601683794, 0.004641588833612777, 0.006812920690579608, 0.01] [0.00026361636009475387, 0.0010431847741888545, 0.014289350262027267, 0.13337928401398413, 0.5, 0.5, 0.5] [np.float64(0.00040802659490992327), np.float64(0.0008261034928036362), np.float64(0.004717143740957409), np.float64(0.030531481717831828), np.float64(0.05), np.float64(0.05), np.float64(0.05)]
# Radial 256 18 16 [1.14080616e-01 1.88647371e-03 6.57949830e-18 1.64428263e+00] [0.001467799267622069, 0.0021544346900318843, 0.0031622776601683794, 0.004641588833612777, 0.006812920690579608] [0.000326362626477672, 0.009763785223697807, 0.23439484973649793, 0.5, 0.5] [np.float64(0.001303553065011385), np.float64(0.007975477927356993), np.float64(0.04490363016198966), np.float64(0.08006407690254357), np.float64(0.08333333333333333)]
# Radial 352 18 20 [1.82936813e-01 1.67609121e-03 2.52102270e-17 1.43245356e+00] [0.0021544346900318843, 0.0031622776601683794, 0.004641588833612777] [0.02028658362606106, 0.5, 0.5] [np.float64(0.04699295236858382), np.float64(0.25), np.float64(0.3535533905932738)]

# %%
fig,ax = plt.subplots()
# xs_test = np.geomspace(5e-4, 1e-3, 10)
# xs_test_surface = np.geomspace(5e-4, 4e-3, 10)
xs_test = np.geomspace(1e-4, 5e-1, 100)
xs_test_surface = np.geomspace(1e-4, 5e-1, 100)
for fp,code_id in zip(fit_params, code_ids):
    code_type,(n,k,d) = code_id
    print(fp)
    if code_type == 'Surface':
        plt.plot(xs_test_surface, logical_fit(xs_test_surface, *fp), 'k--', alpha=0.2)
    else:
        plt.plot(xs_test, logical_fit(xs_test, *fp), 'k--', alpha=0.2)
sinter.plot_error_rate(
    ax=ax,
    stats=stats,
    x_func=lambda s: s.json_metadata['p_sh'],
    group_func=lambda s: f"{s.json_metadata['type']} [[{s.json_metadata['n']}, {s.json_metadata['k']}, {s.json_metadata['d']}]]",
    failure_units_per_shot_func=lambda s: s.json_metadata['d'],
    failure_values_func=lambda s: s.json_metadata['k'],
    # highlight_max_likelihood_factor=None,
    filter_func=lambda s: s.json_metadata['p_sh'] < p_upper_cutoffs.get((s.json_metadata['type'], (s.json_metadata['n'], s.json_metadata['k'], s.json_metadata['d'])), float('inf')),
)

# plt.plot(xs_test, logical_fit(xs_test, 0.5, 0.01, 0.2, 10))

plt.legend(bbox_to_anchor=(1,1), loc='upper left')
plt.loglog()
plt.xlim(1e-4)
plt.ylim(1e-10, top=1)
plt.xlabel('Shuttle error ' + r'$p_\text{sh}$')
plt.ylabel('Idling logical error rate')
ax.grid(which='both', linewidth=0.5)
plt.show()
# Out:
# [4.81794950e-01 9.02974456e-02 4.96501267e-18 2.25033502e+00]
# [7.52018227e-02 3.05913148e-02 1.67425057e-16 3.04934078e+00]
# [7.58817019e-02 3.44324962e-02 1.46119364e-18 3.11154163e+00]
# [2.62921230e-01 5.88664213e-02 2.77708089e-19 3.11976509e+00]
# [3.96895491e-02 1.13959934e-02 3.49212279e-15 2.09152476e+00]
# [1.26530535e+01 2.02109250e-02 1.52164560e-34 7.42689258e+00]
# [2.31005397e+01 5.22384773e-02 1.93064925e-15 3.21683745e+00]
# [9.27833573e+00 3.84803624e-02 5.79902216e-17 2.53784275e+00]
# [3.43842297e-01 4.25731719e-03 1.25847707e-13 5.55618158e-01]
# [1.32978449e+00 1.46735665e-02 8.54002034e-15 3.61571371e+00]
# [2.84184439e+01 5.30046369e-02 4.46714413e-15 3.35612661e+00]
# [2.07489259e-01 7.35154749e-03 1.76171289e-23 5.30379429e+00]
# [1.15232793e-01 5.39706184e-03 3.48557535e-15 5.67391355e+00]
# [2.21492896e-01 4.16663281e-03 5.34163238e-09 1.41598173e+01]
# [2.14445018e+00 1.31411850e-02 1.53289522e-17 5.62570788e+00]
# [1.62340903e-01 5.23835096e-03 1.52730966e-14 6.05215892e+00]
# [8.32584266e-02 1.84242056e-03 4.26251332e-19 1.58387635e+00]
# [1.14080616e-01 1.88647371e-03 6.57949830e-18 1.64428263e+00]
# [1.82936813e-01 1.67609121e-03 2.52102270e-17 1.43245356e+00]

# %%
[s for s in stats if s.json_metadata['type'] == 'BB' and s.json_metadata['n'] == 288]
# Out:
# [sinter.TaskStats(strong_id='e578d5c54a76065df8400410951e5318ca81575c7339105a0a17474e5dc23708', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001, 'p_sh': 0.001, 'rounds': 18, 'type': 'BB'}, shots=1556, seconds=14014.560000000003),
#  sinter.TaskStats(strong_id='e1cdf56af427c1c1e49e7a89c269b00bcca5ad3fd6daa7abe981af63449d9d78', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.001467799267622069, 'p_sh': 0.001467799267622069, 'rounds': 18, 'type': 'BB'}, shots=1419, seconds=14005.509999999995),
#  sinter.TaskStats(strong_id='13b34cee9314c68d0966265a77282eac654e3ec533484cb1449140aa6a3c7138', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.0021544346900318843, 'p_sh': 0.0021544346900318843, 'rounds': 18, 'type': 'BB'}, shots=790, errors=5, seconds=14058.900000000003),
#  sinter.TaskStats(strong_id='bb195c9c13abf89f41448acfa9172579120230ea6d7875c39ae9f8a57656e374', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.0031622776601683794, 'p_sh': 0.0031622776601683794, 'rounds': 18, 'type': 'BB'}, shots=238, errors=100, seconds=4826.600000000001),
#  sinter.TaskStats(strong_id='078568797764589a111419d2248c9ee2f80151aa43b8491b805186e109cd6646', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.004641588833612777, 'p_sh': 0.004641588833612777, 'rounds': 18, 'type': 'BB'}, shots=100, errors=100, seconds=1552.3999999999999),
#  sinter.TaskStats(strong_id='c6bf36bb1aae0e50dfcd006734bd1654864f6f3acf2d9c598a7af2effcba2f71', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.006812920690579608, 'p_sh': 0.006812920690579608, 'rounds': 18, 'type': 'BB'}, shots=100, errors=100, seconds=3169.5),
#  sinter.TaskStats(strong_id='006f8a29d2ed6bd1491cd9a8879b048ec08c19a07bdee62247824af1ebe908e5', decoder='bposd', json_metadata={'T2': 0.01, 'basis': 'X', 'd': 18, 'decoder': 'bposd', 'k': 12, 'n': 288, 'p_g': 0.01, 'p_sh': 0.01, 'rounds': 18, 'type': 'BB'}, shots=100, errors=100, seconds=2228.0)]

# %%
fit_params[code_ids.index(('BB', (288,12,18)))]
# Out:
# array([2.21492896e-01, 4.16663281e-03, 5.34163238e-09, 1.41598173e+01])

# %%
from adjustText import adjust_text

label_all = False
label_codes = [
    ('Simplex', (98,18,4)),
    ('BB', (72,12,6)),
    ('BB', (144,12,12)),
    ('BB', (288,12,18)),
    # ('Radial', (256,18,16)),
    # ('Radial', (198,8,14)),
    ('Radial', (144,8,12)),
    # ('Radial', (192,18,12)),
    ('Tile', (288,8,14)),
    ('Tile', (288,8,12)),
]

markerdict = {
    'Surface':'+',
    'BB':'^',
    'Radial':'o',
    'Simplex':'p',
    'Tile':'v',
    'Hypercube':'s',
}
colordict = {
    'Surface':'k',
    'BB':'C5',
    'Radial':'C2',
    'Simplex':'C3',
    'Tile':'C1',
    'Hypercube':'C0'
}

ps_display = [
    r'10^{-2}',
    r'3 \times 10^{-3}',
    r'10^{-3}',
]

skip = ['Hypercube']
# skip = []

fig,ax = plt.subplots(3,1,figsize=(4,10))
fig.subplots_adjust(hspace=0.2)
for j,p_tgt in enumerate([1e-4]):
    T2_tgt = 10**(-6-np.log10(p_tgt))
    p_sh_tgt = p_tgt

    points = [(np.nan, np.nan) for _ in code_ids]
    texts = []
    for i,(code_type, (n,k,d)) in enumerate(code_ids):
        if code_type in skip:
            continue
        if np.all(np.isfinite(fit_params[i])):
            ler_proj = logical_fit(p_tgt, *fit_params[i])
            enc_rate = k / n
            points[i] = (enc_rate*1000, ler_proj)
            ax[j].plot(*points[i], marker=markerdict[code_type], color=colordict[code_type], markeredgecolor=plotter.interpolate(colordict[code_type], 'k', 0.2))
            if label_all or (code_type, (n,k,d)) in label_codes:
                texts.append(ax[j].text(*points[i], f'[[{n}, {k}, {d}]]', fontsize=9, ha='left', va='top'))
            print(code_type, (n,k,d), points[i])
    xs_surface = []
    ys_surface = []
    for d in ds_surface:
        pt = points[code_ids.index(('Surface', (d**2,1,d)))]
        xs_surface.append(pt[0])
        ys_surface.append(pt[1])
    ax[j].plot(xs_surface, ys_surface, 'C0--', alpha=0.5, zorder=0.2)
    ax[j].set_yscale('log')

    ax[j].set_xlim(0, 250)
    ax[j].set_ylim(top=1)
    xlim = ax[j].get_xlim()
    ylim = ax[j].get_ylim()

    xs_surface = np.array([-10] + xs_surface + [1000])
    ys_surface = np.array([1e-30] + ys_surface + [1e-3])
    sort_idx = np.argsort(xs_surface)
    ax[j].fill_between(xs_surface[sort_idx], ys_surface[sort_idx], [1]*len(ys_surface), color='#BBBBBB', zorder=0, alpha=0.5)

    ax[j].set_xlim(*xlim)
    ax[j].set_ylim(*ylim)

    for (code_type, marker) in markerdict.items():
        if code_type in skip:
            continue
        ax[j].plot([], [], color=colordict[code_type], marker=marker, linestyle='none', markeredgecolor=plotter.interpolate(colordict[code_type], 'k', 0.2), label=code_type)
    if j == 1:
        ax[j].legend(bbox_to_anchor=(0.8,0.2), loc='center')

    
    ax[j].set_title(r'$p_\text{sh}=' + ps_display[j] + r'$')
    if j == 2:
        ax[j].set_xlabel('# logical qubits per 1000 physical qubits')
    else:
        ax[j].set_xticklabels([])
    ax[j].set_ylabel('Logical error rate')
    # ax[j].ylim(1e-18, 1e-2)
    ax[j].set_yticks(ax[j].get_yticks(), minor=[])
    adjust_text(
        texts,
        arrowprops=dict(arrowstyle='->', color='gray'),
        # force_text=(1, 1),
        force_static=(1, 1),
        expand=(1.2, 3),
        prevent_crossings=True,
        add_objects=ax[j].collections,
        ax=ax[j],
    )
    ax[j].grid(which='both', linewidth=0.5, zorder=0.1)
    ax[j].tick_params(direction='in', which='both')
    ax[j].set_ylim(top=1)
plt.savefig('notebooks/fig/10_encoding_rate.pdf', bbox_inches='tight')
plt.savefig('notebooks/fig/10_encoding_rate.svg', bbox_inches='tight')
plt.show()
# Out:
# Surface (9, 1, 3) (111.1111111111111, np.float64(7.575207124187202e-06))
# Surface (25, 1, 5) (40.0, np.float64(6.977685730853027e-07))
# Surface (49, 1, 7) (20.408163265306122, np.float64(4.620736879949741e-07))
# Surface (81, 1, 9) (12.345679012345679, np.float64(5.178734751442321e-07))
# Surface (121, 1, 11) (8.264462809917356, np.float64(2.626793935655598e-05))
# Tile (288, 8, 12) (27.777777777777775, np.float64(2.4419218766325166e-09))
# Tile (288, 8, 14) (27.777777777777775, np.float64(4.294969032082463e-05))
# Tile (288, 18, 13) (62.5, np.float64(0.0002479620906365509))
# Tile (512, 18, 19) (35.15625, np.float64(0.018586709953911318))
# Simplex (98, 18, 4) (183.67346938775512, np.float64(1.3296184423702614e-05))
# Simplex (450, 32, 8) (71.11111111111111, np.float64(3.3103372457566685e-05))
# BB (72, 12, 6) (166.66666666666666, np.float64(2.7187026312491424e-07))
# BB (144, 12, 12) (83.33333333333333, np.float64(1.9117968360600065e-07))
# BB (288, 12, 18) (41.666666666666664, np.float64(1.168251777621318e-13))
# Radial (144, 8, 12) (55.55555555555555, np.float64(2.053946904887855e-07))
# Radial (198, 8, 14) (40.40404040404041, np.float64(1.4073794904222187e-07))
# Radial (192, 18, 12) (93.75, np.float64(0.0019302970100523256))
# Radial (256, 18, 16) (70.3125, np.float64(0.0023475847965243202))
# Radial (352, 18, 20) (51.13636363636364, np.float64(0.005933043347098474))

# %%
from adjustText import adjust_text

label_all = False

ps_display = [
    r'10^{-2}',
    r'3 \times 10^{-3}',
    r'10^{-3}',
]

for j,p_tgt in enumerate([1e-3]):
    fig,ax = plt.subplots(figsize=(4,3))
    T2_tgt = 10**(-6-np.log10(p_tgt))
    p_sh_tgt = p_tgt

    points = [(np.nan, np.nan) for _ in code_ids]
    texts = []
    for i,(code_type, (n,k,d)) in enumerate(code_ids):
        if code_type in skip:
            continue
        if np.all(np.isfinite(fit_params[i])):
            ler_proj = logical_fit(p_tgt, *fit_params[i])
            enc_rate = k / n
            points[i] = (enc_rate*1000, ler_proj)
            ax.plot(*points[i], marker=markerdict[code_type], color=colordict[code_type], markeredgecolor=plotter.interpolate(colordict[code_type], 'k', 0.2))
            if label_all or (code_type, (n,k,d)) in label_codes:
                texts.append(ax.text(*points[i], f'[[{n}, {k}, {d}]]', fontsize=9, ha='left', va='top'))
    xs_surface = []
    ys_surface = []
    for d in ds_surface:
        pt = points[code_ids.index(('Surface', (d**2,1,d)))]
        xs_surface.append(pt[0])
        ys_surface.append(pt[1])
    ax.plot(xs_surface, ys_surface, 'C0--', alpha=1, zorder=0.2, linewidth=2)
    ax.set_yscale('log')

    ax.set_xlim(0, 250)
    ax.set_ylim(top=1)
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()

    xs_surface = np.array([-10] + xs_surface + [1000])
    ys_surface = np.array([1e-30] + ys_surface + [1])
    sort_idx = np.argsort(xs_surface)
    ax.fill_between(xs_surface[sort_idx], ys_surface[sort_idx], [1]*len(ys_surface), color='#BBBBBB', zorder=0, alpha=0.5)

    ax.set_xlim(*xlim)
    ax.set_ylim(*ylim)

    for (code_type, marker) in markerdict.items():
        if code_type in skip:
            continue
        ax.plot([], [], color=colordict[code_type], marker=marker, linestyle='none', markeredgecolor=plotter.interpolate(colordict[code_type], 'k', 0.2), label=code_type)

    ax.legend(bbox_to_anchor=(1,0.5), loc='center left')
    
    # ax.set_title(r'$(p,T_2,p_\text{sh})=(' + ps_display[j] + f', {T2_tgt*1e3:.2g}ms, ' + ps_display[j] + r')$')
    ax.set_title(r'$p_\text{gate} = 10^{-3}, p_\text{sh}=' + ps_display[j] + r'$')
    ax.set_xlabel('# logical qubits per 1000 physical qubits')

    ax.set_ylabel('Logical error rate')
    # ax.ylim(1e-18, 1e-2)
    ax.set_yticks(ax.get_yticks(), minor=[])
    adjust_text(
        texts,
        arrowprops=dict(arrowstyle='->', color='gray'),
        # force_text=(1, 1),
        force_static=(1, 3),
        expand=(1.2, 4),
        prevent_crossings=True,
        add_objects=ax.collections,
        ax=ax,
    )
    ax.grid(which='both', linewidth=0.5, zorder=0.1)
    ax.tick_params(direction='in', which='both')
    ax.set_ylim(top=1)
    plt.savefig(f'notebooks/fig/10_encoding_rate_{j}.pdf', bbox_inches='tight')
    plt.savefig(f'notebooks/fig/10_encoding_rate_{j}.png', dpi=300, bbox_inches='tight')
    # plt.savefig('notebooks/fig/10_encoding_rate.svg', bbox_inches='tight')
    plt.show()

# %%
from scipy.interpolate import interp1d

# Define the range of physical error rates to plot
ps_eval = np.geomspace(1e-4, 1e-2, 50)

fig, ax = plt.subplots(figsize=(6, 5))

# Extract surface code fit parameters
surface_data = []
for d in ds_surface:
    idx = code_ids.index(('Surface', (d**2, 1, d)))
    fp = fit_params[idx]
    surface_data.append((1 / (d**2), fp))

markerlist = [
    '+',
    '^',
    'o',
    'p',
    'v',
    's',
]
type_counts = dict()

# Calculate and plot the improvement factor for each non-Surface code
for i, (code_type, (n, k, d)) in enumerate(code_ids):
    if code_type == 'Surface' or code_type in skip:
        continue
    
    fp_code = fit_params[i]
    if not np.all(np.isfinite(fp_code)):
        continue

    encoding_rate = k / n
    improvements = []

    for p in ps_eval:
        # 1. Evaluate surface code LERs at this specific physical error rate (p)
        sc_rates = []
        sc_lers = []
        for sc_rate, sc_fp in surface_data:
            sc_rates.append(sc_rate)
            sc_lers.append(logical_fit(p, *sc_fp))
            
        # Append the bare physical qubit representing an encoding rate of 1
        sc_rates.append(1.0)
        sc_lers.append(p)
        
        # Sort values to ensure interp1d works correctly
        sort_idx = np.argsort(sc_rates)
        sc_rates = np.array(sc_rates)[sort_idx]
        sc_lers = np.array(sc_lers)[sort_idx]
        
        # 2. Create interpolation function in log-log space
        interp_func = interp1d(
            np.log10(sc_rates), 
            np.log10(sc_lers), 
            kind='linear',
            bounds_error=False, 
            fill_value='extrapolate' # Handles codes with k/n < 1/121
        )
        
        # 3. Find the Equivalent Surface Code LER
        equiv_sc_ler = 10**(interp_func(np.log10(encoding_rate)))
        
        # 4. Find the actual code LER and calculate the ratio (Speedup)
        code_ler = logical_fit(p, *fp_code)
        improvement = equiv_sc_ler / code_ler
        improvements.append(improvement)

    # Plot the results
    ax.plot(
        ps_eval, 
        improvements, 
        label=f'{code_type} [[{n}, {k}, {d}]]',
        color=colordict.get(code_type, 'k'),
        marker=markerlist[type_counts.get(code_type, 0)],
        markevery=5, # Spacing out markers so they don't clutter the line
        markeredgecolor=plotter.interpolate(colordict.get(code_type, 'k'), 'k', 0.2)
    )
    type_counts[code_type] = type_counts.get(code_type, 0) + 1

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'Physical error rate ($p_{\text{sh}}$)')
ax.set_ylabel('Improvement Factor\n(Equivalent Surface LER / Code LER)')

# Add a baseline indicating "no improvement" over surface codes
ax.axhline(1, color='k', linestyle='--', alpha=0.5, label='Surface Code Baseline')

ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
ax.grid(which='both', linewidth=0.5, zorder=0.1)
ax.tick_params(direction='in', which='both')

plt.title('Relative LER Improvement vs Equivalent Surface Code')
# plt.savefig('notebooks/fig/10_improvement_factor.pdf', bbox_inches='tight')
plt.show()
